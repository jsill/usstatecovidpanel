# %% [markdown]
# # Lagged Association of Relative Humidity with Excess Death Rates during the Covid-19 Pandemic in the United States.

# %%
import pandas as pd,statsmodels,sklearn,numpy,extractors,importlib
import statsmodels.formula.api as smf
import statsmodels.graphics.regressionplots
import statsmodels.api as sm
import matplotlib.pyplot as plt
import datetime
importlib.reload(extractors)
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr, data
import scipy.stats

installsNeeded=False

utils = importr('utils')
base = importr('base')

if (installsNeeded):
    packages=['stats','lmtest','plm','sandwich','Hmisc','MASS','spdep']
    for pkg in packages:
        utils.install_packages(pkg)
        
plm=importr('plm')
stats=importr('stats')
lmtest=importr('lmtest')
sandwich=importr('sandwich')
Hmisc=importr('Hmisc')
MASS=importr('MASS')

# %%
print(robjects.r('version'))
# Out:
#                _
#
# platform       x86_64-w64-mingw32
#
# arch           x86_64
#
# os             mingw32
#
# system         x86_64, mingw32
#
# status
#
# major          3
#
# minor          6.1
#
# year           2019
#
# month          07
#
# day            05
#
# svn rev        76782
#
# language       R
#
# version.string R version 3.6.1 (2019-07-05)
#
# nickname       Action of the Toes

# %%
panelDF=pd.read_csv('panelDataFrame.csv')

def monthObj(monthAndYear):
    splts=monthAndYear.split('_')
    month=int(splts[1].strip())
    year=int(splts[0].strip())
    return datetime.date(year,month,1)

panelDF['MonthAndYearObj']=panelDF['MonthAndYear'].apply(monthObj)

#panelDF['DistanceFromJanuary']=panelDF['']

# %%
importlib.reload(extractors)

def doPlot(stateLevelDataToPlot,xVar,yVar,xlabel,ylabel,title,removeDenseNortheast=False,removeSD=False):
    fig, ax = plt.subplots()

    corr=stateLevelDataToPlot[[xVar,yVar]].corr()[xVar][1]
    R2=corr*corr
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.scatter(stateLevelDataToPlot[xVar],stateLevelDataToPlot[yVar] )

    #abbrs=[extractors.abbrevDict[v] for v in stateLevelDataToPlot['State/Territory'].values ]
    #for i in range(stateLevelDataToPlot.shape[0]):
    #    ax.annotate(abbrs[i], (stateLevelDataToPlot[inEq].values[i], stateLevelDataToPlot[deathMetric].values[i]))
    fig.savefig('ExcessVsHumidityDeviation2MonthsPrev.png',format='png')#,bbox_inches='tight')

# %% [markdown]
# Plotting excess death percentage vs. deviation from the state's median RH 2 months previously reveals that very high excess pct almost never occurs when RH for the state is unusually high 2 months previously and very low excess pct almost never occurs when RH is unusually low 2 months previously. Obviously, a great many factors influence excess death rates during the pandemic, which is probably why there is little observable pattern for intermediate RH values, but the pattern at the extremes is quite clear.

# %%
doPlot(panelDF,'HumidityDeviation2MonthsPrev',
       'ExcessPctCurrent','Humidity Deviation 2 Months Previous','ExcessPct','ExcessPct vs. HumidityDeviation2MonthsPrev')

# %%
panelDFToUse=panelDF


def runSimpleAssociation(panelDFToUse,humidityLevel='HumidityDeviation2MonthsPrev',excessThresh=30,humidityThresh=10):
   
    belowAvg=panelDFToUse[panelDFToUse[humidityLevel] < -humidityThresh]
    numHumidityBelow=belowAvg.shape[0]
    print('num state/month pairs with humidity at least %3.1f pct below median: %d'%(humidityThresh,numHumidityBelow))
    totalNumAboveExcess=panelDFToUse[panelDFToUse['ExcessPctCurrent'] > excessThresh].shape[0]
    
    aboveAvg=panelDFToUse[panelDFToUse[humidityLevel] > humidityThresh]
    numHumidityAbove=aboveAvg.shape[0]
    print('num state/month pairs with humidity at least %3.1f pct above median: %d'%(humidityThresh,numHumidityAbove))
    
    totalNumMonths=panelDFToUse.shape[0]
    
    print('total state/month pairs with excess above %3.1f pct: %d of %d, %3.1f pct'%(excessThresh,totalNumAboveExcess,totalNumMonths,100*totalNumAboveExcess/totalNumMonths))
    print(Hmisc.binconf(totalNumAboveExcess,totalNumMonths))
    numExcessAboveForHumidityAbove=aboveAvg[aboveAvg['ExcessPctCurrent'] > excessThresh].shape[0]
    numExcessAboveForHumidityBelow=belowAvg[belowAvg['ExcessPctCurrent'] > excessThresh].shape[0]
    print('num state/monthpairs with excess above %3.1f pct for humidity at least %3.1f pct below median: %d out of %d, %3.1f pct'%(excessThresh,humidityThresh,
                                                                                                                                numExcessAboveForHumidityBelow,numHumidityBelow,
                                                                                                                                100*numExcessAboveForHumidityBelow/numHumidityBelow))
        
    print(Hmisc.binconf(numExcessAboveForHumidityBelow,numHumidityBelow))
    print('num state/month pairs with excess above %3.1f pct for humidity at least %3.1f pct above median: %d out of %d, %3.1f pct'%(excessThresh,humidityThresh,
                                                                                                                                     numExcessAboveForHumidityAbove,numHumidityAbove,
                                                                                                                                     100*numExcessAboveForHumidityAbove/numHumidityAbove))
    print(Hmisc.binconf(numExcessAboveForHumidityAbove,numHumidityAbove))
                                                                                                                                     


    
    print('low humidity, high excess:')
    print('number of states represented among states with humidity at least %3.1f below median and excess above threshold: '%humidityThresh,len(list(set(belowAvg[belowAvg['ExcessPctCurrent'] > excessThresh]['State'].values))))
    print(belowAvg[belowAvg['ExcessPctCurrent'] > excessThresh].groupby(['State'])['State'].count())
    print('high humidity:')
    print('number of states represented among states with humidity at least %3.1f above median: '%humidityThresh,len(list(set(aboveAvg['State'].values))))
    print(aboveAvg.groupby(['State'])['State'].count())
#print(panelDF[panelDF['State']=='Maryland'][['MonthAndYear','ActualHumidity2MonthsPrev','HumidityDeviation2MonthsPrev','ExcessPct']])

# %% [markdown]
# Excess death above 30 percent is far more likely 2 months after a month with RH at least 10 percent below median than after a month with RH at least 10 percent above. 30 percent excess and 10 percent RH deviations are chosen to correpond roughly to 1 standard deviation of those variables, although the code can obviously be rerun with different thresholds chosen if so desired.

# %%
runSimpleAssociation(panelDF,humidityLevel='HumidityDeviation2MonthsPrev')
# Out:
# num state/month pairs with humidity at least 10.0 pct below median: 109
# num state/month pairs with humidity at least 10.0 pct above median: 80
# total state/month pairs with excess above 30.0 pct: 216 of 1122, 19.3 pct
#   PointEst     Lower     Upper
#
#  0.1925134 0.1705079 0.2166171
#
# num state/monthpairs with excess above 30.0 pct for humidity at least 10.0 pct below median: 42 out of 109, 38.5 pct
#   PointEst     Lower     Upper
#
#  0.3853211 0.2993459 0.4791043
#
# num state/month pairs with excess above 30.0 pct for humidity at least 10.0 pct above median: 3 out of 80, 3.8 pct
#  PointEst      Lower     Upper
#
#    0.0375 0.01283457 0.1045472
#
# low humidity, high excess:
# number of states represented among states with humidity at least 10.0 below median and excess above threshold:  22
# State
# Arizona           1
# Arkansas          1
# California        1
# Georgia           1
# Idaho             4
# Illinois          1
# Iowa              1
# Kentucky          1
# Minnesota         1
# Montana           6
# Nebraska          1
# North_Dakota      2
# Oklahoma          1
# Oregon            3
# South_Carolina    1
# South_Dakota      1
# Texas             1
# Utah              3
# Virginia          1
# Washington        1
# Wisconsin         2
# Wyoming           7
# Name: State, dtype: int64
# high humidity:
# number of states represented among states with humidity at least 10.0 above median:  31
# State
# Arizona          3
# California       3
# Colorado         4
# Connecticut      1
# Georgia          2
# Idaho            4
# Illinois         2
# Indiana          1
# Iowa             4
# Kansas           2
# Kentucky         1
# Michigan         2
# Minnesota        3
# Missouri         1
# Montana          2
# Nebraska         4
# Nevada           5
# New_Hampshire    1
# New_Jersey       1
# New_Mexico       4
# North_Dakota     5
# Ohio             1
# Oklahoma         1
# Oregon           2
# South_Dakota     4
# Texas            2
# Utah             7
# Vermont          2
# Washington       2
# Wisconsin        2
# Wyoming          2
# Name: State, dtype: int64

# %% [markdown]
# The pattern holds up even if we exclude winter months.

# %%
panelDFNoWinter=panelDF.copy()

panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2020_11']
panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2020_12']
panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2021_1']
panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2021_2']

panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2021_11']
panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2021_12']
panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2022_1']
panelDFNoWinter=panelDFNoWinter[panelDFNoWinter['MonthAndYear'] != '2022_2']

runSimpleAssociation(panelDFNoWinter,'HumidityDeviation2MonthsPrev')
# Out:
# num state/month pairs with humidity at least 10.0 pct below median: 53
# num state/month pairs with humidity at least 10.0 pct above median: 62
# total state/month pairs with excess above 30.0 pct: 85 of 714, 11.9 pct
#   PointEst     Lower     Upper
#
#  0.1190476 0.0973084 0.1448641
#
# num state/monthpairs with excess above 30.0 pct for humidity at least 10.0 pct below median: 19 out of 53, 35.8 pct
#   PointEst     Lower     Upper
#
#  0.3584906 0.2430195 0.4930886
#
# num state/month pairs with excess above 30.0 pct for humidity at least 10.0 pct above median: 1 out of 62, 1.6 pct
#    PointEst        Lower     Upper
#
#  0.01612903 0.0008273112 0.0858672
#
# low humidity, high excess:
# number of states represented among states with humidity at least 10.0 below median and excess above threshold:  8
# State
# Arizona         1
# Idaho           2
# Montana         4
# North_Dakota    1
# Oregon          3
# Utah            2
# Washington      1
# Wyoming         5
# Name: State, dtype: int64
# high humidity:
# number of states represented among states with humidity at least 10.0 above median:  29
# State
# Arizona          2
# California       2
# Colorado         4
# Connecticut      1
# Georgia          1
# Idaho            2
# Illinois         2
# Indiana          1
# Iowa             4
# Kansas           2
# Kentucky         1
# Michigan         2
# Minnesota        3
# Missouri         1
# Montana          1
# Nebraska         4
# Nevada           3
# New_Hampshire    1
# New_Jersey       1
# New_Mexico       4
# North_Dakota     3
# Ohio             1
# Oklahoma         1
# South_Dakota     4
# Texas            2
# Utah             3
# Vermont          2
# Wisconsin        2
# Wyoming          2
# Name: State, dtype: int64

# %% [markdown]
# If we look at different lags (0 months, 1 month, 3 months), the strength of the association wanes in a way which is consistent with known lags between infection and death (2 to 8 weeks).

# %%
runSimpleAssociation(panelDF,humidityLevel='HumidityDeviationCurrent')
# Out:
# num state/month pairs with humidity at least 10.0 pct below median: 115
# num state/month pairs with humidity at least 10.0 pct above median: 94
# total state/month pairs with excess above 30.0 pct: 216 of 1122, 19.3 pct
#   PointEst     Lower     Upper
#
#  0.1925134 0.1705079 0.2166171
#
# num state/monthpairs with excess above 30.0 pct for humidity at least 10.0 pct below median: 24 out of 115, 20.9 pct
#   PointEst     Lower     Upper
#
#  0.2086957 0.1444454 0.2917783
#
# num state/month pairs with excess above 30.0 pct for humidity at least 10.0 pct above median: 13 out of 94, 13.8 pct
#   PointEst      Lower     Upper
#
#  0.1382979 0.08263778 0.2223603
#
# low humidity, high excess:
# number of states represented among states with humidity at least 10.0 below median and excess above threshold:  14
# State
# Arkansas         2
# Connecticut      2
# Idaho            1
# Kansas           1
# Massachusetts    1
# Missouri         1
# Montana          2
# Oklahoma         3
# Oregon           2
# Rhode_Island     2
# Texas            2
# Utah             1
# Washington       1
# Wyoming          3
# Name: State, dtype: int64
# high humidity:
# number of states represented among states with humidity at least 10.0 above median:  32
# State
# Alaska           1
# Arizona          3
# California       2
# Colorado         6
# Connecticut      1
# Georgia          1
# Idaho            6
# Illinois         2
# Indiana          1
# Iowa             4
# Kansas           2
# Kentucky         1
# Michigan         3
# Minnesota        4
# Missouri         1
# Montana          4
# Nebraska         4
# Nevada           6
# New_Hampshire    1
# New_Jersey       1
# New_Mexico       5
# North_Dakota     6
# Ohio             1
# Oklahoma         1
# Oregon           3
# South_Dakota     3
# Texas            2
# Utah             8
# Vermont          2
# Washington       3
# Wisconsin        2
# Wyoming          4
# Name: State, dtype: int64

# %%
runSimpleAssociation(panelDF,humidityLevel='HumidityDeviation1MonthsPrev')
# Out:
# num state/month pairs with humidity at least 10.0 pct below median: 114
# num state/month pairs with humidity at least 10.0 pct above median: 82
# total state/month pairs with excess above 30.0 pct: 216 of 1122, 19.3 pct
#   PointEst     Lower     Upper
#
#  0.1925134 0.1705079 0.2166171
#
# num state/monthpairs with excess above 30.0 pct for humidity at least 10.0 pct below median: 34 out of 114, 29.8 pct
#   PointEst     Lower     Upper
#
#  0.2982456 0.2219614 0.3876837
#
# num state/month pairs with excess above 30.0 pct for humidity at least 10.0 pct above median: 5 out of 82, 6.1 pct
#    PointEst      Lower     Upper
#
#  0.06097561 0.02632396 0.1349205
#
# low humidity, high excess:
# number of states represented among states with humidity at least 10.0 below median and excess above threshold:  19
# State
# Arizona         1
# Arkansas        2
# Idaho           3
# Illinois        1
# Iowa            1
# Kansas          1
# Minnesota       1
# Montana         4
# Nebraska        1
# North_Dakota    2
# Oklahoma        1
# Oregon          3
# Rhode_Island    1
# South_Dakota    1
# Texas           1
# Utah            2
# Washington      1
# Wisconsin       2
# Wyoming         5
# Name: State, dtype: int64
# high humidity:
# number of states represented among states with humidity at least 10.0 above median:  31
# State
# Arizona          2
# California       2
# Colorado         5
# Connecticut      1
# Georgia          1
# Idaho            5
# Illinois         2
# Indiana          1
# Iowa             4
# Kansas           2
# Kentucky         1
# Michigan         2
# Minnesota        3
# Missouri         1
# Montana          3
# Nebraska         4
# Nevada           5
# New_Hampshire    1
# New_Jersey       1
# New_Mexico       4
# North_Dakota     5
# Ohio             1
# Oklahoma         1
# Oregon           3
# South_Dakota     3
# Texas            2
# Utah             7
# Vermont          2
# Washington       3
# Wisconsin        2
# Wyoming          3
# Name: State, dtype: int64

# %%
runSimpleAssociation(panelDF,humidityLevel='HumidityDeviation3MonthsPrev')
# Out:
# num state/month pairs with humidity at least 10.0 pct below median: 106
# num state/month pairs with humidity at least 10.0 pct above median: 82
# total state/month pairs with excess above 30.0 pct: 216 of 1122, 19.3 pct
#   PointEst     Lower     Upper
#
#  0.1925134 0.1705079 0.2166171
#
# num state/monthpairs with excess above 30.0 pct for humidity at least 10.0 pct below median: 34 out of 106, 32.1 pct
#   PointEst     Lower     Upper
#
#  0.3207547 0.2395086 0.4145383
#
# num state/month pairs with excess above 30.0 pct for humidity at least 10.0 pct above median: 4 out of 82, 4.9 pct
#    PointEst      Lower     Upper
#
#  0.04878049 0.01913107 0.1188146
#
# low humidity, high excess:
# number of states represented among states with humidity at least 10.0 below median and excess above threshold:  13
# State
# California      2
# Idaho           4
# Minnesota       2
# Montana         6
# Nevada          1
# North_Dakota    2
# Oregon          3
# South_Dakota    1
# Texas           2
# Utah            3
# Washington      1
# Wisconsin       1
# Wyoming         6
# Name: State, dtype: int64
# high humidity:
# number of states represented among states with humidity at least 10.0 above median:  32
# State
# Arizona           2
# California        2
# Colorado          5
# Connecticut       1
# Georgia           3
# Idaho             4
# Illinois          2
# Indiana           1
# Iowa              4
# Kansas            2
# Kentucky          1
# Michigan          2
# Minnesota         4
# Missouri          1
# Montana           2
# Nebraska          4
# Nevada            4
# New_Hampshire     1
# New_Jersey        1
# New_Mexico        5
# North_Dakota      5
# Ohio              1
# Oklahoma          1
# Oregon            1
# South_Carolina    1
# South_Dakota      5
# Texas             2
# Utah              7
# Vermont           2
# Washington        1
# Wisconsin         2
# Wyoming           3
# Name: State, dtype: int64

# %% [markdown]
# In addition to looking at associations of RH with high excess rates 2 months later, we can also look at associations with low excess rates 2 months later. The result below is not mentioned in the paper, for space considerations, but reinforces the pattern observed regarding high excess rates. A low excess rate (below 5 percent) is 5X more likely if RH is at least 10% above median than if at least 10% below.

# %%
def runForLowExcess(panelDFToUse,excessThresh=5,humidityLevel='HumidityDeviation2MonthsPrev',humidityThresh=10):
    aboveAvg=panelDFToUse[panelDFToUse[humidityLevel] > humidityThresh]
    numHumidityAbove=aboveAvg.shape[0]
    print('num state/month pairs with humidity at least %3.1f pct above median: %d'%(humidityThresh,numHumidityAbove))
    belowAvg=panelDFToUse[panelDFToUse[humidityLevel] < -humidityThresh]
    numHumidityBelow=belowAvg.shape[0]
    print('num state/month pairs with humidity at least %3.1f pct below median: %d'%(humidityThresh,numHumidityBelow))
    totalNumBelowExcess=panelDFToUse[panelDFToUse['ExcessPctCurrent'] < excessThresh].shape[0]
    totalNumMonths=panelDFToUse.shape[0]
    print('total state/month pairs with excess below %3.1f: %d of %d, %3.1f pct'%(excessThresh,totalNumBelowExcess,totalNumMonths,100*totalNumBelowExcess/totalNumMonths))
    print(Hmisc.binconf(totalNumBelowExcess,totalNumMonths))
    numExcessBelowForHumidityAbove=aboveAvg[aboveAvg['ExcessPctCurrent'] < excessThresh]['State'].shape[0]
    numExcessBelowForHumidityBelow=belowAvg[belowAvg['ExcessPctCurrent'] < excessThresh]['State'].shape[0]
    numStatesExcessBelowForHumidityAbove=len(set(aboveAvg[aboveAvg['ExcessPctCurrent'] < excessThresh]['State'].values))#,'MonthAndYear','HumidityDeviation2MonthsPrev']])
    print('num state/month pairs with excess below %3.1f pct for humidity at least %3.1f pct above median: %d out of %d, %3.1f pct'%(excessThresh,humidityThresh,
                                                                                                                                     numExcessBelowForHumidityAbove,
                                                                                                                                     numHumidityAbove,
                                                                                                                                     100*numExcessBelowForHumidityAbove/numHumidityAbove))  
    print('num distinct states: %d'%numStatesExcessBelowForHumidityAbove)
    print(Hmisc.binconf(numExcessBelowForHumidityAbove,numHumidityAbove))
    print('num state/monthpairs with excess below %3.1f pct for humidity at least %3.1f below median: %d out of %d, %3.1f pct'%(excessThresh,humidityThresh,
                                                                                                                                numExcessBelowForHumidityBelow,numHumidityBelow,
                                                                                                                                100*numExcessBelowForHumidityBelow/numHumidityBelow))
    print(Hmisc.binconf(numExcessBelowForHumidityBelow,numHumidityBelow))
    print(numExcessBelowForHumidityAbove,numExcessBelowForHumidityAbove/numHumidityAbove)
    print(numExcessBelowForHumidityBelow,numExcessBelowForHumidityBelow/numHumidityBelow)
    print('high humidity, low excess:')
    print(aboveAvg[aboveAvg['ExcessPctCurrent'] < excessThresh].groupby(['State'])['State'].count())
    print('low humidity:')
    print(belowAvg.groupby(['State'])['State'].count())

# %%
runForLowExcess(panelDF)
# Out:
# num state/month pairs with humidity at least 10.0 pct above median: 80
# num state/month pairs with humidity at least 10.0 pct below median: 109
# total state/month pairs with excess below 5.0: 243 of 1122, 21.7 pct
#   PointEst     Lower     Upper
#
#  0.2165775 0.1934641 0.2416251
#
# num state/month pairs with excess below 5.0 pct for humidity at least 10.0 pct above median: 35 out of 80, 43.8 pct
# num distinct states: 19
#  PointEst     Lower     Upper
#
#    0.4375 0.3341386 0.5465887
#
# num state/monthpairs with excess below 5.0 pct for humidity at least 10.0 below median: 9 out of 109, 8.3 pct
#    PointEst      Lower     Upper
#
#  0.08256881 0.04404671 0.1495121
#
# 35 0.4375
# 9 0.08256880733944955
# high humidity, low excess:
# State
# Arizona          1
# California       2
# Colorado         1
# Connecticut      1
# Idaho            3
# Illinois         2
# Indiana          1
# Iowa             2
# Michigan         1
# Minnesota        2
# Nebraska         2
# Nevada           3
# New_Hampshire    1
# North_Dakota     3
# Ohio             1
# South_Dakota     3
# Utah             3
# Wisconsin        2
# Wyoming          1
# Name: State, dtype: int64
# low humidity:
# State
# Alaska            1
# Arizona           1
# Arkansas          2
# California        2
# Connecticut       2
# Georgia           1
# Idaho             8
# Illinois          1
# Iowa              4
# Kansas            3
# Kentucky          1
# Maine             2
# Massachusetts     3
# Michigan          1
# Minnesota         5
# Missouri          1
# Montana           7
# Nebraska          4
# Nevada            2
# New_Hampshire     2
# New_Mexico        1
# North_Carolina    1
# North_Dakota      4
# Oklahoma          2
# Oregon            8
# Rhode_Island      4
# South_Carolina    1
# South_Dakota      4
# Texas             2
# Utah              8
# Vermont           1
# Virginia          1
# Washington        9
# Wisconsin         3
# Wyoming           7
# Name: State, dtype: int64

# %% [markdown]
# We can inspect the timing of large spikes in excess death percentage vs. RH a few months prior for certain states to get some anecodotal evidence in addition to the various statistical measures in the paper.

# %%
def showExcessVsHumidity(state):
    print('\n\n' + state + '\n')
    stateDF=panelDF[panelDF['State']==state]
    print('mean humidity: %3.1f'%(stateDF['RelativeHumidity2MonthsPrev'].mean()))
    print('median humidity: %3.1f'%(stateDF['RelativeHumidity2MonthsPrev'].median()))
    print('stdev humidity: %3.1f'%(stateDF['RelativeHumidity2MonthsPrev'].std()))
    print('mean hist avg humidity: %3.1f'%(stateDF['HistoricalAvgRelativeHumidity2MonthsPrev'].mean()))
    print(stateDF[['MonthAndYear','ExcessPctCurrent','RelativeHumidity2MonthsPrev']])

# %%
#for state in sorted(list(set(panelDF['State'].values))):
#    print(state)
showExcessVsHumidity('South_Dakota')
# Out:
# South_Dakota
#
# mean humidity: 63.9
# median humidity: 65.8
# stdev humidity: 10.8
# mean hist avg humidity: 68.1
#      MonthAndYear  ExcessPctCurrent  RelativeHumidity2MonthsPrev
# 20         2020_5          3.862661                         77.8
# 71         2020_6          6.079027                         63.1
# 122        2020_7          7.237814                         76.2
# 173        2020_8         17.236256                         66.1
# 224        2020_9         24.018127                         69.5
# 275       2020_10         40.028289                         58.3
# 326       2020_11        104.781997                         42.5
# 377       2020_12         46.845638                         58.3
# 428        2021_1         18.484043                         58.6
# 479        2021_2          4.985337                         68.8
# 530        2021_3          1.731025                         76.1
# 581        2021_4          3.025937                         83.5
# 632        2021_5          3.473227                         68.8
# 683        2021_6          3.206107                         72.3
# 734        2021_7          5.786350                         69.5
# 785        2021_8         11.940299                         58.2
# 836        2021_9         23.088235                         56.8
# 887       2021_10         17.056396                         41.3
# 938       2021_11         25.722146                         51.1
# 989       2021_12         25.331565                         68.4
# 1040       2022_1         28.994845                         55.5
# 1091       2022_2         16.502116                         65.4

# %%
showExcessVsHumidity('Hawaii')
# Out:
# Hawaii
#
# mean humidity: 73.5
# median humidity: 73.0
# stdev humidity: 2.5
# mean hist avg humidity: 69.8
#      MonthAndYear  ExcessPctCurrent  RelativeHumidity2MonthsPrev
# 13         2020_5          0.501002                         78.1
# 64         2020_6          3.205791                         72.8
# 115        2020_7          1.907631                         75.2
# 166        2020_8          4.658077                         73.4
# 217        2020_9          8.427544                         72.3
# 268       2020_10          4.627767                         71.7
# 319       2020_11          3.367347                         71.2
# 370       2020_12          0.559701                         73.8
# 421        2021_1          0.091743                         77.7
# 472        2021_2          4.591837                         73.1
# 523        2021_3          2.266289                         76.2
# 574        2021_4          3.363007                         73.6
# 625        2021_5          2.837573                         77.1
# 676        2021_6          0.203874                         70.4
# 727        2021_7          1.771654                         72.2
# 778        2021_8         22.286822                         68.2
# 829        2021_9         26.834171                         72.4
# 880       2021_10         10.460653                         72.3
# 931       2021_11          2.895753                         71.0
# 982       2021_12          0.088731                         73.0
# 1033       2022_1         16.069869                         74.9
# 1084       2022_2         10.231660                         76.3

# %%
showExcessVsHumidity('California')
# Out:
# California
#
# mean humidity: 46.8
# median humidity: 46.0
# stdev humidity: 7.9
# mean hist avg humidity: 57.9
#      MonthAndYear  ExcessPctCurrent  RelativeHumidity2MonthsPrev
# 19         2020_5          4.697282                         60.9
# 70         2020_6          7.022234                         55.5
# 121        2020_7         20.266702                         47.9
# 172        2020_8         21.539005                         41.1
# 223        2020_9         11.766312                         47.2
# 274       2020_10          6.065460                         42.5
# 325       2020_11         15.060631                         33.7
# 376       2020_12         62.689934                         35.0
# 427        2021_1         81.486384                         48.4
# 478        2021_2         27.610071                         36.2
# 529        2021_3          7.108362                         50.3
# 580        2021_4          0.943437                         59.4
# 631        2021_5          2.725486                         49.6
# 682        2021_6          6.238909                         50.9
# 733        2021_7          9.265983                         43.4
# 784        2021_8         25.385041                         44.7
# 835        2021_9         29.745486                         42.4
# 886       2021_10         21.116819                         41.2
# 937       2021_11         14.445180                         39.9
# 988       2021_12         16.918515                         44.9
# 1039       2022_1         35.628160                         55.4
# 1090       2022_2         22.385944                         60.0

# %%
showExcessVsHumidity('Virginia')
# Out:
# Virginia
#
# mean humidity: 72.2
# median humidity: 72.5
# stdev humidity: 4.4
# mean hist avg humidity: 67.2
#      MonthAndYear  ExcessPctCurrent  RelativeHumidity2MonthsPrev
# 11         2020_5         12.834672                         74.7
# 62         2020_6          5.770584                         68.2
# 113        2020_7         10.716144                         77.2
# 164        2020_8         13.620509                         76.2
# 215        2020_9         12.531061                         71.7
# 266       2020_10         11.133501                         71.9
# 317       2020_11         15.112757                         74.6
# 368       2020_12         27.824726                         72.1
# 419        2021_1         36.659600                         73.3
# 470        2021_2         19.850125                         69.7
# 521        2021_3          4.394591                         73.0
# 572        2021_4          5.115132                         69.5
# 623        2021_5          5.690252                         79.3
# 674        2021_6          3.918468                         75.8
# 725        2021_7          7.835371                         69.5
# 776        2021_8         20.712810                         67.1
# 827        2021_9         29.077890                         65.9
# 878       2021_10         26.057724                         75.2
# 929       2021_11         17.420408                         77.7
# 980       2021_12         20.067557                         71.7
# 1031       2022_1         39.701715                         60.4
# 1082       2022_2         18.502568                         74.3

# %% [markdown]
# ## Negative Binomial Regression

# %%
outcome='ExcessDeathCountCurrent'

predictors=['RelativeHumidity2MonthsPrev',
            'Stringency2MonthsPrev',
            'MaskMandates2MonthsPrev',
            'MobilityReduction2MonthsPrev',
            'CumulCasesPer330Mill3MonthsPrev',
            'DeviationFrom68Fahrenheit2MonthsPrev',
            'CovidDeathsPer330Mill2MonthsPrev',
            'FahrenheitTemperature2MonthsPrev',
            'BoostedRate2MonthsPrev',
            'VaxRate2MonthsPrev']

predictorsUsingMobilityResidual=[p.replace('MobilityReduction','MobilityResidual') for p in predictors]

predictorsStandardized=[p + '_stdized' for p in predictors]

modelString=outcome + '~' + "+".join(predictors)

modelStringStdized=outcome + '~' + "+".join(predictorsStandardized)


includeTimeFixedParams=True

timeDummyModelString=''

timeFixedParamPredictors=[]

# %% [markdown]
# When using dummy variables for a particular month, the dummy variable for one of the months is redundant, since that month is implied by all other month dummy variables taking a value of 0. The same logic applies for dummy variables for states. Here we arbitrarily choose May 2020 and Kansas to be removed from the dummy variable coding. One single month and and single state can be chosen without changing the regression results (this can be verified by rerunning the code if desired).

# %%
ARBITRARY_MONTH='2020_5'

modelStringPreFixedEffects=modelString

if (includeTimeFixedParams):
    for col in panelDF.columns:
        if (col.find('isMonthAndYear') != -1):
            if (col.find(ARBITRARY_MONTH)==-1):
                modelString=modelString + '+' + col
                timeFixedParamPredictors.append(col)
                #timeDummyModelString=timeDummyModelString + '+' + col

                
includeStateFixedParams=True

stateFixedParamPredictors=[]
stateDummyModelString=''

ARBITRARY_STATE='Kansas'

if (includeStateFixedParams):
    for col in panelDF.columns:
        if (col.find('isState') != -1):
            if (col.find(ARBITRARY_STATE)==-1):
                modelString=modelString + '+' + col
                stateFixedParamPredictors.append(col)
                #stateDummyModelString=stateDummyModelString + '+' + col
modelString=modelString.replace(outcome + '+',outcome)

fixedParamPredictors=stateFixedParamPredictors + timeFixedParamPredictors

# %% [markdown]
# Summary statistics for RH, controls and outcomes are presented here.

# %%
summaryStatsDct=dict()

variables=predictors + ['ExcessPctCurrent','CovidDeathsPer330MillCurrent']

summaryStatsDct['Variable']=variables
summaryStatsDct['Mean']=numpy.array([panelDF[var].mean() for var in variables])
summaryStatsDct['Std']=numpy.array([panelDF[var].std() for var in variables])
summaryStatsDct['Max']=numpy.array([panelDF[var].max() for var in variables])
summaryStatsDct['Min']=numpy.array([panelDF[var].min() for var in variables])

summaryStatsDF=pd.DataFrame(summaryStatsDct)

print(summaryStatsDF)
# Out:
#                                 Variable          Mean           Std  \
# 0            RelativeHumidity2MonthsPrev  6.757602e+01  1.448762e+01
# 1                  Stringency2MonthsPrev  5.053789e+01  1.527324e+01
# 2                MaskMandates2MonthsPrev  4.087666e-01  4.796146e-01
# 3           MobilityReduction2MonthsPrev  8.517402e+00  1.205405e+01
# 4        CumulCasesPer330Mill3MonthsPrev  2.074645e+07  1.753852e+07
# 5   DeviationFrom68Fahrenheit2MonthsPrev  1.505080e+01  1.186065e+01
# 6       CovidDeathsPer330Mill2MonthsPrev  3.494281e+04  3.616324e+04
# 7       FahrenheitTemperature2MonthsPrev  5.936934e+01  1.711283e+01
# 8                 BoostedRate2MonthsPrev  2.229487e+00  7.038534e+00
# 9                     VaxRate2MonthsPrev  1.995024e+01  2.448068e+01
# 10                      ExcessPctCurrent  1.772583e+01  1.554740e+01
# 11          CovidDeathsPer330MillCurrent  3.830351e+04  3.388057e+04
#
#              Max        Min
# 0   9.110000e+01  14.400000
# 1   9.283258e+01  23.088750
# 2   1.000000e+00   0.000000
# 3   5.900833e+01 -28.013244
# 4   6.906191e+07   0.000000
# 5   6.030000e+01   0.000000
# 6   3.580483e+05   0.000000
# 7   9.600000e+01   7.700000
# 8   4.309677e+01   0.000000
# 9   7.566129e+01   0.000000
# 10  1.047820e+02   0.000000
# 11  2.016235e+05   0.000000

# %%
import rpy2.robjects as robjects

type(panelDF)

from rpy2.robjects import vectors
from rpy2.robjects import pandas2ri
pandas2ri.activate()


panelDF_R = pandas2ri.py2ri(panelDF)
# Out:
# C:\Users\joe_s\Anaconda3\envs\renv\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# C:\Users\joe_s\Anaconda3\envs\renv\lib\site-packages\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "MonthAndYearObj". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'datetime.date'>'
#   (name, str(e)))

# %% [markdown]
# Negative binomial regression is set up to predict counts but can be adapted to predict rates via the use of an offset. An offset is an independent variable whose coefficient is fixed at 1.  ExcessDeathPct = ExcessDeathCountCurrent/ExpectedDeathCountCurrent.  Therefore log(ExcessDeathPct)= log(ExcessDeathCountCurrent/ExpectedDeathCountCurrent)=log(ExcessDeathCountCurrent) - log(ExpectedDeathCountCurrent). If we think in terms of a regression model with log(ExcessDeathPct) ~ RH+ controls, equivalently, log(ExpectedDeathCountCurrent) can be moved to the right hand side and used as an independent variable with coefficient fixed at 1, with the regression now using log(ExcessDeathCountCurrent) as the dependent variable.

# %%
addOffset=True

modelStringExcessPct=modelString + "+offset(log(ExpectedDeathCountCurrent))"
    
modelStringCovidDeathRate=modelStringExcessPct.replace('ExcessDeathCountCurrent','CovidDeathCountCurrent')
modelStringCovidDeathRate=modelStringCovidDeathRate.replace("+offset(log(ExpectedDeathCountCurrent))","+offset(log(StatePopulation))")
 

def stdize(mString):
    for pred in predictors:
        mString=mString.replace(pred,pred + '_stdized')
    return mString

modelStringExcessPctStdized=stdize(modelStringExcessPct)

modelStringCovidDeathRateStdized=stdize(modelString)

def runNegBinModel(mString,dFrame,stdErrs='clustered',popWeighted=False):
    if (popWeighted):
        negBinRes=MASS.glm_nb(mString,data=pandas2ri.py2ri(dFrame),weights=panelDF['StatePopulation'])
    else:
        negBinRes=MASS.glm_nb(mString,data=pandas2ri.py2ri(dFrame))

    #stdErrs='clustered'
    if (stdErrs=='standard'):
        negBinCoefTest=lmtest.coeftest(negBinRes)
    elif (stdErrs=='HC3'):
        negBinCoefTest=lmtest.coeftest(negBinRes,vcov=sandwich.vcovHC(negBinRes,type="HC3"))
    elif (stdErrs=='clustered'):
        negBinCoefTest=lmtest.coeftest(negBinRes,vcov=sandwich.vcovCL(negBinRes,cluster=dFrame["State"].values))
    return negBinCoefTest,negBinRes

# %%
negBinModelExcessPctCoef,result=runNegBinModel(modelStringExcessPct,panelDF)

# %% [markdown]
# Before we examine the model coefficients, let's confirm that we understand the mechanics of the model by reproducing the fitted values. Here are first 10 fitted values:

# %%
print(result.rx('fitted.values')[0][0:10])
# Out:
#  [1]  526.0368  693.8450 1371.7831  309.5024  278.1425  618.9945  580.5766
#
#  [8]  295.8420 1375.1865  816.4813

# %% [markdown]
# The model prediction should be a product of the exponential of the coefficient times the corresponding variable, for all such variables and the intercept.

# %%
def predict(resultCoef,i,offsetName='ExpectedDeathCountCurrent'):
    def getCoef(coefName):
        #print(coefName)
        #print(coef.names)
        #print(coef[coef.names.index('Stringency2MonthsPrev')])
        return resultCoef[resultCoef.names.index(coefName)]
    product=numpy.exp(getCoef('(Intercept)'))*panelDF[offsetName].values[i]
    
    allPredictors=predictors + fixedParamPredictors
    for pred in allPredictors:
        product=product*numpy.exp(getCoef(pred)*panelDF[pred].values[i])
    return product

recreatedPredictions=numpy.array([predict(result.rx('coefficients')[0],i) for i in range(panelDF.shape[0])])
print(recreatedPredictions[0:10])
# Out:
# [ 526.03676924  693.84498313 1371.78311365  309.50242349  278.14248776
#   618.99454642  580.57664782  295.84196561 1375.18652677  816.48128074]

# %% [markdown]
# Here are the results of the primary regression model presented in the paper (excess death pct vs. RH with various controls).

# %%
print(negBinModelExcessPctCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           1.6328e+00  7.4879e-01   2.1806 0.0292116
#
# RelativeHumidity2MonthsPrev          -2.0277e-02  3.6721e-03  -5.5220 3.352e-08
#
# Stringency2MonthsPrev                -6.4668e-03  5.9467e-03  -1.0875 0.2768287
#
# MaskMandates2MonthsPrev              -3.4664e-01  8.4047e-02  -4.1243 3.719e-05
#
# MobilityReduction2MonthsPrev         -2.5115e-02  1.0434e-02  -2.4070 0.0160825
#
# CumulCasesPer330Mill3MonthsPrev      -7.3440e-08  8.4625e-09  -8.6782 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev -3.7244e-03  5.4809e-03  -0.6795 0.4968128
#
# CovidDeathsPer330Mill2MonthsPrev     -3.5624e-06  8.2573e-07  -4.3143 1.601e-05
#
# FahrenheitTemperature2MonthsPrev     -3.0247e-02  6.1942e-03  -4.8831 1.045e-06
#
# BoostedRate2MonthsPrev               -1.2744e-02  9.7319e-03  -1.3095 0.1903566
#
# VaxRate2MonthsPrev                   -4.5283e-02  7.9070e-03  -5.7270 1.022e-08
#
# isMonthAndYear_2020_10                1.1643e+00  1.7468e-01   6.6656 2.636e-11
#
# isMonthAndYear_2020_11                1.7155e+00  1.4413e-01  11.9026 < 2.2e-16
#
# isMonthAndYear_2020_12                1.9361e+00  1.2909e-01  14.9982 < 2.2e-16
#
# isMonthAndYear_2020_6                 1.6995e-01  2.4365e-01   0.6975 0.4854749
#
# isMonthAndYear_2020_7                 4.1824e-01  2.1298e-01   1.9637 0.0495606
#
# isMonthAndYear_2020_8                 6.3890e-01  1.8032e-01   3.5431 0.0003955
#
# isMonthAndYear_2020_9                 8.6117e-01  1.8366e-01   4.6888 2.748e-06
#
# isMonthAndYear_2021_1                 1.7600e+00  1.5923e-01  11.0534 < 2.2e-16
#
# isMonthAndYear_2021_10                5.7074e+00  5.9042e-01   9.6666 < 2.2e-16
#
# isMonthAndYear_2021_11                5.8865e+00  6.2283e-01   9.4512 < 2.2e-16
#
# isMonthAndYear_2021_12                6.3137e+00  6.7947e-01   9.2921 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.0216e+00  2.3388e-01   4.3683 1.252e-05
#
# isMonthAndYear_2021_3                 3.5872e-01  2.8411e-01   1.2626 0.2067290
#
# isMonthAndYear_2021_4                 8.2966e-01  3.1329e-01   2.6483 0.0080909
#
# isMonthAndYear_2021_5                 1.6548e+00  3.3368e-01   4.9592 7.078e-07
#
# isMonthAndYear_2021_6                 2.4853e+00  4.1378e-01   6.0064 1.897e-09
#
# isMonthAndYear_2021_7                 3.4911e+00  4.9242e-01   7.0895 1.346e-12
#
# isMonthAndYear_2021_8                 4.9888e+00  5.3543e-01   9.3173 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.6559e+00  5.6060e-01  10.0890 < 2.2e-16
#
# isMonthAndYear_2022_1                 6.8410e+00  7.3044e-01   9.3655 < 2.2e-16
#
# isMonthAndYear_2022_2                 6.7674e+00  7.6586e-01   8.8363 < 2.2e-16
#
# isState_Alabama                       8.3280e-01  8.1885e-02  10.1703 < 2.2e-16
#
# isState_Alaska                       -7.9520e-02  1.9759e-01  -0.4025 0.6873461
#
# isState_Arizona                       5.4540e-01  1.3395e-01   4.0716 4.669e-05
#
# isState_Arkansas                      7.5933e-01  4.7931e-02  15.8420 < 2.2e-16
#
# isState_California                    4.7400e-01  1.6618e-01   2.8523 0.0043403
#
# isState_Colorado                     -2.5381e-01  9.7047e-02  -2.6154 0.0089130
#
# isState_Connecticut                  -3.4182e-01  1.1631e-01  -2.9388 0.0032946
#
# isState_Delaware                      2.3138e-01  9.1476e-02   2.5294 0.0114249
#
# isState_District_of_Columbia          4.3117e-01  4.1214e-01   1.0462 0.2954811
#
# isState_Florida                       1.0035e+00  1.6353e-01   6.1360 8.460e-10
#
# isState_Georgia                       5.9801e-01  7.0248e-02   8.5129 < 2.2e-16
#
# isState_Hawaii                       -6.5277e-01  3.9502e-01  -1.6525 0.0984369
#
# isState_Idaho                        -8.9069e-01  1.4080e-01  -6.3259 2.518e-10
#
# isState_Illinois                      2.1108e-01  4.8449e-02   4.3568 1.320e-05
#
# isState_Indiana                      -4.6871e-02  3.2101e-02  -1.4601 0.1442656
#
# isState_Iowa                         -2.6966e-01  6.2617e-02  -4.3065 1.658e-05
#
# isState_Kentucky                      5.4464e-01  6.3638e-02   8.5584 < 2.2e-16
#
# isState_Louisiana                     1.1713e+00  1.4822e-01   7.9022 2.740e-15
#
# isState_Maine                        -1.1856e+00  1.2580e-01  -9.4248 < 2.2e-16
#
# isState_Maryland                     -1.0465e-01  1.3508e-01  -0.7747 0.4384974
#
# isState_Massachusetts                -7.0164e-01  1.6906e-01  -4.1502 3.322e-05
#
# isState_Michigan                     -1.2295e-03  5.4746e-02  -0.0225 0.9820824
#
# isState_Minnesota                    -2.7820e-01  6.5054e-02  -4.2765 1.899e-05
#
# isState_Mississippi                   1.1445e+00  8.7743e-02  13.0436 < 2.2e-16
#
# isState_Missouri                     -3.2786e-01  6.1939e-02  -5.2933 1.201e-07
#
# isState_Montana                      -4.0771e-01  1.6146e-01  -2.5252 0.0115648
#
# isState_Nebraska                     -5.3666e-01  8.2804e-02  -6.4811 9.107e-11
#
# isState_Nevada                       -4.3440e-02  1.1871e-01  -0.3659 0.7144153
#
# isState_New_Hampshire                -1.5300e+00  8.9605e-02 -17.0744 < 2.2e-16
#
# isState_New_Jersey                   -1.9201e-01  1.3168e-01  -1.4581 0.1448000
#
# isState_New_Mexico                    5.1414e-01  1.0950e-01   4.6953 2.662e-06
#
# isState_New_York                      2.8141e-01  1.3907e-01   2.0235 0.0430212
#
# isState_North_Carolina                3.0397e-01  8.3813e-02   3.6268 0.0002869
#
# isState_North_Dakota                  1.4575e-02  1.1686e-01   0.1247 0.9007399
#
# isState_Ohio                         -5.2706e-01  5.0796e-02 -10.3759 < 2.2e-16
#
# isState_Oklahoma                      1.8589e-01  4.8272e-02   3.8510 0.0001177
#
# isState_Oregon                       -4.1797e-01  9.7066e-02  -4.3060 1.662e-05
#
# isState_Pennsylvania                 -4.8406e-01  5.8965e-02  -8.2093 2.226e-16
#
# isState_Rhode_Island                  5.9697e-01  1.7229e-01   3.4650 0.0005303
#
# isState_South_Carolina                6.8286e-01  5.5690e-02  12.2619 < 2.2e-16
#
# isState_South_Dakota                 -7.5270e-02  1.5447e-01  -0.4873 0.6260658
#
# isState_Tennessee                     5.9912e-01  4.4575e-02  13.4409 < 2.2e-16
#
# isState_Texas                         9.7024e-01  9.5732e-02  10.1349 < 2.2e-16
#
# isState_Utah                         -3.0868e-01  1.2673e-01  -2.4357 0.0148636
#
# isState_Vermont                      -4.4207e-01  1.8026e-01  -2.4525 0.0141886
#
# isState_Virginia                      1.3389e-01  9.7635e-02   1.3713 0.1702893
#
# isState_Washington                   -6.1014e-01  1.0609e-01  -5.7513 8.858e-09
#
# isState_West_Virginia                 1.1805e-01  6.0529e-02   1.9502 0.0511509
#
# isState_Wisconsin                    -1.9779e-01  5.2283e-02  -3.7830 0.0001549
#
# isState_Wyoming                      -2.7649e-01  1.5425e-01  -1.7925 0.0730507
#
#
#
# (Intercept)                          *
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev         *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                *
#
# isMonthAndYear_2020_8                ***
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   **
#
# isState_Colorado                     **
#
# isState_Connecticut                  **
#
# isState_Delaware                     *
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       .
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                ***
#
# isState_Michigan
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      *
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York                     *
#
# isState_North_Carolina               ***
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         *
#
# isState_Vermont                      *
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia                .
#
# isState_Wisconsin                    ***
#
# isState_Wyoming                      .
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# We need to write some code to look at 95% CIs for the coefficients themselves and also for the multiplicative association with excess percentage itself rather than the log itself.

# %%
def getVal(coefTest,coefName,j):
    lst=str(coefTest).split('z test of coefficients')[1].split(coefName)[1].split('\n')[0].split(' ')
    nonEmpty=[]
    for l in lst:
        if (l.strip() != ''):
            nonEmpty.append(l.strip())
    return float(nonEmpty[j])

def getEstimate(coefTest,coefName):
    return getVal(coefTest,coefName,0)

def getStdError(coefTest,coefName):
    return getVal(coefTest,coefName,1)

def showMultiplicativeAssociationAndCI(coefTest,coef,delta=-1,stdev=True,unitStrDict=dict()):
    #print('coef',coef)
    est=getEstimate(coefTest,coef)
    stdErr=getStdError(coefTest,coef)
    multEst=numpy.exp(est*delta)
    if (est > 0):
        multCILow=numpy.exp((est+ 1.96*stdErr)*delta)
        multCIHigh=numpy.exp((est - 1.96*stdErr)*delta)
        ciLow=est -1.96*stdErr
        ciHigh=est + 1.96*stdErr
    else:
        multCILow=numpy.exp((est - 1.96*stdErr)*delta)
        multCIHigh=numpy.exp((est + 1.96*stdErr)*delta) 
        ciLow=est + 1.96*stdErr
        ciHigh=est - 1.96*stdErr
    unitStr=unitStrDict.get(coef,'')
    if (stdev):
        unitStr='stdev'
    print('multiplicative estimate: %4.4f [%4.4f, %4.4f] per %d %s'%(multEst,multCILow,multCIHigh,delta,unitStr))
    #print('log-linear estimate: %9.9f [%9.9f, %9.9f] per 1 %s'%(est,ciLow,ciHigh,unitStr))
    print('log-linear estimate: ' +  "{:e}".format(est) + " [{:e},".format(ciLow) + " {:e}]".format(ciHigh) + " per 1 %s'"%(unitStr))

deltas={"RelativeHumidity2MonthsPrev":10,
        "HistoricalAvgHumidity2MonthsPrev":10,
        "Stringency2MonthsPrev":10,
       "MobilityReduction2MonthsPrev":10,
       "CumulCasesPer330Mill3MonthsPrev":1e6,
       "VaxRate2MonthsPrev":10,
       "BoostedRate2MonthsPrev":10,
       "FahrenheitTemperature2MonthsPrev":10,
        'DeviationFrom68Fahrenheit2MonthsPrev':10,
       "CovidDeathsPer330Mill2MonthsPrev":1e4}


unitStrDct={"RelativeHumidity2MonthsPrev":'RH percent',
            "HistoricalAvgHumidity2MonthsPrev":"RH percent",
        "Stringency2MonthsPrev":'Oxford Stringency Index units',
       "MobilityReduction2MonthsPrev":'Mobility reduction percent',
       "CumulCasesPer330Mill3MonthsPrev":'cumulative cases per 330 million people',
       "VaxRate2MonthsPrev":'vaccination rate percent',
       "BoostedRate2MonthsPrev":'boosted rate percent',
       "FahrenheitTemperature2MonthsPrev":'degree Fahrenheit',
        'DeviationFrom68Fahrenheit2MonthsPrev':'degrees Fahrenheit abs difference from 68F (room temp)',
       "CovidDeathsPer330Mill2MonthsPrev":'covid death 2 months previous'}

# %%
for p in predictors:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelExcessPctCoef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.8165 [0.7598, 0.8774] per 10 RH percent
# log-linear estimate: -2.027700e-02 [-1.307968e-02, -2.747432e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9374 [0.8342, 1.0533] per 10 Oxford Stringency Index units
# log-linear estimate: -6.466800e-03 [5.188732e-03, -1.812233e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.7071 [0.5997, 0.8337] per 1
# log-linear estimate: -3.466400e-01 [-1.819079e-01, -5.113721e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7779 [0.6340, 0.9544] per 10 Mobility reduction percent
# log-linear estimate: -2.511500e-02 [-4.664360e-03, -4.556564e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9292 [0.9139, 0.9447] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -7.344000e-08 [-5.685350e-08, -9.002650e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9634 [0.8653, 1.0727] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -3.724400e-03 [7.018164e-03, -1.446696e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9650 [0.9495, 0.9807] per 10000 covid death 2 months previous
# log-linear estimate: -3.562400e-06 [-1.943969e-06, -5.180831e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.7390 [0.6545, 0.8344] per 10 degree Fahrenheit
# log-linear estimate: -3.024700e-02 [-1.810637e-02, -4.238763e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.8803 [0.7275, 1.0654] per 10 boosted rate percent
# log-linear estimate: -1.274400e-02 [6.330524e-03, -3.181852e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.6358 [0.5445, 0.7424] per 10 vaccination rate percent
# log-linear estimate: -4.528300e-02 [-2.978528e-02, -6.078072e-02] per 1 vaccination rate percent'

# %% [markdown]
# Results are similar when using covid death rates rather than all-cause excess death rates.

# %%
negBinModelCovidDeathRateCoef,_=runNegBinModel(modelStringCovidDeathRate,panelDF)
print(negBinModelCovidDeathRateCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                          -5.4391e+00  4.6231e-01 -11.7652 < 2.2e-16
#
# RelativeHumidity2MonthsPrev          -2.0011e-02  2.6808e-03  -7.4647 8.347e-14
#
# Stringency2MonthsPrev                -7.2301e-03  4.1668e-03  -1.7352 0.0827141
#
# MaskMandates2MonthsPrev              -2.7194e-01  7.9006e-02  -3.4420 0.0005774
#
# MobilityReduction2MonthsPrev         -2.8668e-02  1.0208e-02  -2.8083 0.0049803
#
# CumulCasesPer330Mill3MonthsPrev      -6.5257e-08  7.0680e-09  -9.2328 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev  7.2520e-03  4.0286e-03   1.8001 0.0718407
#
# CovidDeathsPer330Mill2MonthsPrev      1.4091e-06  8.7643e-07   1.6078 0.1078894
#
# FahrenheitTemperature2MonthsPrev     -3.7826e-02  5.7367e-03  -6.5937 4.291e-11
#
# BoostedRate2MonthsPrev               -6.8010e-03  7.3101e-03  -0.9304 0.3521878
#
# VaxRate2MonthsPrev                   -4.8872e-02  6.3941e-03  -7.6434 2.116e-14
#
# isMonthAndYear_2020_10                1.2100e+00  1.9758e-01   6.1239 9.131e-10
#
# isMonthAndYear_2020_11                1.6656e+00  1.5510e-01  10.7389 < 2.2e-16
#
# isMonthAndYear_2020_12                2.0302e+00  1.3020e-01  15.5930 < 2.2e-16
#
# isMonthAndYear_2020_6                 2.4566e-01  2.4045e-01   1.0217 0.3069418
#
# isMonthAndYear_2020_7                 3.7583e-01  2.1059e-01   1.7846 0.0743195
#
# isMonthAndYear_2020_8                 5.9142e-01  1.8610e-01   3.1780 0.0014829
#
# isMonthAndYear_2020_9                 8.1150e-01  2.0216e-01   4.0140 5.969e-05
#
# isMonthAndYear_2021_1                 1.8972e+00  1.6007e-01  11.8523 < 2.2e-16
#
# isMonthAndYear_2021_10                5.5986e+00  4.1646e-01  13.4431 < 2.2e-16
#
# isMonthAndYear_2021_11                5.6697e+00  4.3731e-01  12.9649 < 2.2e-16
#
# isMonthAndYear_2021_12                5.9498e+00  4.5910e-01  12.9597 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.1511e+00  2.3166e-01   4.9689 6.732e-07
#
# isMonthAndYear_2021_3                 1.0838e+00  2.4671e-01   4.3931 1.118e-05
#
# isMonthAndYear_2021_4                 9.2776e-01  2.7874e-01   3.3284 0.0008735
#
# isMonthAndYear_2021_5                 1.7096e+00  2.5101e-01   6.8110 9.695e-12
#
# isMonthAndYear_2021_6                 2.1185e+00  3.0045e-01   7.0512 1.774e-12
#
# isMonthAndYear_2021_7                 2.8670e+00  3.4993e-01   8.1930 2.548e-16
#
# isMonthAndYear_2021_8                 4.4896e+00  3.9598e-01  11.3378 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.5063e+00  4.0260e-01  13.6769 < 2.2e-16
#
# isMonthAndYear_2022_1                 6.1935e+00  5.2381e-01  11.8239 < 2.2e-16
#
# isMonthAndYear_2022_2                 6.5220e+00  5.9886e-01  10.8907 < 2.2e-16
#
# isState_Alabama                       7.4319e-01  7.5469e-02   9.8476 < 2.2e-16
#
# isState_Alaska                       -1.8448e+00  1.6214e-01 -11.3778 < 2.2e-16
#
# isState_Arizona                       4.0391e-01  1.2081e-01   3.3435 0.0008274
#
# isState_Arkansas                      6.6162e-01  4.6953e-02  14.0911 < 2.2e-16
#
# isState_California                    3.4447e-01  1.6804e-01   2.0499 0.0403697
#
# isState_Colorado                     -7.5068e-01  1.2027e-01  -6.2416 4.332e-10
#
# isState_Connecticut                   3.6727e-02  1.1511e-01   0.3191 0.7496863
#
# isState_Delaware                      4.0145e-01  7.5152e-02   5.3419 9.197e-08
#
# isState_District_of_Columbia          5.8635e-01  4.0847e-01   1.4355 0.1511493
#
# isState_Florida                       1.3470e+00  1.4324e-01   9.4034 < 2.2e-16
#
# isState_Georgia                       4.6050e-01  6.2300e-02   7.3917 1.450e-13
#
# isState_Hawaii                       -3.5162e-01  3.5980e-01  -0.9772 0.3284461
#
# isState_Idaho                        -1.0802e+00  9.9071e-02 -10.9030 < 2.2e-16
#
# isState_Illinois                      1.9628e-01  4.7869e-02   4.1004 4.124e-05
#
# isState_Indiana                       1.1020e-01  2.8686e-02   3.8415 0.0001223
#
# isState_Iowa                         -8.3097e-02  5.4967e-02  -1.5118 0.1305949
#
# isState_Kentucky                      4.6116e-01  3.5734e-02  12.9055 < 2.2e-16
#
# isState_Louisiana                     1.1500e+00  9.2657e-02  12.4116 < 2.2e-16
#
# isState_Maine                        -1.4672e+00  1.1418e-01 -12.8504 < 2.2e-16
#
# isState_Maryland                      5.0615e-02  1.4029e-01   0.3608 0.7182610
#
# isState_Massachusetts                 4.7076e-01  1.6587e-01   2.8382 0.0045370
#
# isState_Michigan                     -1.8046e-01  5.0045e-02  -3.6059 0.0003111
#
# isState_Minnesota                    -3.0664e-01  8.1594e-02  -3.7581 0.0001712
#
# isState_Mississippi                   8.7191e-01  7.6809e-02  11.3518 < 2.2e-16
#
# isState_Missouri                     -2.1360e-01  5.0258e-02  -4.2501 2.136e-05
#
# isState_Montana                      -9.0252e-01  1.2144e-01  -7.4317 1.072e-13
#
# isState_Nebraska                     -7.0197e-01  6.7486e-02 -10.4018 < 2.2e-16
#
# isState_Nevada                       -9.7693e-02  8.4387e-02  -1.1577 0.2469940
#
# isState_New_Hampshire                -9.9134e-01  9.0601e-02 -10.9419 < 2.2e-16
#
# isState_New_Jersey                    4.9227e-01  1.2798e-01   3.8465 0.0001198
#
# isState_New_Mexico                    4.4736e-02  1.1534e-01   0.3879 0.6981143
#
# isState_New_York                      1.3602e-01  1.1863e-01   1.1466 0.2515437
#
# isState_North_Carolina                1.1224e-01  6.1445e-02   1.8267 0.0677422
#
# isState_North_Dakota                 -1.2576e-01  1.0499e-01  -1.1979 0.2309701
#
# isState_Ohio                         -1.7536e-01  3.5065e-02  -5.0010 5.702e-07
#
# isState_Oklahoma                      6.8855e-02  5.2968e-02   1.2999 0.1936231
#
# isState_Oregon                       -1.0904e+00  1.0376e-01 -10.5094 < 2.2e-16
#
# isState_Pennsylvania                  4.8997e-02  6.1749e-02   0.7935 0.4274938
#
# isState_Rhode_Island                  8.6144e-01  1.4590e-01   5.9043 3.542e-09
#
# isState_South_Carolina                5.5237e-01  5.6425e-02   9.7893 < 2.2e-16
#
# isState_South_Dakota                 -3.7895e-01  1.2452e-01  -3.0433 0.0023399
#
# isState_Tennessee                     4.2724e-01  5.5198e-02   7.7402 9.929e-15
#
# isState_Texas                         5.2793e-01  8.8550e-02   5.9620 2.492e-09
#
# isState_Utah                         -9.4434e-01  9.2891e-02 -10.1662 < 2.2e-16
#
# isState_Vermont                      -1.8034e+00  1.9875e-01  -9.0741 < 2.2e-16
#
# isState_Virginia                     -1.5583e-02  1.0073e-01  -0.1547 0.8770610
#
# isState_Washington                   -8.2674e-01  1.1513e-01  -7.1807 6.937e-13
#
# isState_West_Virginia                -2.7055e-02  4.6101e-02  -0.5869 0.5572882
#
# isState_Wisconsin                    -9.3040e-02  5.6618e-02  -1.6433 0.1003232
#
# isState_Wyoming                      -1.0737e+00  1.1899e-01  -9.0235 < 2.2e-16
#
#
#
# (Intercept)                          ***
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev                .
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev         **
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev .
#
# CovidDeathsPer330Mill2MonthsPrev
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                .
#
# isMonthAndYear_2020_8                **
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3                ***
#
# isMonthAndYear_2021_4                ***
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska                       ***
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   *
#
# isState_Colorado                     ***
#
# isState_Connecticut
#
# isState_Delaware                     ***
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana                      ***
#
# isState_Iowa
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                **
#
# isState_Michigan                     ***
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      ***
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey                   ***
#
# isState_New_Mexico
#
# isState_New_York
#
# isState_North_Carolina               .
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma
#
# isState_Oregon                       ***
#
# isState_Pennsylvania
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota                 **
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         ***
#
# isState_Vermont                      ***
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia
#
# isState_Wisconsin
#
# isState_Wyoming                      ***
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
for p in predictors:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelCovidDeathRateCoef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.8186 [0.7767, 0.8628] per 10 RH percent
# log-linear estimate: -2.001100e-02 [-1.475663e-02, -2.526537e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9303 [0.8573, 1.0094] per 10 Oxford Stringency Index units
# log-linear estimate: -7.230100e-03 [9.368280e-04, -1.539703e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.7619 [0.6526, 0.8895] per 1
# log-linear estimate: -2.719400e-01 [-1.170882e-01, -4.267918e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7508 [0.6146, 0.9170] per 10 Mobility reduction percent
# log-linear estimate: -2.866800e-02 [-8.660320e-03, -4.867568e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9368 [0.9239, 0.9499] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -6.525700e-08 [-5.140372e-08, -7.911028e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 1.0752 [1.1636, 0.9936] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: 7.252000e-03 [-6.440560e-04, 1.514806e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 1.0142 [1.0318, 0.9969] per 10000 covid death 2 months previous
# log-linear estimate: 1.409100e-06 [-3.087028e-07, 3.126903e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.6851 [0.6122, 0.7666] per 10 degree Fahrenheit
# log-linear estimate: -3.782600e-02 [-2.658207e-02, -4.906993e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.9343 [0.8095, 1.0782] per 10 boosted rate percent
# log-linear estimate: -6.801000e-03 [7.526796e-03, -2.112880e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.6134 [0.5412, 0.6953] per 10 vaccination rate percent
# log-linear estimate: -4.887200e-02 [-3.633956e-02, -6.140444e-02] per 1 vaccination rate percent'

# %% [markdown]
# Results are similar if the long-term historical average monthly RH for each state, obtained from ncei.noaa.gov, is used. While it may seem surprising that the coefficient is slightly larger when using historical average is used rather than actual RH over the course of the pandemic is used, note that the confidence interval is significantly wider when using the historical average.

# %%
negBinModelUsingHistoricalAvgHumidityCoef,_=runNegBinModel(modelStringExcessPct.replace('RelativeHumidity','HistoricalAvgRelativeHumidity'),panelDF)
print(negBinModelUsingHistoricalAvgHumidityCoef)
# Out:
# z test of coefficients:
#
#
#
#                                             Estimate  Std. Error  z value
#
# (Intercept)                               9.7247e-01  7.5794e-01   1.2830
#
# HistoricalAvgRelativeHumidity2MonthsPrev -2.1462e-02  5.1682e-03  -4.1526
#
# Stringency2MonthsPrev                    -3.9257e-03  5.9901e-03  -0.6554
#
# MaskMandates2MonthsPrev                  -3.8190e-01  8.4257e-02  -4.5326
#
# MobilityReduction2MonthsPrev             -2.5838e-02  1.0936e-02  -2.3627
#
# CumulCasesPer330Mill3MonthsPrev          -7.5451e-08  8.7180e-09  -8.6546
#
# DeviationFrom68Fahrenheit2MonthsPrev     -1.3716e-03  5.4235e-03  -0.2529
#
# CovidDeathsPer330Mill2MonthsPrev         -3.2235e-06  7.7242e-07  -4.1733
#
# FahrenheitTemperature2MonthsPrev         -2.0684e-02  6.0228e-03  -3.4343
#
# BoostedRate2MonthsPrev                   -6.7253e-03  1.0175e-02  -0.6609
#
# VaxRate2MonthsPrev                       -4.7441e-02  8.0473e-03  -5.8953
#
# isMonthAndYear_2020_10                    1.0368e+00  1.9905e-01   5.2085
#
# isMonthAndYear_2020_11                    1.7056e+00  1.5002e-01  11.3692
#
# isMonthAndYear_2020_12                    1.9677e+00  1.2905e-01  15.2482
#
# isMonthAndYear_2020_6                     7.1090e-02  2.4938e-01   0.2851
#
# isMonthAndYear_2020_7                     2.7170e-01  2.2059e-01   1.2317
#
# isMonthAndYear_2020_8                     4.3603e-01  2.1387e-01   2.0387
#
# isMonthAndYear_2020_9                     6.1727e-01  2.3045e-01   2.6785
#
# isMonthAndYear_2021_1                     1.9148e+00  1.5295e-01  12.5187
#
# isMonthAndYear_2021_10                    5.7793e+00  5.7491e-01  10.0525
#
# isMonthAndYear_2021_11                    6.0630e+00  6.1000e-01   9.9393
#
# isMonthAndYear_2021_12                    6.4784e+00  6.7024e-01   9.6658
#
# isMonthAndYear_2021_2                     1.2577e+00  2.1687e-01   5.7995
#
# isMonthAndYear_2021_3                     4.8966e-01  2.8289e-01   1.7309
#
# isMonthAndYear_2021_4                     8.9871e-01  3.1557e-01   2.8479
#
# isMonthAndYear_2021_5                     1.6801e+00  3.3309e-01   5.0441
#
# isMonthAndYear_2021_6                     2.5191e+00  4.1480e-01   6.0729
#
# isMonthAndYear_2021_7                     3.5449e+00  4.8236e-01   7.3491
#
# isMonthAndYear_2021_8                     5.0283e+00  5.1861e-01   9.6958
#
# isMonthAndYear_2021_9                     5.6239e+00  5.4836e-01  10.2558
#
# isMonthAndYear_2022_1                     7.1829e+00  7.1620e-01  10.0292
#
# isMonthAndYear_2022_2                     6.9812e+00  7.6372e-01   9.1410
#
# isState_Alabama                           7.5837e-01  7.6843e-02   9.8690
#
# isState_Alaska                            1.3555e-02  1.9161e-01   0.0707
#
# isState_Arizona                           6.4057e-01  1.3259e-01   4.8311
#
# isState_Arkansas                          6.5923e-01  4.1045e-02  16.0610
#
# isState_California                        6.8175e-01  1.8637e-01   3.6581
#
# isState_Colorado                         -1.6567e-01  1.2793e-01  -1.2950
#
# isState_Connecticut                      -3.3752e-01  1.2115e-01  -2.7860
#
# isState_Delaware                          1.4412e-01  8.4969e-02   1.6962
#
# isState_District_of_Columbia              4.2034e-01  4.2479e-01   0.9895
#
# isState_Florida                           1.0023e+00  1.6247e-01   6.1695
#
# isState_Georgia                           5.7054e-01  6.7231e-02   8.4862
#
# isState_Hawaii                           -7.9852e-01  3.8382e-01  -2.0804
#
# isState_Idaho                            -7.9604e-01  1.3820e-01  -5.7603
#
# isState_Illinois                          2.7656e-01  5.0547e-02   5.4715
#
# isState_Indiana                          -9.2075e-02  2.8851e-02  -3.1915
#
# isState_Iowa                             -2.4397e-01  6.6569e-02  -3.6649
#
# isState_Kentucky                          4.2770e-01  4.2911e-02   9.9671
#
# isState_Louisiana                         1.0555e+00  1.3649e-01   7.7333
#
# isState_Maine                            -1.1836e+00  1.2469e-01  -9.4925
#
# isState_Maryland                         -1.8391e-01  1.2987e-01  -1.4161
#
# isState_Massachusetts                    -6.9335e-01  1.7821e-01  -3.8907
#
# isState_Michigan                          4.6809e-02  5.1802e-02   0.9036
#
# isState_Minnesota                        -1.3617e-01  7.1537e-02  -1.9035
#
# isState_Mississippi                       1.0040e+00  7.6617e-02  13.1046
#
# isState_Missouri                         -3.7167e-01  7.0647e-02  -5.2610
#
# isState_Montana                          -3.1121e-01  1.5842e-01  -1.9645
#
# isState_Nebraska                         -4.6855e-01  7.7655e-02  -6.0337
#
# isState_Nevada                            1.8685e-01  1.0454e-01   1.7874
#
# isState_New_Hampshire                    -1.5682e+00  8.7562e-02 -17.9092
#
# isState_New_Jersey                       -1.6318e-01  1.4128e-01  -1.1550
#
# isState_New_Mexico                        6.8018e-01  1.4029e-01   4.8484
#
# isState_New_York                          3.0355e-01  1.4538e-01   2.0879
#
# isState_North_Carolina                    2.4824e-01  7.6581e-02   3.2415
#
# isState_North_Dakota                      3.0372e-01  1.1311e-01   2.6852
#
# isState_Ohio                             -5.8284e-01  4.3626e-02 -13.3601
#
# isState_Oklahoma                          1.8251e-01  5.2989e-02   3.4443
#
# isState_Oregon                           -4.1682e-01  9.4395e-02  -4.4157
#
# isState_Pennsylvania                     -5.5833e-01  4.9211e-02 -11.3456
#
# isState_Rhode_Island                      5.5144e-01  1.8374e-01   3.0012
#
# isState_South_Carolina                    5.7855e-01  4.7751e-02  12.1161
#
# isState_South_Dakota                      1.3500e-01  1.3883e-01   0.9724
#
# isState_Tennessee                         4.9776e-01  4.1973e-02  11.8591
#
# isState_Texas                             9.5494e-01  9.3273e-02  10.2381
#
# isState_Utah                             -1.5656e-01  1.3135e-01  -1.1919
#
# isState_Vermont                          -5.8858e-01  1.7238e-01  -3.4144
#
# isState_Virginia                          6.5597e-02  8.9768e-02   0.7307
#
# isState_Washington                       -5.8624e-01  1.0593e-01  -5.5340
#
# isState_West_Virginia                     3.3243e-02  5.1422e-02   0.6465
#
# isState_Wisconsin                        -1.9124e-01  5.4530e-02  -3.5070
#
# isState_Wyoming                          -1.2541e-01  1.4759e-01  -0.8497
#
#                                           Pr(>|z|)
#
# (Intercept)                              0.1994771
#
# HistoricalAvgRelativeHumidity2MonthsPrev 3.287e-05 ***
#
# Stringency2MonthsPrev                    0.5122355
#
# MaskMandates2MonthsPrev                  5.826e-06 ***
#
# MobilityReduction2MonthsPrev             0.0181416 *
#
# CumulCasesPer330Mill3MonthsPrev          < 2.2e-16 ***
#
# DeviationFrom68Fahrenheit2MonthsPrev     0.8003423
#
# CovidDeathsPer330Mill2MonthsPrev         3.003e-05 ***
#
# FahrenheitTemperature2MonthsPrev         0.0005942 ***
#
# BoostedRate2MonthsPrev                   0.5086514
#
# VaxRate2MonthsPrev                       3.741e-09 ***
#
# isMonthAndYear_2020_10                   1.904e-07 ***
#
# isMonthAndYear_2020_11                   < 2.2e-16 ***
#
# isMonthAndYear_2020_12                   < 2.2e-16 ***
#
# isMonthAndYear_2020_6                    0.7755898
#
# isMonthAndYear_2020_7                    0.2180606
#
# isMonthAndYear_2020_8                    0.0414778 *
#
# isMonthAndYear_2020_9                    0.0073949 **
#
# isMonthAndYear_2021_1                    < 2.2e-16 ***
#
# isMonthAndYear_2021_10                   < 2.2e-16 ***
#
# isMonthAndYear_2021_11                   < 2.2e-16 ***
#
# isMonthAndYear_2021_12                   < 2.2e-16 ***
#
# isMonthAndYear_2021_2                    6.651e-09 ***
#
# isMonthAndYear_2021_3                    0.0834643 .
#
# isMonthAndYear_2021_4                    0.0044016 **
#
# isMonthAndYear_2021_5                    4.557e-07 ***
#
# isMonthAndYear_2021_6                    1.256e-09 ***
#
# isMonthAndYear_2021_7                    1.996e-13 ***
#
# isMonthAndYear_2021_8                    < 2.2e-16 ***
#
# isMonthAndYear_2021_9                    < 2.2e-16 ***
#
# isMonthAndYear_2022_1                    < 2.2e-16 ***
#
# isMonthAndYear_2022_2                    < 2.2e-16 ***
#
# isState_Alabama                          < 2.2e-16 ***
#
# isState_Alaska                           0.9436048
#
# isState_Arizona                          1.358e-06 ***
#
# isState_Arkansas                         < 2.2e-16 ***
#
# isState_California                       0.0002541 ***
#
# isState_Colorado                         0.1953281
#
# isState_Connecticut                      0.0053369 **
#
# isState_Delaware                         0.0898528 .
#
# isState_District_of_Columbia             0.3223997
#
# isState_Florida                          6.851e-10 ***
#
# isState_Georgia                          < 2.2e-16 ***
#
# isState_Hawaii                           0.0374854 *
#
# isState_Idaho                            8.399e-09 ***
#
# isState_Illinois                         4.463e-08 ***
#
# isState_Indiana                          0.0014156 **
#
# isState_Iowa                             0.0002475 ***
#
# isState_Kentucky                         < 2.2e-16 ***
#
# isState_Louisiana                        1.048e-14 ***
#
# isState_Maine                            < 2.2e-16 ***
#
# isState_Maryland                         0.1567367
#
# isState_Massachusetts                    9.996e-05 ***
#
# isState_Michigan                         0.3662059
#
# isState_Minnesota                        0.0569754 .
#
# isState_Mississippi                      < 2.2e-16 ***
#
# isState_Missouri                         1.433e-07 ***
#
# isState_Montana                          0.0494736 *
#
# isState_Nebraska                         1.603e-09 ***
#
# isState_Nevada                           0.0738761 .
#
# isState_New_Hampshire                    < 2.2e-16 ***
#
# isState_New_Jersey                       0.2480816
#
# isState_New_Mexico                       1.245e-06 ***
#
# isState_New_York                         0.0368041 *
#
# isState_North_Carolina                   0.0011889 **
#
# isState_North_Dakota                     0.0072476 **
#
# isState_Ohio                             < 2.2e-16 ***
#
# isState_Oklahoma                         0.0005725 ***
#
# isState_Oregon                           1.007e-05 ***
#
# isState_Pennsylvania                     < 2.2e-16 ***
#
# isState_Rhode_Island                     0.0026892 **
#
# isState_South_Carolina                   < 2.2e-16 ***
#
# isState_South_Dakota                     0.3308433
#
# isState_Tennessee                        < 2.2e-16 ***
#
# isState_Texas                            < 2.2e-16 ***
#
# isState_Utah                             0.2332927
#
# isState_Vermont                          0.0006392 ***
#
# isState_Virginia                         0.4649376
#
# isState_Washington                       3.131e-08 ***
#
# isState_West_Virginia                    0.5179777
#
# isState_Wisconsin                        0.0004532 ***
#
# isState_Wyoming                          0.3954996
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
for p in predictors:
    if (p=='RelativeHumidity2MonthsPrev'):
        pToUse="HistoricalAvgRelativeHumidity2MonthsPrev"
    else:
        pToUse=p
    print(pToUse)
    showMultiplicativeAssociationAndCI(negBinModelUsingHistoricalAvgHumidityCoef,pToUse,delta=deltas.get(pToUse,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# HistoricalAvgRelativeHumidity2MonthsPrev
# multiplicative estimate: 0.9788 [0.9689, 0.9887] per 1
# log-linear estimate: -2.146200e-02 [-1.133233e-02, -3.159167e-02] per 1 '
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9615 [0.8550, 1.0813] per 10 Oxford Stringency Index units
# log-linear estimate: -3.925700e-03 [7.814896e-03, -1.566630e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.6826 [0.5787, 0.8051] per 1
# log-linear estimate: -3.819000e-01 [-2.167563e-01, -5.470437e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7723 [0.6233, 0.9569] per 10 Mobility reduction percent
# log-linear estimate: -2.583800e-02 [-4.403440e-03, -4.727256e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9273 [0.9116, 0.9433] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -7.545100e-08 [-5.836372e-08, -9.253828e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9864 [0.8869, 1.0970] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -1.371600e-03 [9.258460e-03, -1.200166e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9683 [0.9537, 0.9830] per 10000 covid death 2 months previous
# log-linear estimate: -3.223500e-06 [-1.709557e-06, -4.737443e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.8131 [0.7226, 0.9150] per 10 degree Fahrenheit
# log-linear estimate: -2.068400e-02 [-8.879312e-03, -3.248869e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.9350 [0.7659, 1.1413] per 10 boosted rate percent
# log-linear estimate: -6.725300e-03 [1.321770e-02, -2.666830e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.6223 [0.5315, 0.7286] per 10 vaccination rate percent
# log-linear estimate: -4.744100e-02 [-3.166829e-02, -6.321371e-02] per 1 vaccination rate percent'

# %% [markdown]
# The RH coefficient is similar if we restrict data to state-month pairs either above or below national median RH.

# %%
medianHumidity=panelDF['RelativeHumidity2MonthsPrev'].median()
print('median RH: %3.1f'%(medianHumidity))
# Out:
# median RH: 71.7

# %%
panelDFAboveMedianHumidity=panelDF[panelDF['RelativeHumidity2MonthsPrev'] >= medianHumidity]
negBinModelAboveMedianHumidityCoef,_=runNegBinModel(modelStringExcessPct,panelDFAboveMedianHumidity)
print(negBinModelAboveMedianHumidityCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           1.5262e+00  1.2614e+00   1.2100 0.2262915
#
# RelativeHumidity2MonthsPrev          -2.1133e-02  8.7660e-03  -2.4108 0.0159162
#
# Stringency2MonthsPrev                -5.3862e-03  8.1125e-03  -0.6639 0.5067329
#
# MaskMandates2MonthsPrev              -3.9789e-01  1.1167e-01  -3.5631 0.0003665
#
# MobilityReduction2MonthsPrev         -3.7604e-03  1.2177e-02  -0.3088 0.7574736
#
# CumulCasesPer330Mill3MonthsPrev      -6.8096e-08  1.1374e-08  -5.9871 2.136e-09
#
# DeviationFrom68Fahrenheit2MonthsPrev -2.0176e-02  8.7034e-03  -2.3182 0.0204402
#
# CovidDeathsPer330Mill2MonthsPrev     -4.1063e-06  1.9837e-06  -2.0700 0.0384538
#
# FahrenheitTemperature2MonthsPrev     -2.8735e-02  9.9296e-03  -2.8939 0.0038048
#
# BoostedRate2MonthsPrev               -1.2694e-02  1.2833e-02  -0.9892 0.3225855
#
# VaxRate2MonthsPrev                   -2.9120e-02  1.0270e-02  -2.8355 0.0045752
#
# isMonthAndYear_2020_10                1.4884e+00  2.7829e-01   5.3485 8.870e-08
#
# isMonthAndYear_2020_11                1.9281e+00  2.3106e-01   8.3443 < 2.2e-16
#
# isMonthAndYear_2020_12                2.1114e+00  2.7249e-01   7.7486 9.293e-15
#
# isMonthAndYear_2020_6                -2.8103e-01  3.6915e-01  -0.7613 0.4464879
#
# isMonthAndYear_2020_7                 5.1338e-01  3.0229e-01   1.6983 0.0894549
#
# isMonthAndYear_2020_8                 8.3750e-01  2.6624e-01   3.1456 0.0016573
#
# isMonthAndYear_2020_9                 1.2099e+00  3.0975e-01   3.9060 9.382e-05
#
# isMonthAndYear_2021_1                 1.8918e+00  2.4792e-01   7.6305 2.338e-14
#
# isMonthAndYear_2021_10                5.1428e+00  8.6862e-01   5.9207 3.206e-09
#
# isMonthAndYear_2021_11                5.1912e+00  8.9888e-01   5.7752 7.685e-09
#
# isMonthAndYear_2021_12                5.6789e+00  9.4651e-01   5.9998 1.976e-09
#
# isMonthAndYear_2021_2                 1.3867e+00  3.1420e-01   4.4133 1.018e-05
#
# isMonthAndYear_2021_3                 5.1476e-01  3.8912e-01   1.3229 0.1858747
#
# isMonthAndYear_2021_4                 1.1186e+00  3.9016e-01   2.8670 0.0041435
#
# isMonthAndYear_2021_5                 1.7379e+00  4.2540e-01   4.0853 4.402e-05
#
# isMonthAndYear_2021_6                 2.1303e+00  5.4452e-01   3.9123 9.143e-05
#
# isMonthAndYear_2021_7                 2.9631e+00  6.6112e-01   4.4819 7.400e-06
#
# isMonthAndYear_2021_8                 4.5303e+00  7.3054e-01   6.2013 5.599e-10
#
# isMonthAndYear_2021_9                 5.1787e+00  8.1193e-01   6.3783 1.791e-10
#
# isMonthAndYear_2022_1                 6.1071e+00  9.2563e-01   6.5978 4.174e-11
#
# isMonthAndYear_2022_2                 6.1625e+00  1.0188e+00   6.0489 1.458e-09
#
# isState_Alabama                       6.5264e-01  1.0311e-01   6.3296 2.457e-10
#
# isState_Alaska                        2.6985e-01  2.9232e-01   0.9231 0.3559423
#
# isState_Arkansas                      7.3132e-01  6.1973e-02  11.8006 < 2.2e-16
#
# isState_Connecticut                  -1.0669e+00  1.6350e-01  -6.5255 6.775e-11
#
# isState_Delaware                     -7.0690e-02  1.1603e-01  -0.6092 0.5423669
#
# isState_District_of_Columbia         -8.7547e-01  5.3122e-01  -1.6480 0.0993461
#
# isState_Florida                       4.3665e-01  1.8818e-01   2.3205 0.0203157
#
# isState_Georgia                       3.5378e-01  1.2858e-01   2.7514 0.0059349
#
# isState_Hawaii                       -1.4424e+00  4.5910e-01  -3.1418 0.0016792
#
# isState_Idaho                        -2.7642e-01  1.5747e-01  -1.7554 0.0791894
#
# isState_Illinois                      1.1961e-01  7.9225e-02   1.5097 0.1311225
#
# isState_Indiana                      -1.1074e-01  6.5711e-02  -1.6853 0.0919403
#
# isState_Iowa                         -2.4272e-01  9.1223e-02  -2.6607 0.0077970
#
# isState_Kentucky                      4.3424e-01  9.6728e-02   4.4893 7.146e-06
#
# isState_Louisiana                     9.7319e-01  1.7886e-01   5.4410 5.297e-08
#
# isState_Maine                        -1.1307e+00  2.1089e-01  -5.3613 8.262e-08
#
# isState_Maryland                     -7.5737e-01  1.8324e-01  -4.1332 3.577e-05
#
# isState_Massachusetts                -1.7443e+00  2.1628e-01  -8.0650 7.323e-16
#
# isState_Michigan                      3.0560e-03  1.0985e-01   0.0278 0.9778070
#
# isState_Minnesota                    -4.5068e-01  1.2628e-01  -3.5690 0.0003584
#
# isState_Mississippi                   1.0339e+00  1.0442e-01   9.9010 < 2.2e-16
#
# isState_Missouri                     -2.5075e-01  9.3383e-02  -2.6852 0.0072493
#
# isState_Montana                       5.7176e-01  2.0264e-01   2.8216 0.0047784
#
# isState_Nebraska                     -7.6329e-01  1.1222e-01  -6.8019 1.033e-11
#
# isState_New_Hampshire                -1.7088e+00  1.6558e-01 -10.3200 < 2.2e-16
#
# isState_New_Jersey                   -4.0554e-01  1.7465e-01  -2.3220 0.0202343
#
# isState_New_York                      6.6091e-02  1.9336e-01   0.3418 0.7324978
#
# isState_North_Carolina                1.7172e-01  1.2512e-01   1.3724 0.1699335
#
# isState_North_Dakota                  8.5109e-02  2.2055e-01   0.3859 0.6995794
#
# isState_Ohio                         -6.8129e-01  1.0078e-01  -6.7601 1.379e-11
#
# isState_Oklahoma                      3.8334e-01  5.1481e-02   7.4463 9.598e-14
#
# isState_Oregon                       -3.7882e-01  1.6487e-01  -2.2977 0.0215794
#
# isState_Pennsylvania                 -5.5359e-01  9.3990e-02  -5.8899 3.865e-09
#
# isState_Rhode_Island                  2.2086e-02  2.0767e-01   0.1064 0.9153031
#
# isState_South_Carolina                5.6717e-01  9.7281e-02   5.8302 5.537e-09
#
# isState_South_Dakota                 -6.3418e-02  1.7681e-01  -0.3587 0.7198281
#
# isState_Tennessee                     4.9214e-01  7.7429e-02   6.3559 2.072e-10
#
# isState_Texas                         8.2246e-01  1.9218e-01   4.2797 1.872e-05
#
# isState_Utah                          3.3931e-02  1.8432e-01   0.1841 0.8539473
#
# isState_Vermont                      -7.4316e-01  2.6982e-01  -2.7543 0.0058817
#
# isState_Virginia                     -7.1149e-02  1.3644e-01  -0.5215 0.6020281
#
# isState_Washington                   -8.8826e-01  1.7509e-01  -5.0731 3.914e-07
#
# isState_West_Virginia                 1.2514e-01  9.6442e-02   1.2976 0.1944226
#
# isState_Wisconsin                    -3.3167e-01  9.2647e-02  -3.5799 0.0003437
#
# isState_Wyoming                      -5.4256e-01  2.1381e-01  -2.5376 0.0111615
#
#
#
# (Intercept)
#
# RelativeHumidity2MonthsPrev          *
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev *
#
# CovidDeathsPer330Mill2MonthsPrev     *
#
# FahrenheitTemperature2MonthsPrev     **
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   **
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                .
#
# isMonthAndYear_2020_8                **
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arkansas                     ***
#
# isState_Connecticut                  ***
#
# isState_Delaware
#
# isState_District_of_Columbia         .
#
# isState_Florida                      *
#
# isState_Georgia                      **
#
# isState_Hawaii                       **
#
# isState_Idaho                        .
#
# isState_Illinois
#
# isState_Indiana                      .
#
# isState_Iowa                         **
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland                     ***
#
# isState_Massachusetts                ***
#
# isState_Michigan
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     **
#
# isState_Montana                      **
#
# isState_Nebraska                     ***
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey                   *
#
# isState_New_York
#
# isState_North_Carolina
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       *
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah
#
# isState_Vermont                      **
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia
#
# isState_Wisconsin                    ***
#
# isState_Wyoming                      *
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# C:\Users\joe_s\Anaconda3\envs\renv\lib\site-packages\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "MonthAndYearObj". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'datetime.date'>'
#   (name, str(e)))

# %%
for p in predictors:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelAboveMedianHumidityCoef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.8095 [0.6817, 0.9613] per 10 RH percent
# log-linear estimate: -2.113300e-02 [-3.951640e-03, -3.831436e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9476 [0.8083, 1.1109] per 10 Oxford Stringency Index units
# log-linear estimate: -5.386200e-03 [1.051430e-02, -2.128670e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.6717 [0.5397, 0.8361] per 1
# log-linear estimate: -3.978900e-01 [-1.790168e-01, -6.167632e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.9631 [0.7586, 1.2227] per 10 Mobility reduction percent
# log-linear estimate: -3.760400e-03 [2.010652e-02, -2.762732e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9342 [0.9136, 0.9552] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -6.809600e-08 [-4.580296e-08, -9.038904e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.8173 [0.6891, 0.9693] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -2.017600e-02 [-3.117336e-03, -3.723466e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9598 [0.9232, 0.9978] per 10000 covid death 2 months previous
# log-linear estimate: -4.106300e-06 [-2.182480e-07, -7.994352e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.7502 [0.6176, 0.9114] per 10 degree Fahrenheit
# log-linear estimate: -2.873500e-02 [-9.272984e-03, -4.819702e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.8808 [0.6849, 1.1327] per 10 boosted rate percent
# log-linear estimate: -1.269400e-02 [1.245868e-02, -3.784668e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.7474 [0.6111, 0.9140] per 10 vaccination rate percent
# log-linear estimate: -2.912000e-02 [-8.990800e-03, -4.924920e-02] per 1 vaccination rate percent'

# %%
panelDFBelowMedianHumidity=panelDF[panelDF['RelativeHumidity2MonthsPrev'] < medianHumidity]
negBinModelBelowMedianHumidityCoef,_=runNegBinModel(modelStringExcessPct,panelDFBelowMedianHumidity)
print(negBinModelBelowMedianHumidityCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           2.5627e+00  8.5099e-01   3.0114 0.0026002
#
# RelativeHumidity2MonthsPrev          -2.5488e-02  4.9751e-03  -5.1232 3.003e-07
#
# Stringency2MonthsPrev                -2.8599e-03  5.5042e-03  -0.5196 0.6033531
#
# MaskMandates2MonthsPrev              -2.3905e-01  1.1867e-01  -2.0144 0.0439647
#
# MobilityReduction2MonthsPrev         -3.5164e-02  1.0995e-02  -3.1984 0.0013821
#
# CumulCasesPer330Mill3MonthsPrev      -8.0258e-08  1.1097e-08  -7.2321 4.755e-13
#
# DeviationFrom68Fahrenheit2MonthsPrev  6.2571e-03  5.1721e-03   1.2098 0.2263645
#
# CovidDeathsPer330Mill2MonthsPrev     -3.8504e-06  8.4193e-07  -4.5733 4.802e-06
#
# FahrenheitTemperature2MonthsPrev     -4.2913e-02  8.1838e-03  -5.2436 1.575e-07
#
# BoostedRate2MonthsPrev               -2.2271e-02  1.4798e-02  -1.5050 0.1323339
#
# VaxRate2MonthsPrev                   -5.3471e-02  1.0323e-02  -5.1796 2.224e-07
#
# isMonthAndYear_2020_10                1.1392e+00  3.3353e-01   3.4155 0.0006368
#
# isMonthAndYear_2020_11                1.6917e+00  2.8314e-01   5.9746 2.306e-09
#
# isMonthAndYear_2020_12                1.9039e+00  2.1968e-01   8.6670 < 2.2e-16
#
# isMonthAndYear_2020_6                 1.9246e-01  3.2378e-01   0.5944 0.5522220
#
# isMonthAndYear_2020_7                 3.6774e-01  3.4213e-01   1.0749 0.2824387
#
# isMonthAndYear_2020_8                 6.3969e-01  2.9206e-01   2.1902 0.0285065
#
# isMonthAndYear_2020_9                 6.8822e-01  2.7824e-01   2.4735 0.0133806
#
# isMonthAndYear_2021_1                 1.6959e+00  2.4929e-01   6.8027 1.027e-11
#
# isMonthAndYear_2021_10                6.5432e+00  8.3048e-01   7.8789 3.303e-15
#
# isMonthAndYear_2021_11                6.7045e+00  8.5799e-01   7.8143 5.529e-15
#
# isMonthAndYear_2021_12                6.9319e+00  9.3981e-01   7.3758 1.633e-13
#
# isMonthAndYear_2021_2                 5.6642e-01  3.6085e-01   1.5697 0.1164893
#
# isMonthAndYear_2021_3                 2.3844e-01  4.1609e-01   0.5730 0.5666152
#
# isMonthAndYear_2021_4                 5.5827e-01  4.0397e-01   1.3819 0.1669921
#
# isMonthAndYear_2021_5                 1.5570e+00  5.2232e-01   2.9810 0.0028730
#
# isMonthAndYear_2021_6                 2.9066e+00  5.8835e-01   4.9403 7.802e-07
#
# isMonthAndYear_2021_7                 4.0224e+00  6.9112e-01   5.8201 5.881e-09
#
# isMonthAndYear_2021_8                 5.6057e+00  7.4191e-01   7.5557 4.165e-14
#
# isMonthAndYear_2021_9                 6.3839e+00  8.0672e-01   7.9134 2.504e-15
#
# isMonthAndYear_2022_1                 7.5807e+00  1.0492e+00   7.2253 5.000e-13
#
# isMonthAndYear_2022_2                 7.4377e+00  1.1478e+00   6.4802 9.158e-11
#
# isState_Alabama                       1.1892e+00  9.5316e-02  12.4767 < 2.2e-16
#
# isState_Alaska                       -5.3194e-01  2.4570e-01  -2.1650 0.0303860
#
# isState_Arizona                       6.6020e-01  1.6966e-01   3.8913 9.972e-05
#
# isState_Arkansas                      4.7422e-01  7.5043e-02   6.3193 2.628e-10
#
# isState_California                    5.9333e-01  1.7719e-01   3.3485 0.0008125
#
# isState_Colorado                     -4.1431e-01  1.2343e-01  -3.3567 0.0007888
#
# isState_Connecticut                  -2.3565e-01  1.0769e-01  -2.1882 0.0286524
#
# isState_Delaware                      2.5949e-01  1.0129e-01   2.5620 0.0104073
#
# isState_District_of_Columbia          8.0365e-01  4.3108e-01   1.8642 0.0622867
#
# isState_Florida                       1.4093e+00  2.0221e-01   6.9694 3.184e-12
#
# isState_Georgia                       8.3682e-01  8.8709e-02   9.4333 < 2.2e-16
#
# isState_Hawaii                       -1.0383e+00  4.4638e-01  -2.3262 0.0200102
#
# isState_Idaho                        -1.1825e+00  1.5380e-01  -7.6881 1.493e-14
#
# isState_Illinois                      1.8488e-01  7.8773e-02   2.3469 0.0189280
#
# isState_Indiana                      -4.1642e-02  6.6226e-02  -0.6288 0.5294885
#
# isState_Iowa                         -5.5105e-01  9.6902e-02  -5.6867 1.295e-08
#
# isState_Kentucky                      5.0544e-01  9.1254e-02   5.5389 3.045e-08
#
# isState_Louisiana                     1.2055e+00  1.6746e-01   7.1990 6.065e-13
#
# isState_Maine                        -1.6807e+00  1.3224e-01 -12.7092 < 2.2e-16
#
# isState_Maryland                      8.2570e-02  1.3930e-01   0.5928 0.5533407
#
# isState_Massachusetts                -3.8618e-01  1.5172e-01  -2.5454 0.0109152
#
# isState_Michigan                     -1.4955e-01  9.3207e-02  -1.6045 0.1086013
#
# isState_Minnesota                    -2.2493e-01  1.0538e-01  -2.1344 0.0328110
#
# isState_Mississippi                   8.9100e-01  1.3648e-01   6.5283 6.650e-11
#
# isState_Missouri                     -5.2113e-01  9.3097e-02  -5.5977 2.173e-08
#
# isState_Montana                      -8.3413e-01  1.7976e-01  -4.6403 3.480e-06
#
# isState_Nebraska                     -4.8773e-01  8.8684e-02  -5.4997 3.805e-08
#
# isState_Nevada                       -2.2372e-01  1.7263e-01  -1.2960 0.1949798
#
# isState_New_Hampshire                -1.5483e+00  1.1151e-01 -13.8841 < 2.2e-16
#
# isState_New_Jersey                   -1.8418e-01  1.4207e-01  -1.2964 0.1948496
#
# isState_New_Mexico                    3.8182e-01  1.4090e-01   2.7100 0.0067293
#
# isState_New_York                      8.8236e-02  1.2795e-01   0.6896 0.4904321
#
# isState_North_Carolina                1.9114e-01  7.4418e-02   2.5685 0.0102154
#
# isState_North_Dakota                  5.2271e-02  1.3202e-01   0.3959 0.6921557
#
# isState_Ohio                         -2.2416e-01  8.3133e-02  -2.6964 0.0070102
#
# isState_Oklahoma                      2.6453e-01  6.1876e-02   4.2751 1.911e-05
#
# isState_Oregon                       -7.4837e-01  1.3443e-01  -5.5669 2.593e-08
#
# isState_Pennsylvania                 -9.2883e-01  9.5917e-02  -9.6837 < 2.2e-16
#
# isState_Rhode_Island                  6.6686e-01  1.6272e-01   4.0981 4.166e-05
#
# isState_South_Carolina                8.8644e-01  6.9770e-02  12.7051 < 2.2e-16
#
# isState_South_Dakota                 -9.2322e-02  1.6958e-01  -0.5444 0.5861572
#
# isState_Tennessee                     6.6561e-01  8.1066e-02   8.2108 < 2.2e-16
#
# isState_Texas                         1.1725e+00  1.1878e-01   9.8710 < 2.2e-16
#
# isState_Utah                         -5.0805e-01  1.5255e-01  -3.3304 0.0008673
#
# isState_Vermont                      -5.4366e-01  1.9089e-01  -2.8480 0.0043997
#
# isState_Virginia                      4.4787e-02  1.1374e-01   0.3938 0.6937557
#
# isState_Washington                   -6.3596e-01  1.4289e-01  -4.4508 8.556e-06
#
# isState_West_Virginia                -7.6030e-01  2.8465e-01  -2.6710 0.0075626
#
# isState_Wisconsin                    -7.2517e-02  1.0686e-01  -0.6786 0.4973884
#
# isState_Wyoming                      -5.9802e-01  1.7664e-01  -3.3856 0.0007102
#
#
#
# (Intercept)                          **
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              *
#
# MobilityReduction2MonthsPrev         **
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7
#
# isMonthAndYear_2020_8                *
#
# isMonthAndYear_2020_9                *
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4
#
# isMonthAndYear_2021_5                **
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska                       *
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   ***
#
# isState_Colorado                     ***
#
# isState_Connecticut                  *
#
# isState_Delaware                     *
#
# isState_District_of_Columbia         .
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       *
#
# isState_Idaho                        ***
#
# isState_Illinois                     *
#
# isState_Indiana
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                *
#
# isState_Michigan
#
# isState_Minnesota                    *
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      ***
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   **
#
# isState_New_York
#
# isState_North_Carolina               *
#
# isState_North_Dakota
#
# isState_Ohio                         **
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         ***
#
# isState_Vermont                      **
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia                **
#
# isState_Wisconsin
#
# isState_Wyoming                      ***
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# C:\Users\joe_s\Anaconda3\envs\renv\lib\site-packages\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "MonthAndYearObj". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'datetime.date'>'
#   (name, str(e)))

# %%
for p in predictors:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelBelowMedianHumidityCoef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.7750 [0.7030, 0.8544] per 10 RH percent
# log-linear estimate: -2.548800e-02 [-1.573680e-02, -3.523920e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9718 [0.8724, 1.0825] per 10 Oxford Stringency Index units
# log-linear estimate: -2.859900e-03 [7.928332e-03, -1.364813e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.7874 [0.6240, 0.9936] per 1
# log-linear estimate: -2.390500e-01 [-6.456800e-03, -4.716432e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7035 [0.5671, 0.8727] per 10 Mobility reduction percent
# log-linear estimate: -3.516400e-02 [-1.361380e-02, -5.671420e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9229 [0.9030, 0.9432] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -8.025800e-08 [-5.850788e-08, -1.020081e-07] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 1.0646 [1.1781, 0.9619] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: 6.257100e-03 [-3.880216e-03, 1.639442e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9622 [0.9465, 0.9782] per 10000 covid death 2 months previous
# log-linear estimate: -3.850400e-06 [-2.200217e-06, -5.500583e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.6511 [0.5546, 0.7644] per 10 degree Fahrenheit
# log-linear estimate: -4.291300e-02 [-2.687275e-02, -5.895325e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.8003 [0.5988, 1.0696] per 10 boosted rate percent
# log-linear estimate: -2.227100e-02 [6.733080e-03, -5.127508e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.5858 [0.4785, 0.7172] per 10 vaccination rate percent
# log-linear estimate: -5.347100e-02 [-3.323792e-02, -7.370408e-02] per 1 vaccination rate percent'

# %% [markdown]
# Results are robust to the removal of any 2 states from the regression, with only modest changes in the coefficient for RH.

# %%
primaryVariableStudied='RelativeHumidity2MonthsPrev'
    
import gc

estimatesForTwoStatesRemoved=[]
stdErrsForTwoStatesRemoved=[]
states=list(set(panelDF['State'].values))

cnt=0

doRemoveStates=True

numStates=len(states)

if (doRemoveStates):
    for i1 in range(numStates):
        for i2 in range(i1+1,numStates):
            state=states[i1]
            state2=states[i2]
            #if (state2 ==state):
            #    continue
            #print(state,
            cnt=cnt +1
            if (cnt%100==0):
                print(cnt)
            panelDFStatesRemoved=panelDF[numpy.logical_and(panelDF['State'] != state,panelDF['State'] != state2)].copy()
            #print(len(list(set(panelDFStateRemoved['State'].values))))
            panelDF_R_StatesRemoved = pandas2ri.py2ri(panelDFStatesRemoved)
            modelStringHere=modelStringExcessPct
            modelStringHere=modelStringHere.replace('+isState_' + state,'')
            modelStringHere=modelStringHere.replace('+isState_' + state2,'')
            #print(state,state2)
            #print(modelStringHere + '\n\n')
            negBinResStatesRemoved=MASS.glm_nb(modelStringHere,data=panelDF_R_StatesRemoved)
            negBinCoefTestStatesRemoved=lmtest.coeftest(negBinResStatesRemoved,vcov=sandwich.vcovCL(negBinResStatesRemoved,cluster=panelDFStatesRemoved["State"].values))
            estimatesForTwoStatesRemoved.append(getEstimate(negBinCoefTestStatesRemoved,primaryVariableStudied))
            stdErrsForTwoStatesRemoved.append(getStdError(negBinCoefTestStatesRemoved,primaryVariableStudied))
            del panelDFStatesRemoved
            del panelDF_R_StatesRemoved
            gc.collect()

    estimatesForTwoStatesRemoved=numpy.array(estimatesForTwoStatesRemoved)
    stdErrsForTwoStatesRemoved=numpy.array(stdErrsForTwoStatesRemoved)
    ciLower95Pct=estimatesForTwoStatesRemoved - 1.96*stdErrsForTwoStatesRemoved
    ciUpper95Pct=estimatesForTwoStatesRemoved + 1.96*stdErrsForTwoStatesRemoved
    print(primaryVariableStudied + ":\n")
    print('max estimate',numpy.max(estimatesForTwoStatesRemoved))
    print('min estimate',numpy.min(estimatesForTwoStatesRemoved))
    print('max stderr',numpy.max(stdErrsForTwoStatesRemoved))
    print('min stderr',numpy.min(stdErrsForTwoStatesRemoved))
    print('max lower bound 95% CI',numpy.max(ciLower95Pct))
    print('min lower bound 95% CI',numpy.min(ciLower95Pct))
    print('max upper bound 95% CI',numpy.max(ciUpper95Pct))
    print('min upper bound 95% CI',numpy.min(ciUpper95Pct))
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# RelativeHumidity2MonthsPrev:
#
# max estimate -0.018489
# min estimate -0.022581
# max stderr 0.0039658
# min stderr 0.0034237
# max lower bound 95% CI -0.025240452
# min lower bound 95% CI -0.029530848
# max upper bound 95% CI -0.011147720000000002
# min upper bound 95% CI -0.01568376

# %% [markdown]
# Examining the regression coefficients when all independent variables are standardized to have 0 mean and variance 1 can be helpful when interpreting the relative magnitude of the various coefficients. Note that this model is fully equivalent to the non-standardized model already presented.

# %%
negBinModelExcessPctCoefStdized,_=runNegBinModel(modelStringExcessPctStdized,panelDF)
print(negBinModelExcessPctCoefStdized)
# Out:
# z test of coefficients:
#
#
#
#                                                Estimate Std. Error  z value
#
# (Intercept)                                  -4.8515679  0.2876158 -16.8682
#
# RelativeHumidity2MonthsPrev_stdized          -0.2937698  0.0532002  -5.5220
#
# Stringency2MonthsPrev_stdized                -0.0987696  0.0908250  -1.0875
#
# MaskMandates2MonthsPrev_stdized              -0.1662523  0.0403104  -4.1243
#
# MobilityReduction2MonthsPrev_stdized         -0.3027406  0.1257730  -2.4070
#
# CumulCasesPer330Mill3MonthsPrev_stdized      -1.2880216  0.1484199  -8.6782
#
# DeviationFrom68Fahrenheit2MonthsPrev_stdized -0.0441735  0.0650076  -0.6795
#
# CovidDeathsPer330Mill2MonthsPrev_stdized     -0.1288289  0.0298612  -4.3143
#
# FahrenheitTemperature2MonthsPrev_stdized     -0.5176079  0.1060007  -4.8831
#
# BoostedRate2MonthsPrev_stdized               -0.0897001  0.0684982  -1.3095
#
# VaxRate2MonthsPrev_stdized                   -1.1085693  0.1935693  -5.7270
#
# isMonthAndYear_2020_10                        1.1643431  0.1746801   6.6656
#
# isMonthAndYear_2020_11                        1.7154617  0.1441254  11.9026
#
# isMonthAndYear_2020_12                        1.9360885  0.1290880  14.9982
#
# isMonthAndYear_2020_6                         0.1699522  0.2436508   0.6975
#
# isMonthAndYear_2020_7                         0.4182394  0.2129813   1.9637
#
# isMonthAndYear_2020_8                         0.6388976  0.1803230   3.5431
#
# isMonthAndYear_2020_9                         0.8611682  0.1836637   4.6888
#
# isMonthAndYear_2021_1                         1.7600270  0.1592300  11.0534
#
# isMonthAndYear_2021_10                        5.7073906  0.5904240   9.6666
#
# isMonthAndYear_2021_11                        5.8864603  0.6228265   9.4512
#
# isMonthAndYear_2021_12                        6.3137136  0.6794733   9.2921
#
# isMonthAndYear_2021_2                         1.0216406  0.2338781   4.3683
#
# isMonthAndYear_2021_3                         0.3587177  0.2841078   1.2626
#
# isMonthAndYear_2021_4                         0.8296590  0.3132855   2.6483
#
# isMonthAndYear_2021_5                         1.6547725  0.3336764   4.9592
#
# isMonthAndYear_2021_6                         2.4853320  0.4137789   6.0064
#
# isMonthAndYear_2021_7                         3.4910548  0.4924240   7.0895
#
# isMonthAndYear_2021_8                         4.9887810  0.5354292   9.3173
#
# isMonthAndYear_2021_9                         5.6558661  0.5605959  10.0890
#
# isMonthAndYear_2022_1                         6.8409837  0.7304446   9.3655
#
# isMonthAndYear_2022_2                         6.7673519  0.7658602   8.8363
#
# isState_Alabama                               0.8327991  0.0818852  10.1703
#
# isState_Alaska                               -0.0795203  0.1975861  -0.4025
#
# isState_Arizona                               0.5453992  0.1339520   4.0716
#
# isState_Arkansas                              0.7593251  0.0479311  15.8420
#
# isState_California                            0.4740003  0.1661811   2.8523
#
# isState_Colorado                             -0.2538145  0.0970472  -2.6154
#
# isState_Connecticut                          -0.3418181  0.1163112  -2.9388
#
# isState_Delaware                              0.2313820  0.0914761   2.5294
#
# isState_District_of_Columbia                  0.4311746  0.4121445   1.0462
#
# isState_Florida                               1.0034572  0.1635350   6.1360
#
# isState_Georgia                               0.5980088  0.0702476   8.5129
#
# isState_Hawaii                               -0.6527654  0.3950218  -1.6525
#
# isState_Idaho                                -0.8906880  0.1408003  -6.3259
#
# isState_Illinois                              0.2110791  0.0484486   4.3568
#
# isState_Indiana                              -0.0468710  0.0321015  -1.4601
#
# isState_Iowa                                 -0.2696628  0.0626174  -4.3065
#
# isState_Kentucky                              0.5446444  0.0636382   8.5584
#
# isState_Louisiana                             1.1712559  0.1482189   7.9022
#
# isState_Maine                                -1.1856063  0.1257964  -9.4248
#
# isState_Maryland                             -0.1046497  0.1350784  -0.7747
#
# isState_Massachusetts                        -0.7016408  0.1690627  -4.1502
#
# isState_Michigan                             -0.0012295  0.0547464  -0.0225
#
# isState_Minnesota                            -0.2782014  0.0650537  -4.2765
#
# isState_Mississippi                           1.1444877  0.0877435  13.0436
#
# isState_Missouri                             -0.3278607  0.0619386  -5.2933
#
# isState_Montana                              -0.4077066  0.1614582  -2.5252
#
# isState_Nebraska                             -0.5366613  0.0828044  -6.4811
#
# isState_Nevada                               -0.0434402  0.1187109  -0.3659
#
# isState_New_Hampshire                        -1.5299524  0.0896051 -17.0744
#
# isState_New_Jersey                           -0.1920090  0.1316802  -1.4581
#
# isState_New_Mexico                            0.5141401  0.1095006   4.6953
#
# isState_New_York                              0.2814089  0.1390701   2.0235
#
# isState_North_Carolina                        0.3039732  0.0838125   3.6268
#
# isState_North_Dakota                          0.0145751  0.1168559   0.1247
#
# isState_Ohio                                 -0.5270555  0.0507961 -10.3759
#
# isState_Oklahoma                              0.1858929  0.0482718   3.8510
#
# isState_Oregon                               -0.4179689  0.0970661  -4.3060
#
# isState_Pennsylvania                         -0.4840553  0.0589646  -8.2093
#
# isState_Rhode_Island                          0.5969716  0.1722869   3.4650
#
# isState_South_Carolina                        0.6828600  0.0556897  12.2619
#
# isState_South_Dakota                         -0.0752704  0.1544732  -0.4873
#
# isState_Tennessee                             0.5991242  0.0445746  13.4409
#
# isState_Texas                                 0.9702375  0.0957324  10.1349
#
# isState_Utah                                 -0.3086836  0.1267338  -2.4357
#
# isState_Vermont                              -0.4420701  0.1802564  -2.4525
#
# isState_Virginia                              0.1338850  0.0976355   1.3713
#
# isState_Washington                           -0.6101352  0.1060871  -5.7513
#
# isState_West_Virginia                         0.1180453  0.0605295   1.9502
#
# isState_Wisconsin                            -0.1977881  0.0522830  -3.7830
#
# isState_Wyoming                              -0.2764916  0.1542480  -1.7925
#
#                                               Pr(>|z|)
#
# (Intercept)                                  < 2.2e-16 ***
#
# RelativeHumidity2MonthsPrev_stdized          3.352e-08 ***
#
# Stringency2MonthsPrev_stdized                0.2768287
#
# MaskMandates2MonthsPrev_stdized              3.719e-05 ***
#
# MobilityReduction2MonthsPrev_stdized         0.0160825 *
#
# CumulCasesPer330Mill3MonthsPrev_stdized      < 2.2e-16 ***
#
# DeviationFrom68Fahrenheit2MonthsPrev_stdized 0.4968128
#
# CovidDeathsPer330Mill2MonthsPrev_stdized     1.601e-05 ***
#
# FahrenheitTemperature2MonthsPrev_stdized     1.045e-06 ***
#
# BoostedRate2MonthsPrev_stdized               0.1903566
#
# VaxRate2MonthsPrev_stdized                   1.022e-08 ***
#
# isMonthAndYear_2020_10                       2.636e-11 ***
#
# isMonthAndYear_2020_11                       < 2.2e-16 ***
#
# isMonthAndYear_2020_12                       < 2.2e-16 ***
#
# isMonthAndYear_2020_6                        0.4854749
#
# isMonthAndYear_2020_7                        0.0495606 *
#
# isMonthAndYear_2020_8                        0.0003955 ***
#
# isMonthAndYear_2020_9                        2.748e-06 ***
#
# isMonthAndYear_2021_1                        < 2.2e-16 ***
#
# isMonthAndYear_2021_10                       < 2.2e-16 ***
#
# isMonthAndYear_2021_11                       < 2.2e-16 ***
#
# isMonthAndYear_2021_12                       < 2.2e-16 ***
#
# isMonthAndYear_2021_2                        1.252e-05 ***
#
# isMonthAndYear_2021_3                        0.2067290
#
# isMonthAndYear_2021_4                        0.0080909 **
#
# isMonthAndYear_2021_5                        7.078e-07 ***
#
# isMonthAndYear_2021_6                        1.897e-09 ***
#
# isMonthAndYear_2021_7                        1.346e-12 ***
#
# isMonthAndYear_2021_8                        < 2.2e-16 ***
#
# isMonthAndYear_2021_9                        < 2.2e-16 ***
#
# isMonthAndYear_2022_1                        < 2.2e-16 ***
#
# isMonthAndYear_2022_2                        < 2.2e-16 ***
#
# isState_Alabama                              < 2.2e-16 ***
#
# isState_Alaska                               0.6873461
#
# isState_Arizona                              4.669e-05 ***
#
# isState_Arkansas                             < 2.2e-16 ***
#
# isState_California                           0.0043403 **
#
# isState_Colorado                             0.0089130 **
#
# isState_Connecticut                          0.0032946 **
#
# isState_Delaware                             0.0114249 *
#
# isState_District_of_Columbia                 0.2954811
#
# isState_Florida                              8.460e-10 ***
#
# isState_Georgia                              < 2.2e-16 ***
#
# isState_Hawaii                               0.0984369 .
#
# isState_Idaho                                2.518e-10 ***
#
# isState_Illinois                             1.320e-05 ***
#
# isState_Indiana                              0.1442656
#
# isState_Iowa                                 1.658e-05 ***
#
# isState_Kentucky                             < 2.2e-16 ***
#
# isState_Louisiana                            2.740e-15 ***
#
# isState_Maine                                < 2.2e-16 ***
#
# isState_Maryland                             0.4384974
#
# isState_Massachusetts                        3.322e-05 ***
#
# isState_Michigan                             0.9820824
#
# isState_Minnesota                            1.899e-05 ***
#
# isState_Mississippi                          < 2.2e-16 ***
#
# isState_Missouri                             1.201e-07 ***
#
# isState_Montana                              0.0115648 *
#
# isState_Nebraska                             9.107e-11 ***
#
# isState_Nevada                               0.7144153
#
# isState_New_Hampshire                        < 2.2e-16 ***
#
# isState_New_Jersey                           0.1448000
#
# isState_New_Mexico                           2.662e-06 ***
#
# isState_New_York                             0.0430212 *
#
# isState_North_Carolina                       0.0002869 ***
#
# isState_North_Dakota                         0.9007399
#
# isState_Ohio                                 < 2.2e-16 ***
#
# isState_Oklahoma                             0.0001177 ***
#
# isState_Oregon                               1.662e-05 ***
#
# isState_Pennsylvania                         2.226e-16 ***
#
# isState_Rhode_Island                         0.0005303 ***
#
# isState_South_Carolina                       < 2.2e-16 ***
#
# isState_South_Dakota                         0.6260658
#
# isState_Tennessee                            < 2.2e-16 ***
#
# isState_Texas                                < 2.2e-16 ***
#
# isState_Utah                                 0.0148636 *
#
# isState_Vermont                              0.0141886 *
#
# isState_Virginia                             0.1702893
#
# isState_Washington                           8.858e-09 ***
#
# isState_West_Virginia                        0.0511509 .
#
# isState_Wisconsin                            0.0001549 ***
#
# isState_Wyoming                              0.0730507 .
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
for p in [pl + '_stdized' for pl in  predictors]:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelExcessPctCoefStdized,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev_stdized
# multiplicative estimate: 0.7454 [0.6716, 0.8274] per 1
# log-linear estimate: -2.937698e-01 [-1.894974e-01, -3.980422e-01] per 1 '
#
#
#
# Stringency2MonthsPrev_stdized
# multiplicative estimate: 0.9060 [0.7582, 1.0825] per 1
# log-linear estimate: -9.876960e-02 [7.924740e-02, -2.767866e-01] per 1 '
#
#
#
# MaskMandates2MonthsPrev_stdized
# multiplicative estimate: 0.8468 [0.7825, 0.9165] per 1
# log-linear estimate: -1.662523e-01 [-8.724392e-02, -2.452607e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev_stdized
# multiplicative estimate: 0.7388 [0.5774, 0.9453] per 1
# log-linear estimate: -3.027406e-01 [-5.622552e-02, -5.492557e-01] per 1 '
#
#
#
# CumulCasesPer330Mill3MonthsPrev_stdized
# multiplicative estimate: 0.2758 [0.2062, 0.3689] per 1
# log-linear estimate: -1.288022e+00 [-9.971186e-01, -1.578925e+00] per 1 '
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev_stdized
# multiplicative estimate: 0.9568 [0.8423, 1.0868] per 1
# log-linear estimate: -4.417350e-02 [8.324140e-02, -1.715884e-01] per 1 '
#
#
#
# CovidDeathsPer330Mill2MonthsPrev_stdized
# multiplicative estimate: 0.8791 [0.8291, 0.9321] per 1
# log-linear estimate: -1.288289e-01 [-7.030095e-02, -1.873569e-01] per 1 '
#
#
#
# FahrenheitTemperature2MonthsPrev_stdized
# multiplicative estimate: 0.5959 [0.4841, 0.7336] per 1
# log-linear estimate: -5.176079e-01 [-3.098465e-01, -7.253693e-01] per 1 '
#
#
#
# BoostedRate2MonthsPrev_stdized
# multiplicative estimate: 0.9142 [0.7993, 1.0456] per 1
# log-linear estimate: -8.970010e-02 [4.455637e-02, -2.239566e-01] per 1 '
#
#
#
# VaxRate2MonthsPrev_stdized
# multiplicative estimate: 0.3300 [0.2258, 0.4823] per 1
# log-linear estimate: -1.108569e+00 [-7.291735e-01, -1.487965e+00] per 1 '

# %% [markdown]
# This paper is intended to examine the association of RH with excess deaths, but it may be tempting for readers to draw conclusions about some of the controls in the regression.  The set of appropriate controls for RH may not be the appropriate control set for another variable. In particular, the stringency index control is almost surely mediated by the Google Mobility data, so the insignificance of the stringency index should be interpreted with caution. In "Stringency of containment and closures on the growth of SARS-CoV-2 in Canada prior to accelerated vaccine roll-out" by Vickers, Baral, Mishra et. al (https://www.ijidonline.com/article/S1201-9712(22)00108-4/fulltext), which studies NPIs such as the stringency index, the mobility variable is regressed against stringency index and the residual of that regression is used as a control. Here we present the results of the same approach.

# %%
modelStringExcessPctMobilityResidual=modelStringExcessPct.replace('Reduction','Residual')
negBinModelExcessPctMobilityResidual,_=runNegBinModel(modelStringExcessPctMobilityResidual,panelDF)
print(negBinModelExcessPctMobilityResidual)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           2.0534e+00  8.1140e-01   2.5307 0.0113832
#
# RelativeHumidity2MonthsPrev          -2.0277e-02  3.6721e-03  -5.5220 3.352e-08
#
# Stringency2MonthsPrev                -1.9022e-02  7.7889e-03  -2.4422 0.0145997
#
# MaskMandates2MonthsPrev              -3.4664e-01  8.4047e-02  -4.1243 3.719e-05
#
# MobilityResidual2MonthsPrev          -2.5115e-02  1.0434e-02  -2.4070 0.0160825
#
# CumulCasesPer330Mill3MonthsPrev      -7.3440e-08  8.4625e-09  -8.6782 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev -3.7244e-03  5.4809e-03  -0.6795 0.4968128
#
# CovidDeathsPer330Mill2MonthsPrev     -3.5624e-06  8.2573e-07  -4.3143 1.601e-05
#
# FahrenheitTemperature2MonthsPrev     -3.0247e-02  6.1942e-03  -4.8831 1.045e-06
#
# BoostedRate2MonthsPrev               -1.2744e-02  9.7319e-03  -1.3095 0.1903566
#
# VaxRate2MonthsPrev                   -4.5283e-02  7.9070e-03  -5.7270 1.022e-08
#
# isMonthAndYear_2020_10                1.1643e+00  1.7468e-01   6.6656 2.636e-11
#
# isMonthAndYear_2020_11                1.7155e+00  1.4413e-01  11.9026 < 2.2e-16
#
# isMonthAndYear_2020_12                1.9361e+00  1.2909e-01  14.9982 < 2.2e-16
#
# isMonthAndYear_2020_6                 1.6995e-01  2.4365e-01   0.6975 0.4854749
#
# isMonthAndYear_2020_7                 4.1824e-01  2.1298e-01   1.9637 0.0495606
#
# isMonthAndYear_2020_8                 6.3890e-01  1.8032e-01   3.5431 0.0003955
#
# isMonthAndYear_2020_9                 8.6117e-01  1.8366e-01   4.6888 2.748e-06
#
# isMonthAndYear_2021_1                 1.7600e+00  1.5923e-01  11.0534 < 2.2e-16
#
# isMonthAndYear_2021_10                5.7074e+00  5.9042e-01   9.6666 < 2.2e-16
#
# isMonthAndYear_2021_11                5.8865e+00  6.2283e-01   9.4512 < 2.2e-16
#
# isMonthAndYear_2021_12                6.3137e+00  6.7947e-01   9.2921 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.0216e+00  2.3388e-01   4.3683 1.252e-05
#
# isMonthAndYear_2021_3                 3.5872e-01  2.8411e-01   1.2626 0.2067290
#
# isMonthAndYear_2021_4                 8.2966e-01  3.1329e-01   2.6483 0.0080909
#
# isMonthAndYear_2021_5                 1.6548e+00  3.3368e-01   4.9592 7.078e-07
#
# isMonthAndYear_2021_6                 2.4853e+00  4.1378e-01   6.0064 1.897e-09
#
# isMonthAndYear_2021_7                 3.4911e+00  4.9242e-01   7.0895 1.346e-12
#
# isMonthAndYear_2021_8                 4.9888e+00  5.3543e-01   9.3173 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.6559e+00  5.6060e-01  10.0890 < 2.2e-16
#
# isMonthAndYear_2022_1                 6.8410e+00  7.3044e-01   9.3655 < 2.2e-16
#
# isMonthAndYear_2022_2                 6.7674e+00  7.6586e-01   8.8363 < 2.2e-16
#
# isState_Alabama                       8.3280e-01  8.1885e-02  10.1703 < 2.2e-16
#
# isState_Alaska                       -7.9520e-02  1.9759e-01  -0.4025 0.6873461
#
# isState_Arizona                       5.4540e-01  1.3395e-01   4.0716 4.669e-05
#
# isState_Arkansas                      7.5933e-01  4.7931e-02  15.8420 < 2.2e-16
#
# isState_California                    4.7400e-01  1.6618e-01   2.8523 0.0043403
#
# isState_Colorado                     -2.5381e-01  9.7047e-02  -2.6154 0.0089130
#
# isState_Connecticut                  -3.4182e-01  1.1631e-01  -2.9388 0.0032946
#
# isState_Delaware                      2.3138e-01  9.1476e-02   2.5294 0.0114249
#
# isState_District_of_Columbia          4.3117e-01  4.1214e-01   1.0462 0.2954811
#
# isState_Florida                       1.0035e+00  1.6353e-01   6.1360 8.460e-10
#
# isState_Georgia                       5.9801e-01  7.0248e-02   8.5129 < 2.2e-16
#
# isState_Hawaii                       -6.5277e-01  3.9502e-01  -1.6525 0.0984369
#
# isState_Idaho                        -8.9069e-01  1.4080e-01  -6.3259 2.518e-10
#
# isState_Illinois                      2.1108e-01  4.8449e-02   4.3568 1.320e-05
#
# isState_Indiana                      -4.6871e-02  3.2101e-02  -1.4601 0.1442656
#
# isState_Iowa                         -2.6966e-01  6.2617e-02  -4.3065 1.658e-05
#
# isState_Kentucky                      5.4464e-01  6.3638e-02   8.5584 < 2.2e-16
#
# isState_Louisiana                     1.1713e+00  1.4822e-01   7.9022 2.740e-15
#
# isState_Maine                        -1.1856e+00  1.2580e-01  -9.4248 < 2.2e-16
#
# isState_Maryland                     -1.0465e-01  1.3508e-01  -0.7747 0.4384974
#
# isState_Massachusetts                -7.0164e-01  1.6906e-01  -4.1502 3.322e-05
#
# isState_Michigan                     -1.2295e-03  5.4746e-02  -0.0225 0.9820824
#
# isState_Minnesota                    -2.7820e-01  6.5054e-02  -4.2765 1.899e-05
#
# isState_Mississippi                   1.1445e+00  8.7743e-02  13.0436 < 2.2e-16
#
# isState_Missouri                     -3.2786e-01  6.1939e-02  -5.2933 1.201e-07
#
# isState_Montana                      -4.0771e-01  1.6146e-01  -2.5252 0.0115648
#
# isState_Nebraska                     -5.3666e-01  8.2804e-02  -6.4811 9.107e-11
#
# isState_Nevada                       -4.3440e-02  1.1871e-01  -0.3659 0.7144153
#
# isState_New_Hampshire                -1.5300e+00  8.9605e-02 -17.0744 < 2.2e-16
#
# isState_New_Jersey                   -1.9201e-01  1.3168e-01  -1.4581 0.1448000
#
# isState_New_Mexico                    5.1414e-01  1.0950e-01   4.6953 2.662e-06
#
# isState_New_York                      2.8141e-01  1.3907e-01   2.0235 0.0430212
#
# isState_North_Carolina                3.0397e-01  8.3813e-02   3.6268 0.0002869
#
# isState_North_Dakota                  1.4575e-02  1.1686e-01   0.1247 0.9007399
#
# isState_Ohio                         -5.2706e-01  5.0796e-02 -10.3759 < 2.2e-16
#
# isState_Oklahoma                      1.8589e-01  4.8272e-02   3.8510 0.0001177
#
# isState_Oregon                       -4.1797e-01  9.7066e-02  -4.3060 1.662e-05
#
# isState_Pennsylvania                 -4.8406e-01  5.8965e-02  -8.2093 2.226e-16
#
# isState_Rhode_Island                  5.9697e-01  1.7229e-01   3.4650 0.0005303
#
# isState_South_Carolina                6.8286e-01  5.5690e-02  12.2619 < 2.2e-16
#
# isState_South_Dakota                 -7.5270e-02  1.5447e-01  -0.4873 0.6260658
#
# isState_Tennessee                     5.9912e-01  4.4575e-02  13.4409 < 2.2e-16
#
# isState_Texas                         9.7024e-01  9.5732e-02  10.1349 < 2.2e-16
#
# isState_Utah                         -3.0868e-01  1.2673e-01  -2.4357 0.0148636
#
# isState_Vermont                      -4.4207e-01  1.8026e-01  -2.4525 0.0141886
#
# isState_Virginia                      1.3389e-01  9.7635e-02   1.3713 0.1702893
#
# isState_Washington                   -6.1014e-01  1.0609e-01  -5.7513 8.858e-09
#
# isState_West_Virginia                 1.1805e-01  6.0529e-02   1.9502 0.0511509
#
# isState_Wisconsin                    -1.9779e-01  5.2283e-02  -3.7830 0.0001549
#
# isState_Wyoming                      -2.7649e-01  1.5425e-01  -1.7925 0.0730507
#
#
#
# (Intercept)                          *
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev                *
#
# MaskMandates2MonthsPrev              ***
#
# MobilityResidual2MonthsPrev          *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                *
#
# isMonthAndYear_2020_8                ***
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   **
#
# isState_Colorado                     **
#
# isState_Connecticut                  **
#
# isState_Delaware                     *
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       .
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                ***
#
# isState_Michigan
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      *
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York                     *
#
# isState_North_Carolina               ***
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         *
#
# isState_Vermont                      *
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia                .
#
# isState_Wisconsin                    ***
#
# isState_Wyoming                      .
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
predictorsHere=[p.replace('Reduction','Residual') for p in predictors]

for p in predictorsHere:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelExcessPctMobilityResidual,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.8165 [0.7598, 0.8774] per 10 RH percent
# log-linear estimate: -2.027700e-02 [-1.307968e-02, -2.747432e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.8268 [0.7097, 0.9631] per 10 Oxford Stringency Index units
# log-linear estimate: -1.902200e-02 [-3.755756e-03, -3.428824e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.7071 [0.5997, 0.8337] per 1
# log-linear estimate: -3.466400e-01 [-1.819079e-01, -5.113721e-01] per 1 '
#
#
#
# MobilityResidual2MonthsPrev
# multiplicative estimate: 0.9752 [0.9555, 0.9953] per 1
# log-linear estimate: -2.511500e-02 [-4.664360e-03, -4.556564e-02] per 1 '
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9292 [0.9139, 0.9447] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -7.344000e-08 [-5.685350e-08, -9.002650e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9634 [0.8653, 1.0727] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -3.724400e-03 [7.018164e-03, -1.446696e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9650 [0.9495, 0.9807] per 10000 covid death 2 months previous
# log-linear estimate: -3.562400e-06 [-1.943969e-06, -5.180831e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.7390 [0.6545, 0.8344] per 10 degree Fahrenheit
# log-linear estimate: -3.024700e-02 [-1.810637e-02, -4.238763e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.8803 [0.7275, 1.0654] per 10 boosted rate percent
# log-linear estimate: -1.274400e-02 [6.330524e-03, -3.181852e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.6358 [0.5445, 0.7424] per 10 vaccination rate percent
# log-linear estimate: -4.528300e-02 [-2.978528e-02, -6.078072e-02] per 1 vaccination rate percent'

# %% [markdown]
# It may be of interest to see the result when no controls are used and excess death pct is simply regressed vs. RH. Such an approach is obviously far more vulnerable to objections regarding confounding, but may still be worth examining.

# %%
modelStringExcessPctVsRHUnadjusted='ExcessDeathCountCurrent~offset(log(ExpectedDeathCountCurrent))+RelativeHumidity2MonthsPrev'
negBinModelExcessPctVsRHUnadjusted,_=runNegBinModel(modelStringExcessPctVsRHUnadjusted,panelDF)
print(negBinModelExcessPctVsRHUnadjusted)
# Out:
# z test of coefficients:
#
#
#
#                               Estimate Std. Error z value  Pr(>|z|)
#
# (Intercept)                 -0.7071692  0.1577801  -4.482 7.395e-06 ***
#
# RelativeHumidity2MonthsPrev -0.0155434  0.0025768  -6.032 1.619e-09 ***
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
for p in ['RelativeHumidity2MonthsPrev']:#predictors:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelExcessPctVsRHUnadjusted,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.8560 [0.8139, 0.9004] per 10 RH percent
# log-linear estimate: -1.554340e-02 [-1.049287e-02, -2.059393e-02] per 1 RH percent'

# %% [markdown]
# Here we examine how sensitive the result is to the choice of controls. It would obviously be highly inappropriate statistical methodology to search systematically over a large number of combinations of controls in search of a particular result. Such a seach is presented here only to make the point that even if one were to do so in search of the combination of controls which is most unfavorable to the conclusion that RH is significant, no combo would be found where the 95% CI contains the null (0).

# %%
controls=list(predictors)
controls.remove(primaryVariableStudied)

totalNumControls=len(controls) + 2

numCombinations=numpy.power(2,totalNumControls)

estimatesForControlCombos=[]
stdErrsForControlCombos=[]

controlCombos=[]

doControlCombos=True

if (doControlCombos):
    rng=range(numCombinations)
    print('numCombinations tested',numCombinations)
else:
    rng=[]

    
for combination in range(numCombinations):
    if (combination%10==0):
        print('combination',combination)
        
    def reverse(strng):
        strngRev = [strng[i] for i in range(len(strng)-1, -1, -1)]
        return "".join(strngRev)
    
    combinationBinary=reverse(bin(combination)[2:])
    
    controlsUsedHere=[]
    def isIncluded(i):
        if (len(combinationBinary) <= i):
            return False
        return combinationBinary[i]=='1'
    
    includeTimeFixedEffect=False
    includeStateFixedEffect=False
    for i in range(totalNumControls):
        if (i==totalNumControls-1):
            if (isIncluded(i)):
                includeTimeFixedEffect=True
        elif (i==totalNumControls-2):
            if (isIncluded(i)):
                includeStateFixedEffect=True
        else:
            if (isIncluded(i)):
                controlsUsedHere.append(controls[i])
    
    predictorsHere=controlsUsedHere + [primaryVariableStudied]
    modelStringHere=outcome + '~' + "+".join(predictorsHere )
    
    if (includeTimeFixedEffect):
        modelStringHere=modelStringHere + '+' + '+'.join(timeFixedParamPredictors)
    if (includeStateFixedEffect):
        modelStringHere=modelStringHere + '+' + '+'.join(stateFixedParamPredictors)
    addOffset=True

    if (addOffset):
        if (modelStringHere.find('ExcessDeathCountCurrent') != -1):
            modelStringHere=modelStringHere + "+offset(log(ExpectedDeathCountCurrent))"
        else:
            modelStringHere=modelStringHere + "+offset(log(StatePopulation))"
            
    panelDF_R = pandas2ri.py2ri(panelDF)#[[outcome,'State','MonthAndYear','StatePopulation','ExpectedDeathCountCurrent'] + predictors + fixedEffectPredictors ])  
    negBinRes=MASS.glm_nb(modelStringHere,data=panelDF_R)
    negBinCoefTest=lmtest.coeftest(negBinRes,vcov=sandwich.vcovCL(negBinRes,cluster=panelDF["State"].values))  
    estimatesForControlCombos.append(getEstimate(negBinCoefTest,primaryVariableStudied))
    stdErrsForControlCombos.append(getStdError(negBinCoefTest,primaryVariableStudied))
    controlCombos.append(modelStringHere + "," + str(includeTimeFixedEffect) + "," + str(includeStateFixedEffect))
    del panelDF_R
    gc.collect()

if (doControlCombos):
    estimatesForControlCombos=numpy.array(estimatesForControlCombos)
    stdErrsForControlCombos=numpy.array(stdErrsForControlCombos)
    #print(estimatesForControlCombos)
    #print(stdErrsForControlCombos)
    
    ciLower95Pct=estimatesForControlCombos - 1.96*stdErrsForControlCombos
    ciUpper95Pct=estimatesForControlCombos + 1.96*stdErrsForControlCombos

#ratiosForControlCombos=numpy.divide(estimatesForControlCombos,stdErrsForControlCombos)
    print(primaryVariableStudied + ':\n')
    print('max estimate',numpy.max(estimatesForControlCombos))
    print('min estimate',numpy.min(estimatesForControlCombos))
    print('max stderr',numpy.max(stdErrsForControlCombos))
    print('min stderr',numpy.min(stdErrsForControlCombos))
    print('max lower bound 95% CI',numpy.max(ciLower95Pct))
    print('min lower bound 95% CI',numpy.min(ciLower95Pct))
    print('max upper bound 95% CI',numpy.max(ciUpper95Pct))
    print('min upper bound 95% CI',numpy.min(ciUpper95Pct))
# Out:
# numCombinations tested 2048
# combination 0
# combination 10
# combination 20
# combination 30
# combination 40
# combination 50
# combination 60
# combination 70
# combination 80
# combination 90
# combination 100
# combination 110
# combination 120
# combination 130
# combination 140
# combination 150
# combination 160
# combination 170
# combination 180
# combination 190
# combination 200
# combination 210
# combination 220
# combination 230
# combination 240
# combination 250
# combination 260
# combination 270
# combination 280
# combination 290
# combination 300
# combination 310
# combination 320
# combination 330
# combination 340
# combination 350
# combination 360
# combination 370
# combination 380
# combination 390
# combination 400
# combination 410
# combination 420
# combination 430
# combination 440
# combination 450
# combination 460
# combination 470
# combination 480
# combination 490
# combination 500
# combination 510
# combination 520
# combination 530
# combination 540
# combination 550
# combination 560
# combination 570
# combination 580
# combination 590
# combination 600
# combination 610
# combination 620
# combination 630
# combination 640
# combination 650
# combination 660
# combination 670
# combination 680
# combination 690
# combination 700
# combination 710
# combination 720
# combination 730
# combination 740
# combination 750
# combination 760
# combination 770
# combination 780
# combination 790
# combination 800
# combination 810
# combination 820
# combination 830
# combination 840
# combination 850
# combination 860
# combination 870
# combination 880
# combination 890
# combination 900
# combination 910
# combination 920
# combination 930
# combination 940
# combination 950
# combination 960
# combination 970
# combination 980
# combination 990
# combination 1000
# combination 1010
# combination 1020
# combination 1030
# combination 1040
# combination 1050
# combination 1060
# combination 1070
# combination 1080
# combination 1090
# combination 1100
# combination 1110
# combination 1120
# combination 1130
# combination 1140
# combination 1150
# combination 1160
# combination 1170
# combination 1180
# combination 1190
# combination 1200
# combination 1210
# combination 1220
# combination 1230
# combination 1240
# combination 1250
# combination 1260
# combination 1270
# combination 1280
# combination 1290
# combination 1300
# combination 1310
# combination 1320
# combination 1330
# combination 1340
# combination 1350
# combination 1360
# combination 1370
# combination 1380
# combination 1390
# combination 1400
# combination 1410
# combination 1420
# combination 1430
# combination 1440
# combination 1450
# combination 1460
# combination 1470
# combination 1480
# combination 1490
# combination 1500
# combination 1510
# combination 1520
# combination 1530
# combination 1540
# combination 1550
# combination 1560
# combination 1570
# combination 1580
# combination 1590
# combination 1600
# combination 1610
# combination 1620
# combination 1630
# combination 1640
# combination 1650
# combination 1660
# combination 1670
# combination 1680
# combination 1690
# combination 1700
# combination 1710
# combination 1720
# combination 1730
# combination 1740
# combination 1750
# combination 1760
# combination 1770
# combination 1780
# combination 1790
# combination 1800
# combination 1810
# combination 1820
# combination 1830
# combination 1840
# combination 1850
# combination 1860
# combination 1870
# combination 1880
# combination 1890
# combination 1900
# combination 1910
# combination 1920
# combination 1930
# combination 1940
# combination 1950
# combination 1960
# combination 1970
# combination 1980
# combination 1990
# combination 2000
# combination 2010
# combination 2020
# combination 2030
# combination 2040
# RelativeHumidity2MonthsPrev:
#
# max estimate -0.0084333
# min estimate -0.041508
# max stderr 0.0049822
# min stderr 0.0022695
# max lower bound 95% CI -0.013755739999999999
# min lower bound 95% CI -0.048055184
# max upper bound 95% CI -0.0029218639999999997
# min upper bound 95% CI -0.03570046

# %% [markdown]
# RH remains significant whether we use data from the first half or the second half of the pandemic, although the association is stronger in the first half (pre-vax) period. It is possible that vaccines have dampened the magnitude of the association.

# %%
import datetime
panelDFThroughMarch2021=panelDF[panelDF['MonthAndYearObj'] <= datetime.date(2021,3,1)]
negBinModelThroughMarch21Coef,_=runNegBinModel(modelStringExcessPct.replace('VaxRate2MonthsPrev','').replace("+BoostedRate2MonthsPrev",''),panelDFThroughMarch2021)
print(negBinModelThroughMarch21Coef)
print(panelDFThroughMarch2021.shape)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error z value  Pr(>|z|)
#
# (Intercept)                           3.2817e+00  8.7492e-01  3.7509 0.0001762
#
# RelativeHumidity2MonthsPrev          -2.8817e-02  4.9458e-03 -5.8265 5.659e-09
#
# Stringency2MonthsPrev                -8.2797e-03  7.8758e-03 -1.0513 0.2931263
#
# MaskMandates2MonthsPrev              -3.7773e-01  1.4327e-01 -2.6364 0.0083783
#
# MobilityReduction2MonthsPrev         -3.4812e-02  1.4005e-02 -2.4856 0.0129335
#
# CumulCasesPer330Mill3MonthsPrev      -1.0727e-07  2.1770e-08 -4.9273 8.339e-07
#
# DeviationFrom68Fahrenheit2MonthsPrev -9.8614e-03  6.7233e-03 -1.4668 0.1424421
#
# CovidDeathsPer330Mill2MonthsPrev     -2.5926e-06  1.0842e-06 -2.3912 0.0167922
#
# FahrenheitTemperature2MonthsPrev     -4.6537e-02  8.4882e-03 -5.4825 4.192e-08
#
# isMonthAndYear_2020_10                1.7840e+00  2.9347e-01  6.0789 1.210e-09
#
# isMonthAndYear_2020_11                2.2379e+00  2.5842e-01  8.6596 < 2.2e-16
#
# isMonthAndYear_2020_12                2.3953e+00  2.3234e-01 10.3091 < 2.2e-16
#
# isMonthAndYear_2020_6                 4.9085e-01  3.5576e-01  1.3797 0.1676701
#
# isMonthAndYear_2020_7                 8.0947e-01  2.9316e-01  2.7612 0.0057585
#
# isMonthAndYear_2020_8                 1.1082e+00  2.6543e-01  4.1750 2.979e-05
#
# isMonthAndYear_2020_9                 1.4575e+00  2.8518e-01  5.1110 3.205e-07
#
# isMonthAndYear_2021_1                 2.2311e+00  2.8303e-01  7.8826 3.206e-15
#
# isMonthAndYear_2021_2                 1.5409e+00  3.7006e-01  4.1639 3.129e-05
#
# isMonthAndYear_2021_3                 1.1636e+00  5.0289e-01  2.3138 0.0206774
#
# isState_Alabama                       1.0930e+00  1.0929e-01 10.0010 < 2.2e-16
#
# isState_Alaska                       -8.0795e-01  2.4823e-01 -3.2549 0.0011343
#
# isState_Arizona                       3.1157e-01  2.0835e-01  1.4954 0.1348077
#
# isState_Arkansas                      8.2144e-01  6.2592e-02 13.1237 < 2.2e-16
#
# isState_California                    5.5971e-01  2.1110e-01  2.6514 0.0080150
#
# isState_Colorado                     -9.3812e-01  1.6115e-01 -5.8216 5.829e-09
#
# isState_Connecticut                  -2.8293e-01  1.3068e-01 -2.1650 0.0303876
#
# isState_Delaware                      2.0214e-01  1.0257e-01  1.9708 0.0487491
#
# isState_District_of_Columbia          7.5264e-01  5.2450e-01  1.4349 0.1513014
#
# isState_Florida                       9.9478e-01  2.2298e-01  4.4613 8.147e-06
#
# isState_Georgia                       7.2904e-01  1.0410e-01  7.0030 2.506e-12
#
# isState_Hawaii                       -4.6945e-02  5.3402e-01 -0.0879 0.9299496
#
# isState_Idaho                        -1.6843e+00  2.0221e-01 -8.3296 < 2.2e-16
#
# isState_Illinois                      2.3548e-01  6.4105e-02  3.6733 0.0002394
#
# isState_Indiana                      -2.7873e-01  6.3277e-02 -4.4050 1.058e-05
#
# isState_Iowa                         -3.6312e-01  1.1289e-01 -3.2166 0.0012973
#
# isState_Kentucky                      1.1650e-01  7.9458e-02  1.4662 0.1425952
#
# isState_Louisiana                     1.5589e+00  1.5387e-01 10.1312 < 2.2e-16
#
# isState_Maine                        -1.5019e+00  1.5546e-01 -9.6613 < 2.2e-16
#
# isState_Maryland                      3.7779e-01  1.5371e-01  2.4577 0.0139812
#
# isState_Massachusetts                -4.9021e-01  1.9040e-01 -2.5747 0.0100325
#
# isState_Michigan                     -1.3432e-01  7.7646e-02 -1.7299 0.0836408
#
# isState_Minnesota                    -4.2526e-01  1.0543e-01 -4.0336 5.492e-05
#
# isState_Mississippi                   1.5217e+00  1.2056e-01 12.6212 < 2.2e-16
#
# isState_Missouri                     -3.2190e-01  1.1846e-01 -2.7174 0.0065805
#
# isState_Montana                      -1.0828e+00  1.7309e-01 -6.2553 3.967e-10
#
# isState_Nebraska                     -5.5305e-01  1.2766e-01 -4.3323 1.475e-05
#
# isState_Nevada                       -5.6050e-01  1.6971e-01 -3.3028 0.0009574
#
# isState_New_Hampshire                -1.4979e+00  1.5552e-01 -9.6315 < 2.2e-16
#
# isState_New_Jersey                   -1.4261e-02  1.7118e-01 -0.0833 0.9336014
#
# isState_New_Mexico                    2.0615e-02  1.9157e-01  0.1076 0.9143027
#
# isState_New_York                      2.7127e-01  1.5915e-01  1.7045 0.0882901
#
# isState_North_Carolina                3.7404e-01  8.4236e-02  4.4404 8.978e-06
#
# isState_North_Dakota                 -3.3952e-03  1.5234e-01 -0.0223 0.9822193
#
# isState_Ohio                         -5.3444e-01  6.4762e-02 -8.2524 < 2.2e-16
#
# isState_Oklahoma                     -1.6097e-01  1.3936e-01 -1.1550 0.2480826
#
# isState_Oregon                       -7.3887e-01  1.0947e-01 -6.7495 1.483e-11
#
# isState_Pennsylvania                 -5.2365e-01  8.5382e-02 -6.1330 8.622e-10
#
# isState_Rhode_Island                  7.7110e-01  1.8347e-01  4.2029 2.635e-05
#
# isState_South_Carolina                6.8228e-01  1.0561e-01  6.4601 1.046e-10
#
# isState_South_Dakota                 -4.1198e-01  2.1284e-01 -1.9357 0.0529061
#
# isState_Tennessee                     3.0037e-01  9.7940e-02  3.0669 0.0021631
#
# isState_Texas                         1.2539e+00  1.1283e-01 11.1139 < 2.2e-16
#
# isState_Utah                         -1.1850e+00  1.8173e-01 -6.5206 7.002e-11
#
# isState_Vermont                      -6.8054e-01  2.2488e-01 -3.0263 0.0024756
#
# isState_Virginia                      2.9376e-01  1.1131e-01  2.6392 0.0083093
#
# isState_Washington                   -1.0404e+00  1.2726e-01 -8.1755 2.947e-16
#
# isState_West_Virginia                -1.6985e-01  9.0737e-02 -1.8719 0.0612256
#
# isState_Wisconsin                    -3.9051e-01  7.7911e-02 -5.0122 5.381e-07
#
# isState_Wyoming                      -5.4556e-01  2.4001e-01 -2.2730 0.0230246
#
#
#
# (Intercept)                          ***
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              **
#
# MobilityReduction2MonthsPrev         *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     *
#
# FahrenheitTemperature2MonthsPrev     ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                **
#
# isMonthAndYear_2020_8                ***
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3                *
#
# isState_Alabama                      ***
#
# isState_Alaska                       **
#
# isState_Arizona
#
# isState_Arkansas                     ***
#
# isState_California                   **
#
# isState_Colorado                     ***
#
# isState_Connecticut                  *
#
# isState_Delaware                     *
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana                      ***
#
# isState_Iowa                         **
#
# isState_Kentucky
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland                     *
#
# isState_Massachusetts                *
#
# isState_Michigan                     .
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     **
#
# isState_Montana                      ***
#
# isState_Nebraska                     ***
#
# isState_Nevada                       ***
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico
#
# isState_New_York                     .
#
# isState_North_Carolina               ***
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota                 .
#
# isState_Tennessee                    **
#
# isState_Texas                        ***
#
# isState_Utah                         ***
#
# isState_Vermont                      **
#
# isState_Virginia                     **
#
# isState_Washington                   ***
#
# isState_West_Virginia                .
#
# isState_Wisconsin                    ***
#
# isState_Wyoming                      *
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
#
# (561, 292)

# %%
for p in predictors:
    if (p.find('Boosted') != -1):
        continue
    if (p.find('Vax') != -1):
        continue
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelThroughMarch21Coef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.7496 [0.6804, 0.8259] per 10 RH percent
# log-linear estimate: -2.881700e-02 [-1.912323e-02, -3.851077e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9205 [0.7889, 1.0742] per 10 Oxford Stringency Index units
# log-linear estimate: -8.279700e-03 [7.156868e-03, -2.371627e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.6854 [0.5176, 0.9076] per 1
# log-linear estimate: -3.777300e-01 [-9.692080e-02, -6.585392e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7060 [0.5365, 0.9290] per 10 Mobility reduction percent
# log-linear estimate: -3.481200e-02 [-7.362200e-03, -6.226180e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.8983 [0.8608, 0.9374] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -1.072700e-07 [-6.460080e-08, -1.499392e-07] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9061 [0.7942, 1.0337] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -9.861400e-03 [3.316268e-03, -2.303907e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9744 [0.9539, 0.9953] per 10000 covid death 2 months previous
# log-linear estimate: -2.592600e-06 [-4.675680e-07, -4.717632e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.6279 [0.5317, 0.7416] per 10 degree Fahrenheit
# log-linear estimate: -4.653700e-02 [-2.990013e-02, -6.317387e-02] per 1 degree Fahrenheit'

# %%
panelDFPostApril2021=panelDF[panelDF['MonthAndYearObj'] > datetime.date(2021,3,1)]
print(panelDFPostApril2021.shape)
negBinModelPostApril21Coef,_=runNegBinModel(modelStringExcessPct,panelDFPostApril2021)
print(negBinModelPostApril21Coef)
# Out:
# (561, 292)
#
#
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           7.2056e+00  1.1116e+00   6.4824 9.030e-11
#
# RelativeHumidity2MonthsPrev          -9.9030e-03  3.9163e-03  -2.5287 0.0114492
#
# Stringency2MonthsPrev                 4.0452e-03  8.5345e-03   0.4740 0.6355134
#
# MaskMandates2MonthsPrev              -3.9032e-01  1.3874e-01  -2.8133 0.0049039
#
# MobilityReduction2MonthsPrev          6.2499e-03  7.7221e-03   0.8094 0.4183070
#
# CumulCasesPer330Mill3MonthsPrev      -1.0837e-07  1.3731e-08  -7.8920 2.974e-15
#
# DeviationFrom68Fahrenheit2MonthsPrev -2.2908e-03  5.8196e-03  -0.3936 0.6938462
#
# CovidDeathsPer330Mill2MonthsPrev     -7.1724e-06  1.2485e-06  -5.7450 9.193e-09
#
# FahrenheitTemperature2MonthsPrev     -1.3343e-02  6.2885e-03  -2.1218 0.0338565
#
# BoostedRate2MonthsPrev               -1.4321e-02  1.2569e-02  -1.1394 0.2545416
#
# VaxRate2MonthsPrev                   -2.3694e-02  1.1003e-02  -2.1534 0.0312874
#
# isMonthAndYear_2021_10               -1.7414e+00  4.2283e-01  -4.1185 3.813e-05
#
# isMonthAndYear_2021_11               -1.3680e+00  3.6028e-01  -3.7970 0.0001464
#
# isMonthAndYear_2021_12               -7.1484e-01  3.0412e-01  -2.3505 0.0187458
#
# isMonthAndYear_2021_4                -5.9683e+00  7.5088e-01  -7.9485 1.889e-15
#
# isMonthAndYear_2021_5                -5.2867e+00  6.3810e-01  -8.2850 < 2.2e-16
#
# isMonthAndYear_2021_6                -4.6961e+00  5.2507e-01  -8.9438 < 2.2e-16
#
# isMonthAndYear_2021_7                -3.8209e+00  4.5545e-01  -8.3893 < 2.2e-16
#
# isMonthAndYear_2021_8                -2.4219e+00  4.4517e-01  -5.4404 5.316e-08
#
# isMonthAndYear_2021_9                -1.8774e+00  4.4829e-01  -4.1878 2.816e-05
#
# isMonthAndYear_2022_1                 1.8109e-02  1.6479e-01   0.1099 0.9124937
#
# isState_Alabama                       7.2652e-01  1.1206e-01   6.4833 8.972e-11
#
# isState_Alaska                        5.6099e-01  2.0777e-01   2.7000 0.0069330
#
# isState_Arizona                       1.0097e+00  1.9946e-01   5.0620 4.148e-07
#
# isState_Arkansas                      9.8637e-01  8.5032e-02  11.6000 < 2.2e-16
#
# isState_California                   -3.7791e-01  1.9015e-01  -1.9875 0.0468708
#
# isState_Colorado                     -2.6052e-01  1.2134e-01  -2.1470 0.0317946
#
# isState_Connecticut                  -1.2514e+00  2.3204e-01  -5.3930 6.929e-08
#
# isState_Delaware                     -1.4797e-01  1.0230e-01  -1.4464 0.1480682
#
# isState_District_of_Columbia         -1.5355e+00  3.5703e-01  -4.3009 1.701e-05
#
# isState_Florida                       8.9319e-01  1.3914e-01   6.4194 1.368e-10
#
# isState_Georgia                       5.1702e-01  8.3498e-02   6.1920 5.940e-10
#
# isState_Hawaii                       -3.2955e+00  4.8878e-01  -6.7423 1.559e-11
#
# isState_Idaho                         7.2822e-02  1.2431e-01   0.5858 0.5579991
#
# isState_Illinois                      5.2075e-02  1.0367e-01   0.5023 0.6154424
#
# isState_Indiana                       1.7077e-01  5.2689e-02   3.2411 0.0011908
#
# isState_Iowa                         -8.2438e-02  5.9232e-02  -1.3918 0.1639877
#
# isState_Kentucky                      8.4306e-01  7.1947e-02  11.7178 < 2.2e-16
#
# isState_Louisiana                     5.9315e-01  1.7121e-01   3.4644 0.0005314
#
# isState_Maine                        -1.9098e+00  3.5464e-01  -5.3853 7.233e-08
#
# isState_Maryland                     -1.9486e+00  2.3430e-01  -8.3166 < 2.2e-16
#
# isState_Massachusetts                -2.0873e+00  2.1411e-01  -9.7490 < 2.2e-16
#
# isState_Michigan                     -1.4675e-01  1.2366e-01  -1.1867 0.2353390
#
# isState_Minnesota                    -4.5307e-01  9.6512e-02  -4.6944 2.674e-06
#
# isState_Mississippi                   8.1647e-01  1.1641e-01   7.0135 2.325e-12
#
# isState_Missouri                     -2.6794e-01  7.3986e-02  -3.6215 0.0002929
#
# isState_Montana                       5.2425e-01  1.2873e-01   4.0724 4.653e-05
#
# isState_Nebraska                     -4.0449e-01  7.3876e-02  -5.4752 4.369e-08
#
# isState_Nevada                        5.8012e-01  1.6389e-01   3.5397 0.0004006
#
# isState_New_Hampshire                -2.5357e+00  2.4439e-01 -10.3757 < 2.2e-16
#
# isState_New_Jersey                   -1.0792e+00  1.4251e-01  -7.5729 3.650e-14
#
# isState_New_Mexico                    5.1213e-01  1.7792e-01   2.8783 0.0039978
#
# isState_New_York                     -4.7940e-01  2.1655e-01  -2.2138 0.0268392
#
# isState_North_Carolina               -1.0145e-01  9.7202e-02  -1.0437 0.2966149
#
# isState_North_Dakota                  5.0453e-01  2.0336e-01   2.4810 0.0131023
#
# isState_Ohio                         -7.4261e-01  1.0666e-01  -6.9623 3.348e-12
#
# isState_Oklahoma                      5.8861e-01  6.2109e-02   9.4770 < 2.2e-16
#
# isState_Oregon                       -1.1533e+00  3.0255e-01  -3.8119 0.0001379
#
# isState_Pennsylvania                 -9.2148e-01  1.3782e-01  -6.6860 2.293e-11
#
# isState_Rhode_Island                 -1.1227e-01  2.0647e-01  -0.5438 0.5865896
#
# isState_South_Carolina                9.2826e-01  7.6424e-02  12.1462 < 2.2e-16
#
# isState_South_Dakota                  8.7055e-01  1.5962e-01   5.4539 4.927e-08
#
# isState_Tennessee                     1.2596e+00  1.0578e-01  11.9083 < 2.2e-16
#
# isState_Texas                         3.3496e-01  8.9189e-02   3.7556 0.0001729
#
# isState_Utah                          5.4129e-01  1.5876e-01   3.4094 0.0006510
#
# isState_Vermont                      -1.9775e+00  4.2643e-01  -4.6374 3.528e-06
#
# isState_Virginia                     -7.3131e-01  1.8725e-01  -3.9054 9.405e-05
#
# isState_Washington                   -1.1961e+00  2.9561e-01  -4.0461 5.207e-05
#
# isState_West_Virginia                 2.7845e-01  1.0689e-01   2.6050 0.0091873
#
# isState_Wisconsin                    -7.6986e-02  7.1166e-02  -1.0818 0.2793480
#
# isState_Wyoming                       3.5522e-01  1.3321e-01   2.6665 0.0076639
#
#
#
# (Intercept)                          ***
#
# RelativeHumidity2MonthsPrev          *
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              **
#
# MobilityReduction2MonthsPrev
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     *
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   *
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               *
#
# isMonthAndYear_2021_4                ***
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1
#
# isState_Alabama                      ***
#
# isState_Alaska                       **
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   *
#
# isState_Colorado                     *
#
# isState_Connecticut                  ***
#
# isState_Delaware
#
# isState_District_of_Columbia         ***
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       ***
#
# isState_Idaho
#
# isState_Illinois
#
# isState_Indiana                      **
#
# isState_Iowa
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland                     ***
#
# isState_Massachusetts                ***
#
# isState_Michigan
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      ***
#
# isState_Nebraska                     ***
#
# isState_Nevada                       ***
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey                   ***
#
# isState_New_Mexico                   **
#
# isState_New_York                     *
#
# isState_North_Carolina
#
# isState_North_Dakota                 *
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island
#
# isState_South_Carolina               ***
#
# isState_South_Dakota                 ***
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         ***
#
# isState_Vermont                      ***
#
# isState_Virginia                     ***
#
# isState_Washington                   ***
#
# isState_West_Virginia                **
#
# isState_Wisconsin
#
# isState_Wyoming                      **
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
for p in predictors:
    
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelPostApril21Coef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity2MonthsPrev
# multiplicative estimate: 0.9057 [0.8388, 0.9780] per 10 RH percent
# log-linear estimate: -9.903000e-03 [-2.227052e-03, -1.757895e-02] per 1 RH percent'
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 1.0413 [1.2309, 0.8809] per 10 Oxford Stringency Index units
# log-linear estimate: 4.045200e-03 [-1.268242e-02, 2.077282e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.6768 [0.5157, 0.8883] per 1
# log-linear estimate: -3.903200e-01 [-1.183896e-01, -6.622504e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 1.0645 [1.2384, 0.9150] per 10 Mobility reduction percent
# log-linear estimate: 6.249900e-03 [-8.885416e-03, 2.138522e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.8973 [0.8735, 0.9218] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -1.083700e-07 [-8.145724e-08, -1.352828e-07] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9774 [0.8720, 1.0954] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -2.290800e-03 [9.115616e-03, -1.369722e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9308 [0.9083, 0.9538] per 10000 covid death 2 months previous
# log-linear estimate: -7.172400e-06 [-4.725340e-06, -9.619460e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.8751 [0.7736, 0.9899] per 10 degree Fahrenheit
# log-linear estimate: -1.334300e-02 [-1.017540e-03, -2.566846e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.8666 [0.6774, 1.1086] per 10 boosted rate percent
# log-linear estimate: -1.432100e-02 [1.031424e-02, -3.895624e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.7890 [0.6360, 0.9789] per 10 vaccination rate percent
# log-linear estimate: -2.369400e-02 [-2.128120e-03, -4.525988e-02] per 1 vaccination rate percent'

# %% [markdown]
# If we use RH with a 1 month or 0 month lag instead of a 2 month lag, the coefficient shrinks in a pattern which is consistent with known lags between covid infection and death.

# %%
negBinModelUsingHumidity1MonthPrevCoef,_=runNegBinModel(modelStringExcessPct.replace('RelativeHumidity2MonthsPrev','RelativeHumidity1MonthsPrev'),panelDF)
print(negBinModelUsingHumidity1MonthPrevCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           7.8435e-01  6.3906e-01   1.2274 0.2196906
#
# RelativeHumidity1MonthsPrev          -1.5174e-02  2.6585e-03  -5.7078 1.144e-08
#
# Stringency2MonthsPrev                -5.3084e-03  5.9537e-03  -0.8916 0.3726017
#
# MaskMandates2MonthsPrev              -3.3393e-01  8.5153e-02  -3.9215 8.800e-05
#
# MobilityReduction2MonthsPrev         -2.4721e-02  1.1174e-02  -2.2124 0.0269382
#
# CumulCasesPer330Mill3MonthsPrev      -7.3301e-08  8.2294e-09  -8.9071 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev -2.3578e-03  5.8689e-03  -0.4017 0.6878749
#
# CovidDeathsPer330Mill2MonthsPrev     -3.1589e-06  7.9911e-07  -3.9531 7.715e-05
#
# FahrenheitTemperature2MonthsPrev     -2.3401e-02  6.0418e-03  -3.8731 0.0001075
#
# BoostedRate2MonthsPrev               -6.0274e-03  1.0560e-02  -0.5708 0.5681568
#
# VaxRate2MonthsPrev                   -4.5953e-02  8.1767e-03  -5.6199 1.910e-08
#
# isMonthAndYear_2020_10                1.0149e+00  1.9316e-01   5.2540 1.488e-07
#
# isMonthAndYear_2020_11                1.6525e+00  1.5129e-01  10.9230 < 2.2e-16
#
# isMonthAndYear_2020_12                1.9001e+00  1.3421e-01  14.1579 < 2.2e-16
#
# isMonthAndYear_2020_6                 1.4471e-01  2.5877e-01   0.5592 0.5760171
#
# isMonthAndYear_2020_7                 3.4707e-01  2.1441e-01   1.6187 0.1055021
#
# isMonthAndYear_2020_8                 5.2516e-01  1.9935e-01   2.6343 0.0084303
#
# isMonthAndYear_2020_9                 6.3849e-01  2.2024e-01   2.8991 0.0037422
#
# isMonthAndYear_2021_1                 1.7896e+00  1.6225e-01  11.0301 < 2.2e-16
#
# isMonthAndYear_2021_10                5.6168e+00  5.8578e-01   9.5885 < 2.2e-16
#
# isMonthAndYear_2021_11                5.9334e+00  6.1935e-01   9.5801 < 2.2e-16
#
# isMonthAndYear_2021_12                6.2111e+00  6.6835e-01   9.2932 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.1455e+00  2.2051e-01   5.1947 2.051e-07
#
# isMonthAndYear_2021_3                 4.2383e-01  2.8105e-01   1.5080 0.1315511
#
# isMonthAndYear_2021_4                 8.1537e-01  3.0841e-01   2.6438 0.0081985
#
# isMonthAndYear_2021_5                 1.6020e+00  3.2185e-01   4.9776 6.438e-07
#
# isMonthAndYear_2021_6                 2.4773e+00  4.0488e-01   6.1186 9.439e-10
#
# isMonthAndYear_2021_7                 3.4373e+00  4.8323e-01   7.1131 1.135e-12
#
# isMonthAndYear_2021_8                 4.9596e+00  5.2249e-01   9.4922 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.5041e+00  5.5888e-01   9.8485 < 2.2e-16
#
# isMonthAndYear_2022_1                 6.9445e+00  6.9590e-01   9.9792 < 2.2e-16
#
# isMonthAndYear_2022_2                 6.6554e+00  7.3539e-01   9.0501 < 2.2e-16
#
# isState_Alabama                       7.9043e-01  7.5105e-02  10.5244 < 2.2e-16
#
# isState_Alaska                        5.8893e-02  1.9263e-01   0.3057 0.7598127
#
# isState_Arizona                       6.6622e-01  1.2081e-01   5.5147 3.495e-08
#
# isState_Arkansas                      7.1257e-01  4.4087e-02  16.1628 < 2.2e-16
#
# isState_California                    5.4334e-01  1.9313e-01   2.8134 0.0049019
#
# isState_Colorado                     -9.2221e-02  1.1203e-01  -0.8232 0.4104067
#
# isState_Connecticut                  -3.1344e-01  1.2507e-01  -2.5061 0.0122081
#
# isState_Delaware                      2.2490e-01  9.0112e-02   2.4958 0.0125681
#
# isState_District_of_Columbia          4.3963e-01  4.3426e-01   1.0124 0.3113635
#
# isState_Florida                       9.3819e-01  1.4731e-01   6.3688 1.906e-10
#
# isState_Georgia                       5.8445e-01  5.9152e-02   9.8805 < 2.2e-16
#
# isState_Hawaii                       -7.3773e-01  3.7582e-01  -1.9630 0.0496471
#
# isState_Idaho                        -7.0611e-01  1.1980e-01  -5.8941 3.768e-09
#
# isState_Illinois                      2.3167e-01  4.9169e-02   4.7116 2.458e-06
#
# isState_Indiana                      -4.9170e-02  3.4005e-02  -1.4459 0.1481931
#
# isState_Iowa                         -2.6554e-01  6.9029e-02  -3.8468 0.0001196
#
# isState_Kentucky                      5.0518e-01  5.1036e-02   9.8984 < 2.2e-16
#
# isState_Louisiana                     1.0584e+00  1.2325e-01   8.5876 < 2.2e-16
#
# isState_Maine                        -1.1391e+00  1.2274e-01  -9.2807 < 2.2e-16
#
# isState_Maryland                     -8.0714e-02  1.3428e-01  -0.6011 0.5477712
#
# isState_Massachusetts                -6.6413e-01  1.8490e-01  -3.5918 0.0003284
#
# isState_Michigan                      2.2875e-02  5.1376e-02   0.4452 0.6561411
#
# isState_Minnesota                    -2.0765e-01  7.3725e-02  -2.8166 0.0048537
#
# isState_Mississippi                   1.0677e+00  7.1543e-02  14.9245 < 2.2e-16
#
# isState_Missouri                     -3.4874e-01  7.0120e-02  -4.9735 6.575e-07
#
# isState_Montana                      -2.3393e-01  1.4082e-01  -1.6612 0.0966646
#
# isState_Nebraska                     -5.0746e-01  7.9730e-02  -6.3648 1.956e-10
#
# isState_Nevada                        1.2881e-01  9.1847e-02   1.4024 0.1607900
#
# isState_New_Hampshire                -1.4858e+00  8.7534e-02 -16.9735 < 2.2e-16
#
# isState_New_Jersey                   -1.4669e-01  1.4505e-01  -1.0113 0.3118847
#
# isState_New_Mexico                    6.6913e-01  1.3131e-01   5.0957 3.475e-07
#
# isState_New_York                      3.0870e-01  1.4945e-01   2.0656 0.0388689
#
# isState_North_Carolina                2.8527e-01  7.0933e-02   4.0217 5.778e-05
#
# isState_North_Dakota                  1.4338e-01  1.1686e-01   1.2269 0.2198431
#
# isState_Ohio                         -5.2351e-01  4.5511e-02 -11.5028 < 2.2e-16
#
# isState_Oklahoma                      1.5774e-01  5.2418e-02   3.0093 0.0026183
#
# isState_Oregon                       -3.9352e-01  9.4543e-02  -4.1624 3.150e-05
#
# isState_Pennsylvania                 -4.7261e-01  5.3020e-02  -8.9139 < 2.2e-16
#
# isState_Rhode_Island                  6.1343e-01  1.8908e-01   3.2442 0.0011778
#
# isState_South_Carolina                6.6538e-01  4.9039e-02  13.5683 < 2.2e-16
#
# isState_South_Dakota                  3.8306e-02  1.4087e-01   0.2719 0.7856814
#
# isState_Tennessee                     5.7371e-01  4.6246e-02  12.4056 < 2.2e-16
#
# isState_Texas                         9.3044e-01  8.6517e-02  10.7544 < 2.2e-16
#
# isState_Utah                         -1.1823e-01  1.0224e-01  -1.1564 0.2475346
#
# isState_Vermont                      -3.9611e-01  1.7693e-01  -2.2388 0.0251703
#
# isState_Virginia                      1.3012e-01  9.0263e-02   1.4416 0.1494113
#
# isState_Washington                   -5.5382e-01  1.0684e-01  -5.1838 2.174e-07
#
# isState_West_Virginia                 1.2032e-01  5.2566e-02   2.2889 0.0220842
#
# isState_Wisconsin                    -1.7692e-01  5.6619e-02  -3.1248 0.0017795
#
# isState_Wyoming                      -8.2532e-02  1.2789e-01  -0.6454 0.5186964
#
#
#
# (Intercept)
#
# RelativeHumidity1MonthsPrev          ***
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev         *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7
#
# isMonthAndYear_2020_8                **
#
# isMonthAndYear_2020_9                **
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   **
#
# isState_Colorado
#
# isState_Connecticut                  *
#
# isState_Delaware                     *
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       *
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                ***
#
# isState_Michigan
#
# isState_Minnesota                    **
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      .
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York                     *
#
# isState_North_Carolina               ***
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     **
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 **
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah
#
# isState_Vermont                      *
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia                *
#
# isState_Wisconsin                    **
#
# isState_Wyoming
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
predictorsHere=[p.replace('RelativeHumidity2MonthsPrev','RelativeHumidity1MonthsPrev') for p in predictors]
for p in predictorsHere:
    print(p)
    
    showMultiplicativeAssociationAndCI(negBinModelUsingHumidity1MonthPrevCoef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidity1MonthsPrev
# multiplicative estimate: 0.9849 [0.9798, 0.9901] per 1
# log-linear estimate: -1.517400e-02 [-9.963340e-03, -2.038466e-02] per 1 '
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9483 [0.8439, 1.0657] per 10 Oxford Stringency Index units
# log-linear estimate: -5.308400e-03 [6.360852e-03, -1.697765e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.7161 [0.6060, 0.8462] per 1
# log-linear estimate: -3.339300e-01 [-1.670301e-01, -5.008299e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7810 [0.6274, 0.9722] per 10 Mobility reduction percent
# log-linear estimate: -2.472100e-02 [-2.819960e-03, -4.662204e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9293 [0.9145, 0.9444] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -7.330100e-08 [-5.717138e-08, -8.943062e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9767 [0.8706, 1.0958] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -2.357800e-03 [9.145244e-03, -1.386084e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9689 [0.9538, 0.9842] per 10000 covid death 2 months previous
# log-linear estimate: -3.158900e-06 [-1.592644e-06, -4.725156e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.7914 [0.7030, 0.8908] per 10 degree Fahrenheit
# log-linear estimate: -2.340100e-02 [-1.155907e-02, -3.524293e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.9415 [0.7655, 1.1580] per 10 boosted rate percent
# log-linear estimate: -6.027400e-03 [1.467020e-02, -2.672500e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.6316 [0.5381, 0.7414] per 10 vaccination rate percent
# log-linear estimate: -4.595300e-02 [-2.992667e-02, -6.197933e-02] per 1 vaccination rate percent'

# %%
predictorsHere=[p.replace('RelativeHumidity2MonthsPrev','RelativeHumidityCurrent') for p in predictors]

negBinModelUsingHumidityCurrentCoef,_=runNegBinModel(modelStringExcessPct.replace('RelativeHumidity2MonthsPrev','RelativeHumidityCurrent'),panelDF)
print(negBinModelUsingHumidityCurrentCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           7.5158e-02  6.6116e-01   0.1137 0.9094946
#
# RelativeHumidityCurrent              -9.8666e-03  3.0377e-03  -3.2481 0.0011619
#
# Stringency2MonthsPrev                -3.9187e-03  6.0747e-03  -0.6451 0.5188749
#
# MaskMandates2MonthsPrev              -3.5155e-01  8.6276e-02  -4.0747 4.607e-05
#
# MobilityReduction2MonthsPrev         -2.6534e-02  1.1737e-02  -2.2606 0.0237843
#
# CumulCasesPer330Mill3MonthsPrev      -7.4693e-08  8.2335e-09  -9.0718 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev -9.4193e-04  6.1005e-03  -0.1544 0.8772933
#
# CovidDeathsPer330Mill2MonthsPrev     -2.6541e-06  7.8403e-07  -3.3852 0.0007112
#
# FahrenheitTemperature2MonthsPrev     -1.7929e-02  6.1692e-03  -2.9062 0.0036585
#
# BoostedRate2MonthsPrev               -5.5664e-03  1.0221e-02  -0.5446 0.5860212
#
# VaxRate2MonthsPrev                   -4.6910e-02  8.1673e-03  -5.7437 9.264e-09
#
# isMonthAndYear_2020_10                8.7512e-01  2.0024e-01   4.3702 1.241e-05
#
# isMonthAndYear_2020_11                1.5685e+00  1.5176e-01  10.3357 < 2.2e-16
#
# isMonthAndYear_2020_12                1.8515e+00  1.3789e-01  13.4277 < 2.2e-16
#
# isMonthAndYear_2020_6                 1.0968e-01  2.7346e-01   0.4011 0.6883453
#
# isMonthAndYear_2020_7                 2.4750e-01  2.2419e-01   1.1040 0.2695992
#
# isMonthAndYear_2020_8                 3.3405e-01  2.1222e-01   1.5741 0.1154758
#
# isMonthAndYear_2020_9                 4.7708e-01  2.3514e-01   2.0289 0.0424646
#
# isMonthAndYear_2021_1                 1.8362e+00  1.6151e-01  11.3691 < 2.2e-16
#
# isMonthAndYear_2021_10                5.6181e+00  5.8745e-01   9.5636 < 2.2e-16
#
# isMonthAndYear_2021_11                5.8362e+00  6.1360e-01   9.5115 < 2.2e-16
#
# isMonthAndYear_2021_12                6.3366e+00  6.6322e-01   9.5543 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.1645e+00  2.2115e-01   5.2656 1.398e-07
#
# isMonthAndYear_2021_3                 3.7002e-01  2.8349e-01   1.3053 0.1918063
#
# isMonthAndYear_2021_4                 8.1101e-01  3.0897e-01   2.6249 0.0086680
#
# isMonthAndYear_2021_5                 1.6110e+00  3.2142e-01   5.0121 5.384e-07
#
# isMonthAndYear_2021_6                 2.4599e+00  4.0133e-01   6.1293 8.829e-10
#
# isMonthAndYear_2021_7                 3.4561e+00  4.7118e-01   7.3349 2.219e-13
#
# isMonthAndYear_2021_8                 4.8707e+00  5.1570e-01   9.4449 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.4457e+00  5.5264e-01   9.8539 < 2.2e-16
#
# isMonthAndYear_2022_1                 7.0072e+00  6.9893e-01  10.0256 < 2.2e-16
#
# isMonthAndYear_2022_2                 6.7808e+00  7.4257e-01   9.1315 < 2.2e-16
#
# isState_Alabama                       7.3065e-01  8.1017e-02   9.0185 < 2.2e-16
#
# isState_Alaska                        1.1681e-01  1.8080e-01   0.6461 0.5182431
#
# isState_Arizona                       8.3425e-01  1.0894e-01   7.6580 1.888e-14
#
# isState_Arkansas                      6.5555e-01  5.0336e-02  13.0236 < 2.2e-16
#
# isState_California                    6.3649e-01  1.8384e-01   3.4622 0.0005357
#
# isState_Colorado                      7.1520e-02  1.1131e-01   0.6425 0.5205411
#
# isState_Connecticut                  -2.8196e-01  1.3237e-01  -2.1301 0.0331609
#
# isState_Delaware                      2.1680e-01  9.9409e-02   2.1809 0.0291922
#
# isState_District_of_Columbia          4.9567e-01  4.5667e-01   1.0854 0.2777385
#
# isState_Florida                       8.7702e-01  1.5073e-01   5.8183 5.944e-09
#
# isState_Georgia                       5.5058e-01  6.3499e-02   8.6708 < 2.2e-16
#
# isState_Hawaii                       -7.7862e-01  3.9186e-01  -1.9870 0.0469254
#
# isState_Idaho                        -5.8093e-01  1.2571e-01  -4.6213 3.813e-06
#
# isState_Illinois                      2.5732e-01  5.4330e-02   4.7363 2.177e-06
#
# isState_Indiana                      -6.6174e-02  3.2844e-02  -2.0148 0.0439243
#
# isState_Iowa                         -2.5875e-01  6.6763e-02  -3.8756 0.0001063
#
# isState_Kentucky                      4.6997e-01  5.6699e-02   8.2888 < 2.2e-16
#
# isState_Louisiana                     9.6088e-01  1.3405e-01   7.1682 7.597e-13
#
# isState_Maine                        -1.1245e+00  1.1515e-01  -9.7656 < 2.2e-16
#
# isState_Maryland                     -7.1320e-02  1.4283e-01  -0.4993 0.6175443
#
# isState_Massachusetts                -6.3308e-01  1.9973e-01  -3.1697 0.0015259
#
# isState_Michigan                      4.2618e-02  5.2090e-02   0.8182 0.4132667
#
# isState_Minnesota                    -1.4538e-01  8.3284e-02  -1.7456 0.0808743
#
# isState_Mississippi                   9.8283e-01  8.1658e-02  12.0359 < 2.2e-16
#
# isState_Missouri                     -3.9503e-01  6.5197e-02  -6.0590 1.369e-09
#
# isState_Montana                      -1.3237e-01  1.4392e-01  -0.9197 0.3577159
#
# isState_Nebraska                     -4.8132e-01  8.0800e-02  -5.9570 2.569e-09
#
# isState_Nevada                        2.9841e-01  1.0658e-01   2.8000 0.0051098
#
# isState_New_Hampshire                -1.4404e+00  8.4083e-02 -17.1307 < 2.2e-16
#
# isState_New_Jersey                   -1.0765e-01  1.5322e-01  -0.7026 0.4823139
#
# isState_New_Mexico                    8.4953e-01  1.2385e-01   6.8593 6.918e-12
#
# isState_New_York                      3.3393e-01  1.5746e-01   2.1208 0.0339412
#
# isState_North_Carolina                2.4730e-01  7.8303e-02   3.1583 0.0015871
#
# isState_North_Dakota                  2.7662e-01  1.2205e-01   2.2664 0.0234279
#
# isState_Ohio                         -5.4441e-01  3.8457e-02 -14.1564 < 2.2e-16
#
# isState_Oklahoma                      1.2435e-01  5.3394e-02   2.3289 0.0198656
#
# isState_Oregon                       -3.8363e-01  9.2472e-02  -4.1486 3.345e-05
#
# isState_Pennsylvania                 -4.9151e-01  5.6564e-02  -8.6895 < 2.2e-16
#
# isState_Rhode_Island                  6.4504e-01  2.0402e-01   3.1617 0.0015687
#
# isState_South_Carolina                6.1397e-01  5.3374e-02  11.5032 < 2.2e-16
#
# isState_South_Dakota                  9.2322e-02  1.4320e-01   0.6447 0.5191283
#
# isState_Tennessee                     5.2367e-01  5.2446e-02   9.9849 < 2.2e-16
#
# isState_Texas                         9.0860e-01  8.5832e-02  10.5857 < 2.2e-16
#
# isState_Utah                          6.1779e-02  1.0138e-01   0.6094 0.5422885
#
# isState_Vermont                      -3.7726e-01  1.8668e-01  -2.0208 0.0432965
#
# isState_Virginia                      1.1912e-01  9.5687e-02   1.2449 0.2131685
#
# isState_Washington                   -5.1927e-01  1.0911e-01  -4.7590 1.945e-06
#
# isState_West_Virginia                 8.0963e-02  4.8700e-02   1.6625 0.0964158
#
# isState_Wisconsin                    -1.6830e-01  5.9589e-02  -2.8244 0.0047374
#
# isState_Wyoming                       3.6213e-02  1.3564e-01   0.2670 0.7894803
#
#
#
# (Intercept)
#
# RelativeHumidityCurrent              **
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev         *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     **
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7
#
# isMonthAndYear_2020_8
#
# isMonthAndYear_2020_9                *
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   ***
#
# isState_Colorado
#
# isState_Connecticut                  *
#
# isState_Delaware                     *
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       *
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana                      *
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                **
#
# isState_Michigan
#
# isState_Minnesota                    .
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana
#
# isState_Nebraska                     ***
#
# isState_Nevada                       **
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York                     *
#
# isState_North_Carolina               **
#
# isState_North_Dakota                 *
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     *
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 **
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah
#
# isState_Vermont                      *
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia                .
#
# isState_Wisconsin                    **
#
# isState_Wyoming
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
predictorsHere=[p.replace('RelativeHumidity2MonthsPrev','RelativeHumidityCurrent') for p in predictors]

for p in predictorsHere:
    print(p)
    showMultiplicativeAssociationAndCI(negBinModelUsingHumidityCurrentCoef,p,delta=deltas.get(p,1),stdev=False,unitStrDict=unitStrDct)
    print('\n\n')
# Out:
# RelativeHumidityCurrent
# multiplicative estimate: 0.9902 [0.9843, 0.9961] per 1
# log-linear estimate: -9.866600e-03 [-3.912708e-03, -1.582049e-02] per 1 '
#
#
#
# Stringency2MonthsPrev
# multiplicative estimate: 0.9616 [0.8536, 1.0832] per 10 Oxford Stringency Index units
# log-linear estimate: -3.918700e-03 [7.987712e-03, -1.582511e-02] per 1 Oxford Stringency Index units'
#
#
#
# MaskMandates2MonthsPrev
# multiplicative estimate: 0.7036 [0.5941, 0.8332] per 1
# log-linear estimate: -3.515500e-01 [-1.824490e-01, -5.206510e-01] per 1 '
#
#
#
# MobilityReduction2MonthsPrev
# multiplicative estimate: 0.7669 [0.6093, 0.9653] per 10 Mobility reduction percent
# log-linear estimate: -2.653400e-02 [-3.529480e-03, -4.953852e-02] per 1 Mobility reduction percent'
#
#
#
# CumulCasesPer330Mill3MonthsPrev
# multiplicative estimate: 0.9280 [0.9132, 0.9431] per 1000000 cumulative cases per 330 million people
# log-linear estimate: -7.469300e-08 [-5.855534e-08, -9.083066e-08] per 1 cumulative cases per 330 million people'
#
#
#
# DeviationFrom68Fahrenheit2MonthsPrev
# multiplicative estimate: 0.9906 [0.8790, 1.1164] per 10 degrees Fahrenheit abs difference from 68F (room temp)
# log-linear estimate: -9.419300e-04 [1.101505e-02, -1.289891e-02] per 1 degrees Fahrenheit abs difference from 68F (room temp)'
#
#
#
# CovidDeathsPer330Mill2MonthsPrev
# multiplicative estimate: 0.9738 [0.9590, 0.9889] per 10000 covid death 2 months previous
# log-linear estimate: -2.654100e-06 [-1.117401e-06, -4.190799e-06] per 1 covid death 2 months previous'
#
#
#
# FahrenheitTemperature2MonthsPrev
# multiplicative estimate: 0.8359 [0.7407, 0.9433] per 10 degree Fahrenheit
# log-linear estimate: -1.792900e-02 [-5.837368e-03, -3.002063e-02] per 1 degree Fahrenheit'
#
#
#
# BoostedRate2MonthsPrev
# multiplicative estimate: 0.9459 [0.7741, 1.1557] per 10 boosted rate percent
# log-linear estimate: -5.566400e-03 [1.446676e-02, -2.559956e-02] per 1 boosted rate percent'
#
#
#
# VaxRate2MonthsPrev
# multiplicative estimate: 0.6256 [0.5330, 0.7342] per 10 vaccination rate percent
# log-linear estimate: -4.691000e-02 [-3.090209e-02, -6.291791e-02] per 1 vaccination rate percent'

# %%
pd.options.display.float_format = '{:,.3f}'.format
print(panelDF[['RelativeHumidity2MonthsPrev','RelativeHumidity1MonthsPrev','RelativeHumidityCurrent']].corr())
# Out:
#                              RelativeHumidity2MonthsPrev  \
# RelativeHumidity2MonthsPrev                        1.000
# RelativeHumidity1MonthsPrev                        0.839
# RelativeHumidityCurrent                            0.750
#
#                              RelativeHumidity1MonthsPrev  \
# RelativeHumidity2MonthsPrev                        0.839
# RelativeHumidity1MonthsPrev                        1.000
# RelativeHumidityCurrent                            0.845
#
#                              RelativeHumidityCurrent
# RelativeHumidity2MonthsPrev                    0.750
# RelativeHumidity1MonthsPrev                    0.845
# RelativeHumidityCurrent                        1.000

# %% [markdown]
# Here are a few more robustness checks not mentioned in the paper or the supplemental. All the results presented up to this point are for regressions with data from each state equally weighted. This choice was made because it is not clear at all that a population weighted regression is appropriate. Covid deaths are not independent events locally,given the local nature of the spread of covid, so the residual noise variance would not necessarily decrease like 1/state_population. However, if we weight the regression by population, the results are very similar.

# %%
negBinModelExcessPctCoefPopWeighted,_=runNegBinModel(modelStringExcessPct,panelDF,popWeighted=True)
print(negBinModelExcessPctCoefPopWeighted)
# Out:
# C:\Users\joe_s\Anaconda3\envs\renv\lib\site-packages\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "MonthAndYearObj". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'datetime.date'>'
#   (name, str(e)))
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           2.5292e+00  8.8292e-01   2.8646 0.0041759
#
# RelativeHumidity2MonthsPrev          -2.3478e-02  3.6336e-03  -6.4613 1.038e-10
#
# Stringency2MonthsPrev                -1.0126e-02  6.1023e-03  -1.6594 0.0970285
#
# MaskMandates2MonthsPrev              -2.6883e-01  1.3197e-01  -2.0371 0.0416449
#
# MobilityReduction2MonthsPrev         -3.5178e-02  1.6503e-02  -2.1317 0.0330325
#
# CumulCasesPer330Mill3MonthsPrev      -9.9422e-08  1.4012e-08  -7.0957 1.287e-12
#
# DeviationFrom68Fahrenheit2MonthsPrev -4.5770e-03  6.2572e-03  -0.7315 0.4644883
#
# CovidDeathsPer330Mill2MonthsPrev     -3.0652e-06  7.6892e-07  -3.9863 6.710e-05
#
# FahrenheitTemperature2MonthsPrev     -3.8541e-02  9.4562e-03  -4.0757 4.587e-05
#
# BoostedRate2MonthsPrev               -7.8192e-03  1.6346e-02  -0.4784 0.6323903
#
# VaxRate2MonthsPrev                   -5.5020e-02  9.1225e-03  -6.0312 1.627e-09
#
# isMonthAndYear_2020_10                1.3236e+00  2.0669e-01   6.4038 1.516e-10
#
# isMonthAndYear_2020_11                1.9629e+00  1.8174e-01  10.8007 < 2.2e-16
#
# isMonthAndYear_2020_12                2.2825e+00  1.6260e-01  14.0378 < 2.2e-16
#
# isMonthAndYear_2020_6                 4.7161e-01  3.0877e-01   1.5274 0.1266589
#
# isMonthAndYear_2020_7                 8.3021e-01  3.0127e-01   2.7557 0.0058573
#
# isMonthAndYear_2020_8                 9.4368e-01  2.3581e-01   4.0018 6.285e-05
#
# isMonthAndYear_2020_9                 1.0999e+00  2.2293e-01   4.9337 8.068e-07
#
# isMonthAndYear_2021_1                 2.2187e+00  2.2271e-01   9.9624 < 2.2e-16
#
# isMonthAndYear_2021_10                7.1350e+00  7.2625e-01   9.8245 < 2.2e-16
#
# isMonthAndYear_2021_11                7.3899e+00  7.8000e-01   9.4741 < 2.2e-16
#
# isMonthAndYear_2021_12                7.7908e+00  8.7842e-01   8.8691 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.4636e+00  3.1821e-01   4.5994 4.237e-06
#
# isMonthAndYear_2021_3                 1.0343e+00  4.5634e-01   2.2665 0.0234228
#
# isMonthAndYear_2021_4                 1.4692e+00  4.1388e-01   3.5498 0.0003855
#
# isMonthAndYear_2021_5                 2.3304e+00  4.3023e-01   5.4167 6.072e-08
#
# isMonthAndYear_2021_6                 3.3029e+00  5.3070e-01   6.2236 4.857e-10
#
# isMonthAndYear_2021_7                 4.5829e+00  5.9563e-01   7.6942 1.424e-14
#
# isMonthAndYear_2021_8                 6.3581e+00  6.3095e-01  10.0770 < 2.2e-16
#
# isMonthAndYear_2021_9                 7.0945e+00  6.8241e-01  10.3963 < 2.2e-16
#
# isMonthAndYear_2022_1                 8.4299e+00  9.6469e-01   8.7385 < 2.2e-16
#
# isMonthAndYear_2022_2                 8.2564e+00  1.0463e+00   7.8911 2.995e-15
#
# isState_Alabama                       8.6306e-01  1.0962e-01   7.8732 3.456e-15
#
# isState_Alaska                       -1.9217e-01  3.5226e-01  -0.5455 0.5853780
#
# isState_Arizona                       6.8789e-01  2.1465e-01   3.2047 0.0013521
#
# isState_Arkansas                      8.3926e-01  5.9839e-02  14.0252 < 2.2e-16
#
# isState_California                    5.1309e-01  2.8810e-01   1.7809 0.0749213
#
# isState_Colorado                     -3.0925e-01  1.1985e-01  -2.5802 0.0098745
#
# isState_Connecticut                  -3.4163e-01  1.4124e-01  -2.4189 0.0155690
#
# isState_Delaware                      3.2359e-01  1.1126e-01   2.9084 0.0036327
#
# isState_District_of_Columbia          6.7723e-01  6.3150e-01   1.0724 0.2835401
#
# isState_Florida                       1.2823e+00  2.8670e-01   4.4727 7.725e-06
#
# isState_Georgia                       6.6293e-01  1.1782e-01   5.6265 1.839e-08
#
# isState_Hawaii                       -4.7578e-01  5.8265e-01  -0.8166 0.4141755
#
# isState_Idaho                        -1.0528e+00  1.9330e-01  -5.4464 5.140e-08
#
# isState_Illinois                      1.9549e-01  6.7586e-02   2.8925 0.0038220
#
# isState_Indiana                      -5.3047e-02  5.0683e-02  -1.0467 0.2952608
#
# isState_Iowa                         -2.6132e-01  1.0193e-01  -2.5638 0.0103537
#
# isState_Kentucky                      6.0309e-01  5.7500e-02  10.4886 < 2.2e-16
#
# isState_Louisiana                     1.3406e+00  2.0585e-01   6.5122 7.406e-11
#
# isState_Maine                        -1.4978e+00  2.1760e-01  -6.8834 5.842e-12
#
# isState_Maryland                     -1.1262e-01  1.9156e-01  -0.5879 0.5565726
#
# isState_Massachusetts                -6.3035e-01  2.1410e-01  -2.9442 0.0032379
#
# isState_Michigan                     -8.1261e-02  7.1761e-02  -1.1324 0.2574716
#
# isState_Minnesota                    -2.7180e-01  8.1280e-02  -3.3440 0.0008256
#
# isState_Mississippi                   1.2655e+00  1.2466e-01  10.1515 < 2.2e-16
#
# isState_Missouri                     -3.8278e-01  8.8281e-02  -4.3359 1.452e-05
#
# isState_Montana                      -5.9755e-01  2.5985e-01  -2.2996 0.0214702
#
# isState_Nebraska                     -5.4891e-01  1.2498e-01  -4.3921 1.123e-05
#
# isState_Nevada                       -1.6284e-01  1.1954e-01  -1.3622 0.1731451
#
# isState_New_Hampshire                -1.6581e+00  1.4587e-01 -11.3667 < 2.2e-16
#
# isState_New_Jersey                   -1.4713e-01  1.9081e-01  -0.7711 0.4406732
#
# isState_New_Mexico                    4.7285e-01  1.2650e-01   3.7378 0.0001856
#
# isState_New_York                      2.9824e-01  1.4676e-01   2.0322 0.0421358
#
# isState_North_Carolina                3.3039e-01  1.0294e-01   3.2096 0.0013292
#
# isState_North_Dakota                  2.0778e-01  1.4283e-01   1.4547 0.1457412
#
# isState_Ohio                         -6.5887e-01  7.5972e-02  -8.6725 < 2.2e-16
#
# isState_Oklahoma                      2.5656e-01  5.7505e-02   4.4616 8.135e-06
#
# isState_Oregon                       -7.3775e-01  1.4521e-01  -5.0804 3.766e-07
#
# isState_Pennsylvania                 -5.8062e-01  7.4545e-02  -7.7888 6.764e-15
#
# isState_Rhode_Island                  8.5442e-01  2.1995e-01   3.8846 0.0001025
#
# isState_South_Carolina                7.9425e-01  8.7819e-02   9.0442 < 2.2e-16
#
# isState_South_Dakota                 -1.6611e-02  2.2347e-01  -0.0743 0.9407447
#
# isState_Tennessee                     7.7492e-01  6.4594e-02  11.9968 < 2.2e-16
#
# isState_Texas                         1.0052e+00  1.7315e-01   5.8055 6.418e-09
#
# isState_Utah                         -2.4725e-01  1.3255e-01  -1.8654 0.0621314
#
# isState_Vermont                      -6.5670e-01  2.3902e-01  -2.7474 0.0060069
#
# isState_Virginia                      8.5953e-02  1.4218e-01   0.6045 0.5454906
#
# isState_Washington                   -8.5153e-01  1.3050e-01  -6.5249 6.805e-11
#
# isState_West_Virginia                 1.1241e-02  6.9947e-02   0.1607 0.8723294
#
# isState_Wisconsin                    -1.8614e-01  1.0238e-01  -1.8181 0.0690516
#
# isState_Wyoming                      -4.0948e-01  2.1838e-01  -1.8751 0.0607777
#
#
#
# (Intercept)                          **
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev                .
#
# MaskMandates2MonthsPrev              *
#
# MobilityReduction2MonthsPrev         *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                **
#
# isMonthAndYear_2020_8                ***
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3                *
#
# isMonthAndYear_2021_4                ***
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arizona                      **
#
# isState_Arkansas                     ***
#
# isState_California                   .
#
# isState_Colorado                     **
#
# isState_Connecticut                  *
#
# isState_Delaware                     **
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii
#
# isState_Idaho                        ***
#
# isState_Illinois                     **
#
# isState_Indiana
#
# isState_Iowa                         *
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                **
#
# isState_Michigan
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      *
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York                     *
#
# isState_North_Carolina               **
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         .
#
# isState_Vermont                      **
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia
#
# isState_Wisconsin                    .
#
# isState_Wyoming                      .
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# The version of excess death used in this study is the CDC's "predicted (weighted)" version, which forecasts excess deaths for very recent weeks based on typical patterns in reporting lags.  There is also an "unweighted" version which stricly uses reported deaths. The difference between the 2 is minimal when only using data from (at a minimum) several months ago, as we are doing here with data limited to February 2022 and earlier. To confirm, here are results with the 'unweighted' version, which are very similar to those with the "predicted (weighted)" version.

# %%
negBinModelUnweightedExcessCoef,_=runNegBinModel(modelStringExcessPct.replace('Excess','UnweightedExcess'),panelDF)
print(negBinModelUnweightedExcessCoef)
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           1.6465e+00  7.6419e-01   2.1546 0.0311923
#
# RelativeHumidity2MonthsPrev          -2.0306e-02  3.8417e-03  -5.2857 1.253e-07
#
# Stringency2MonthsPrev                -7.4998e-03  5.9157e-03  -1.2678 0.2048750
#
# MaskMandates2MonthsPrev              -3.2235e-01  8.6508e-02  -3.7263 0.0001943
#
# MobilityReduction2MonthsPrev         -2.9491e-02  1.0437e-02  -2.8256 0.0047189
#
# CumulCasesPer330Mill3MonthsPrev      -7.3135e-08  8.6842e-09  -8.4217 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev -3.4918e-03  5.4917e-03  -0.6358 0.5248844
#
# CovidDeathsPer330Mill2MonthsPrev     -3.8530e-06  8.9189e-07  -4.3200 1.560e-05
#
# FahrenheitTemperature2MonthsPrev     -2.9543e-02  6.4254e-03  -4.5978 4.270e-06
#
# BoostedRate2MonthsPrev               -9.2261e-03  1.6161e-02  -0.5709 0.5680743
#
# VaxRate2MonthsPrev                   -4.5829e-02  8.0181e-03  -5.7157 1.093e-08
#
# isMonthAndYear_2020_10                1.1412e+00  1.8448e-01   6.1862 6.164e-10
#
# isMonthAndYear_2020_11                1.7000e+00  1.4995e-01  11.3375 < 2.2e-16
#
# isMonthAndYear_2020_12                1.9267e+00  1.3393e-01  14.3853 < 2.2e-16
#
# isMonthAndYear_2020_6                 3.2573e-01  2.4335e-01   1.3385 0.1807258
#
# isMonthAndYear_2020_7                 4.7732e-01  2.1173e-01   2.2544 0.0241689
#
# isMonthAndYear_2020_8                 6.3360e-01  1.8837e-01   3.3636 0.0007692
#
# isMonthAndYear_2020_9                 8.4628e-01  1.9400e-01   4.3623 1.287e-05
#
# isMonthAndYear_2021_1                 1.7869e+00  1.6097e-01  11.1003 < 2.2e-16
#
# isMonthAndYear_2021_10                5.6433e+00  5.9231e-01   9.5276 < 2.2e-16
#
# isMonthAndYear_2021_11                5.8471e+00  6.2645e-01   9.3338 < 2.2e-16
#
# isMonthAndYear_2021_12                6.2516e+00  6.9229e-01   9.0304 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.0666e+00  2.3702e-01   4.5000 6.794e-06
#
# isMonthAndYear_2021_3                 4.2659e-01  2.9452e-01   1.4484 0.1474987
#
# isMonthAndYear_2021_4                 8.7588e-01  3.2433e-01   2.7005 0.0069227
#
# isMonthAndYear_2021_5                 1.6496e+00  3.4516e-01   4.7791 1.760e-06
#
# isMonthAndYear_2021_6                 2.4708e+00  4.2017e-01   5.8804 4.092e-09
#
# isMonthAndYear_2021_7                 3.4520e+00  5.0040e-01   6.8984 5.258e-12
#
# isMonthAndYear_2021_8                 4.9196e+00  5.3870e-01   9.1325 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.5837e+00  5.6228e-01   9.9304 < 2.2e-16
#
# isMonthAndYear_2022_1                 6.5418e+00  8.1175e-01   8.0589 7.701e-16
#
# isMonthAndYear_2022_2                 6.3816e+00  9.2474e-01   6.9010 5.164e-12
#
# isState_Alabama                       7.9875e-01  8.2944e-02   9.6300 < 2.2e-16
#
# isState_Alaska                       -1.2014e-01  1.9673e-01  -0.6107 0.5414068
#
# isState_Arizona                       5.7851e-01  1.4479e-01   3.9956 6.453e-05
#
# isState_Arkansas                      7.9219e-01  4.9200e-02  16.1016 < 2.2e-16
#
# isState_California                    5.6961e-01  1.6829e-01   3.3847 0.0007125
#
# isState_Colorado                     -2.8034e-01  1.0254e-01  -2.7341 0.0062558
#
# isState_Connecticut                  -2.6799e-01  1.1414e-01  -2.3479 0.0188793
#
# isState_Delaware                      3.1163e-01  9.0120e-02   3.4580 0.0005443
#
# isState_District_of_Columbia          6.0218e-01  4.1122e-01   1.4644 0.1430974
#
# isState_Florida                       1.0927e+00  1.6662e-01   6.5580 5.454e-11
#
# isState_Georgia                       6.3292e-01  7.2857e-02   8.6873 < 2.2e-16
#
# isState_Hawaii                       -4.9216e-01  3.9813e-01  -1.2362 0.2163896
#
# isState_Idaho                        -9.4420e-01  1.4168e-01  -6.6644 2.658e-11
#
# isState_Illinois                      2.5902e-01  4.9733e-02   5.2083 1.906e-07
#
# isState_Indiana                      -5.5529e-03  3.3815e-02  -0.1642 0.8695634
#
# isState_Iowa                         -2.5013e-01  6.5017e-02  -3.8471 0.0001195
#
# isState_Kentucky                      6.0095e-01  6.5268e-02   9.2074 < 2.2e-16
#
# isState_Louisiana                     1.1928e+00  1.5108e-01   7.8951 2.900e-15
#
# isState_Maine                        -1.2355e+00  1.2545e-01  -9.8486 < 2.2e-16
#
# isState_Maryland                     -5.1367e-02  1.3485e-01  -0.3809 0.7032618
#
# isState_Massachusetts                -6.3870e-01  1.6482e-01  -3.8752 0.0001065
#
# isState_Michigan                      3.5745e-02  5.6025e-02   0.6380 0.5234581
#
# isState_Minnesota                    -2.1659e-01  6.5944e-02  -3.2844 0.0010218
#
# isState_Mississippi                   1.1866e+00  9.0545e-02  13.1055 < 2.2e-16
#
# isState_Missouri                     -3.0826e-01  6.1746e-02  -4.9923 5.966e-07
#
# isState_Montana                      -3.8913e-01  1.6238e-01  -2.3964 0.0165580
#
# isState_Nebraska                     -5.2339e-01  8.4101e-02  -6.2234 4.866e-10
#
# isState_Nevada                       -1.9075e-02  1.2247e-01  -0.1557 0.8762305
#
# isState_New_Hampshire                -1.5996e+00  9.2729e-02 -17.2498 < 2.2e-16
#
# isState_New_Jersey                   -9.1673e-02  1.2895e-01  -0.7109 0.4771514
#
# isState_New_Mexico                    5.2523e-01  1.1509e-01   4.5635 5.030e-06
#
# isState_New_York                      3.7795e-01  1.3514e-01   2.7967 0.0051630
#
# isState_North_Carolina                3.3713e-01  8.5096e-02   3.9618 7.439e-05
#
# isState_North_Dakota                  8.7170e-02  1.2104e-01   0.7202 0.4714300
#
# isState_Ohio                         -4.8072e-01  5.1397e-02  -9.3532 < 2.2e-16
#
# isState_Oklahoma                      1.9390e-01  4.9421e-02   3.9233 8.733e-05
#
# isState_Oregon                       -3.6765e-01  9.7990e-02  -3.7519 0.0001755
#
# isState_Pennsylvania                 -4.2146e-01  6.0090e-02  -7.0139 2.318e-12
#
# isState_Rhode_Island                  6.8055e-01  1.6894e-01   4.0284 5.616e-05
#
# isState_South_Carolina                6.9983e-01  5.6934e-02  12.2919 < 2.2e-16
#
# isState_South_Dakota                 -6.4723e-02  1.5736e-01  -0.4113 0.6808479
#
# isState_Tennessee                     6.4923e-01  4.7124e-02  13.7771 < 2.2e-16
#
# isState_Texas                         1.0102e+00  9.9436e-02  10.1588 < 2.2e-16
#
# isState_Utah                         -2.4387e-01  1.2980e-01  -1.8788 0.0602738
#
# isState_Vermont                      -4.0390e-01  1.7961e-01  -2.2488 0.0245255
#
# isState_Virginia                      1.9015e-01  9.8781e-02   1.9250 0.0542278
#
# isState_Washington                   -5.4763e-01  1.0559e-01  -5.1863 2.145e-07
#
# isState_West_Virginia                 1.5979e-01  6.5074e-02   2.4555 0.0140699
#
# isState_Wisconsin                    -1.5338e-01  5.6880e-02  -2.6966 0.0070054
#
# isState_Wyoming                      -4.0049e-01  1.5561e-01  -2.5736 0.0100646
#
#
#
# (Intercept)                          *
#
# RelativeHumidity2MonthsPrev          ***
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev         **
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                *
#
# isMonthAndYear_2020_8                ***
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   ***
#
# isState_Colorado                     **
#
# isState_Connecticut                  *
#
# isState_Delaware                     ***
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii
#
# isState_Idaho                        ***
#
# isState_Illinois                     ***
#
# isState_Indiana
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                ***
#
# isState_Michigan
#
# isState_Minnesota                    **
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      *
#
# isState_Nebraska                     ***
#
# isState_Nevada
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York                     **
#
# isState_North_Carolina               ***
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 ***
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah                         .
#
# isState_Vermont                      *
#
# isState_Virginia                     .
#
# isState_Washington                   ***
#
# isState_West_Virginia                *
#
# isState_Wisconsin                    **
#
# isState_Wyoming                      *
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# Given that the first part of the paper looks associations of RH deviations from state median RH rather than RH levels itself, one may wonder what happens if RH deviation is used in the regression rather than RH itself. Could it be that RH deviation is predictive but not RH itself? Below is an analysis that shows that RH itself rather than RH deviation is what is predictive.  Given a model with fixed parameters for each state, we get the same coefficient whether we use RH itself or its deviation from state median RH, since the association with state median RH can be absorbed into the state coefficient. However, we can look at how those state coefficients change when we change from RH itself to RH deviation. Per percent of state median RH, the state coefficients change by approximately the same amount (-0.02) as the coeffient on RH (or its deviation) in the regressions, indicating that it is RH itself and not simply deviation from RH which is driving the association.

# %%
modString=modelStringExcessPct.replace('RelativeHumidity2MonthsPrev','HumidityDeviation2MonthsPrev')
negBinModelExcessPctCoefHumidDeviation,resultHumidDeviation=runNegBinModel(modString,panelDF)
#print(mString)
print(negBinModelExcessPctCoefHumidDeviation)
#print(panelDF['State'])#['RelativeHumidity2MonthsPrev','HumidityDeviation2MonthsPrev','MedianRelativeHumidity']].corr())
# Out:
# z test of coefficients:
#
#
#
#                                         Estimate  Std. Error  z value  Pr(>|z|)
#
# (Intercept)                           2.7729e-01  5.6573e-01   0.4901 0.6240306
#
# HumidityDeviation2MonthsPrev         -2.0277e-02  3.6721e-03  -5.5220 3.352e-08
#
# Stringency2MonthsPrev                -6.4668e-03  5.9467e-03  -1.0875 0.2768287
#
# MaskMandates2MonthsPrev              -3.4664e-01  8.4047e-02  -4.1243 3.719e-05
#
# MobilityReduction2MonthsPrev         -2.5115e-02  1.0434e-02  -2.4070 0.0160825
#
# CumulCasesPer330Mill3MonthsPrev      -7.3440e-08  8.4625e-09  -8.6782 < 2.2e-16
#
# DeviationFrom68Fahrenheit2MonthsPrev -3.7244e-03  5.4809e-03  -0.6795 0.4968128
#
# CovidDeathsPer330Mill2MonthsPrev     -3.5624e-06  8.2573e-07  -4.3143 1.601e-05
#
# FahrenheitTemperature2MonthsPrev     -3.0247e-02  6.1942e-03  -4.8831 1.045e-06
#
# BoostedRate2MonthsPrev               -1.2744e-02  9.7319e-03  -1.3095 0.1903566
#
# VaxRate2MonthsPrev                   -4.5283e-02  7.9070e-03  -5.7270 1.022e-08
#
# isMonthAndYear_2020_10                1.1643e+00  1.7468e-01   6.6656 2.636e-11
#
# isMonthAndYear_2020_11                1.7155e+00  1.4413e-01  11.9026 < 2.2e-16
#
# isMonthAndYear_2020_12                1.9361e+00  1.2909e-01  14.9982 < 2.2e-16
#
# isMonthAndYear_2020_6                 1.6995e-01  2.4365e-01   0.6975 0.4854749
#
# isMonthAndYear_2020_7                 4.1824e-01  2.1298e-01   1.9637 0.0495606
#
# isMonthAndYear_2020_8                 6.3890e-01  1.8032e-01   3.5431 0.0003955
#
# isMonthAndYear_2020_9                 8.6117e-01  1.8366e-01   4.6888 2.748e-06
#
# isMonthAndYear_2021_1                 1.7600e+00  1.5923e-01  11.0534 < 2.2e-16
#
# isMonthAndYear_2021_10                5.7074e+00  5.9042e-01   9.6666 < 2.2e-16
#
# isMonthAndYear_2021_11                5.8865e+00  6.2283e-01   9.4512 < 2.2e-16
#
# isMonthAndYear_2021_12                6.3137e+00  6.7947e-01   9.2921 < 2.2e-16
#
# isMonthAndYear_2021_2                 1.0216e+00  2.3388e-01   4.3683 1.252e-05
#
# isMonthAndYear_2021_3                 3.5872e-01  2.8411e-01   1.2626 0.2067290
#
# isMonthAndYear_2021_4                 8.2966e-01  3.1329e-01   2.6483 0.0080909
#
# isMonthAndYear_2021_5                 1.6548e+00  3.3368e-01   4.9592 7.078e-07
#
# isMonthAndYear_2021_6                 2.4853e+00  4.1378e-01   6.0064 1.897e-09
#
# isMonthAndYear_2021_7                 3.4911e+00  4.9242e-01   7.0895 1.346e-12
#
# isMonthAndYear_2021_8                 4.9888e+00  5.3543e-01   9.3173 < 2.2e-16
#
# isMonthAndYear_2021_9                 5.6559e+00  5.6060e-01  10.0890 < 2.2e-16
#
# isMonthAndYear_2022_1                 6.8410e+00  7.3044e-01   9.3655 < 2.2e-16
#
# isMonthAndYear_2022_2                 6.7674e+00  7.6586e-01   8.8363 < 2.2e-16
#
# isState_Alabama                       6.7971e-01  6.9395e-02   9.7947 < 2.2e-16
#
# isState_Alaska                       -4.0092e-01  2.2516e-01  -1.7806 0.0749781
#
# isState_Arizona                       1.3616e+00  1.1948e-01  11.3962 < 2.2e-16
#
# isState_Arkansas                      5.6466e-01  3.1080e-02  18.1680 < 2.2e-16
#
# isState_California                    8.9577e-01  1.9882e-01   4.5053 6.627e-06
#
# isState_Colorado                      2.4197e-01  8.3709e-02   2.8906 0.0038455
#
# isState_Connecticut                  -4.4320e-01  1.0868e-01  -4.0782 4.539e-05
#
# isState_Delaware                      1.1377e-01  7.9637e-02   1.4287 0.1531016
#
# isState_District_of_Columbia          4.1394e-01  4.1075e-01   1.0078 0.3135656
#
# isState_Florida                       9.6493e-01  1.5995e-01   6.0325 1.614e-09
#
# isState_Georgia                       5.6962e-01  6.7383e-02   8.4535 < 2.2e-16
#
# isState_Hawaii                       -7.7848e-01  3.8108e-01  -2.0428 0.0410692
#
# isState_Idaho                        -6.9501e-01  1.1638e-01  -5.9719 2.345e-09
#
# isState_Illinois                      1.2287e-01  4.3904e-02   2.7987 0.0051316
#
# isState_Indiana                      -2.4356e-01  3.4364e-02  -7.0878 1.363e-12
#
# isState_Iowa                         -4.1971e-01  7.8447e-02  -5.3503 8.781e-08
#
# isState_Kentucky                      3.3376e-01  3.7385e-02   8.9276 < 2.2e-16
#
# isState_Louisiana                     9.5023e-01  1.1857e-01   8.0139 1.111e-15
#
# isState_Maine                        -1.3630e+00  1.2458e-01 -10.9411 < 2.2e-16
#
# isState_Maryland                     -1.8677e-01  1.2692e-01  -1.4716 0.1411405
#
# isState_Massachusetts                -8.3040e-01  1.6020e-01  -5.1834 2.179e-07
#
# isState_Michigan                     -1.6446e-01  4.9692e-02  -3.3096 0.0009343
#
# isState_Minnesota                    -4.1102e-01  6.8025e-02  -6.0421 1.521e-09
#
# isState_Mississippi                   8.9609e-01  6.3242e-02  14.1692 < 2.2e-16
#
# isState_Missouri                     -4.5257e-01  6.6844e-02  -6.7705 1.283e-11
#
# isState_Montana                      -3.7121e-01  1.5723e-01  -2.3609 0.0182308
#
# isState_Nebraska                     -5.4376e-01  8.3613e-02  -6.5033 7.859e-11
#
# isState_Nevada                        7.6664e-01  7.2010e-02  10.6462 < 2.2e-16
#
# isState_New_Hampshire                -1.6993e+00  8.9370e-02 -19.0139 < 2.2e-16
#
# isState_New_Jersey                   -1.9404e-01  1.3154e-01  -1.4751 0.1401920
#
# isState_New_Mexico                    1.1265e+00  1.2011e-01   9.3792 < 2.2e-16
#
# isState_New_York                      2.0740e-01  1.3318e-01   1.5573 0.1194013
#
# isState_North_Carolina                1.7217e-01  6.7137e-02   2.5645 0.0103332
#
# isState_North_Dakota                  7.3379e-02  1.1074e-01   0.6626 0.5075680
#
# isState_Ohio                         -7.3388e-01  4.4118e-02 -16.6345 < 2.2e-16
#
# isState_Oklahoma                      1.8387e-01  4.8367e-02   3.8014 0.0001439
#
# isState_Oregon                       -5.7512e-01  8.8442e-02  -6.5028 7.886e-11
#
# isState_Pennsylvania                 -6.3309e-01  4.6367e-02 -13.6539 < 2.2e-16
#
# isState_Rhode_Island                  4.5402e-01  1.6463e-01   2.7577 0.0058205
#
# isState_South_Carolina                5.6931e-01  4.7331e-02  12.0281 < 2.2e-16
#
# isState_South_Dakota                 -5.2965e-02  1.5167e-01  -0.3492 0.7269352
#
# isState_Tennessee                     4.2068e-01  3.8521e-02  10.9209 < 2.2e-16
#
# isState_Texas                         1.0209e+00  1.0114e-01  10.0938 < 2.2e-16
#
# isState_Utah                          4.7183e-02  7.5040e-02   0.6288 0.5295002
#
# isState_Vermont                      -7.1784e-01  1.6007e-01  -4.4846 7.306e-06
#
# isState_Virginia                      1.8304e-02  8.5545e-02   0.2140 0.8305667
#
# isState_Washington                   -8.0480e-01  9.4244e-02  -8.5395 < 2.2e-16
#
# isState_West_Virginia                -1.1312e-01  4.8438e-02  -2.3353 0.0195301
#
# isState_Wisconsin                    -4.2895e-01  6.9533e-02  -6.1690 6.872e-10
#
# isState_Wyoming                      -2.3025e-02  1.2282e-01  -0.1875 0.8512955
#
#
#
# (Intercept)
#
# HumidityDeviation2MonthsPrev         ***
#
# Stringency2MonthsPrev
#
# MaskMandates2MonthsPrev              ***
#
# MobilityReduction2MonthsPrev         *
#
# CumulCasesPer330Mill3MonthsPrev      ***
#
# DeviationFrom68Fahrenheit2MonthsPrev
#
# CovidDeathsPer330Mill2MonthsPrev     ***
#
# FahrenheitTemperature2MonthsPrev     ***
#
# BoostedRate2MonthsPrev
#
# VaxRate2MonthsPrev                   ***
#
# isMonthAndYear_2020_10               ***
#
# isMonthAndYear_2020_11               ***
#
# isMonthAndYear_2020_12               ***
#
# isMonthAndYear_2020_6
#
# isMonthAndYear_2020_7                *
#
# isMonthAndYear_2020_8                ***
#
# isMonthAndYear_2020_9                ***
#
# isMonthAndYear_2021_1                ***
#
# isMonthAndYear_2021_10               ***
#
# isMonthAndYear_2021_11               ***
#
# isMonthAndYear_2021_12               ***
#
# isMonthAndYear_2021_2                ***
#
# isMonthAndYear_2021_3
#
# isMonthAndYear_2021_4                **
#
# isMonthAndYear_2021_5                ***
#
# isMonthAndYear_2021_6                ***
#
# isMonthAndYear_2021_7                ***
#
# isMonthAndYear_2021_8                ***
#
# isMonthAndYear_2021_9                ***
#
# isMonthAndYear_2022_1                ***
#
# isMonthAndYear_2022_2                ***
#
# isState_Alabama                      ***
#
# isState_Alaska                       .
#
# isState_Arizona                      ***
#
# isState_Arkansas                     ***
#
# isState_California                   ***
#
# isState_Colorado                     **
#
# isState_Connecticut                  ***
#
# isState_Delaware
#
# isState_District_of_Columbia
#
# isState_Florida                      ***
#
# isState_Georgia                      ***
#
# isState_Hawaii                       *
#
# isState_Idaho                        ***
#
# isState_Illinois                     **
#
# isState_Indiana                      ***
#
# isState_Iowa                         ***
#
# isState_Kentucky                     ***
#
# isState_Louisiana                    ***
#
# isState_Maine                        ***
#
# isState_Maryland
#
# isState_Massachusetts                ***
#
# isState_Michigan                     ***
#
# isState_Minnesota                    ***
#
# isState_Mississippi                  ***
#
# isState_Missouri                     ***
#
# isState_Montana                      *
#
# isState_Nebraska                     ***
#
# isState_Nevada                       ***
#
# isState_New_Hampshire                ***
#
# isState_New_Jersey
#
# isState_New_Mexico                   ***
#
# isState_New_York
#
# isState_North_Carolina               *
#
# isState_North_Dakota
#
# isState_Ohio                         ***
#
# isState_Oklahoma                     ***
#
# isState_Oregon                       ***
#
# isState_Pennsylvania                 ***
#
# isState_Rhode_Island                 **
#
# isState_South_Carolina               ***
#
# isState_South_Dakota
#
# isState_Tennessee                    ***
#
# isState_Texas                        ***
#
# isState_Utah
#
# isState_Vermont                      ***
#
# isState_Virginia
#
# isState_Washington                   ***
#
# isState_West_Virginia                *
#
# isState_Wisconsin                    ***
#
# isState_Wyoming
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
def getStateFixedParams(resultCoef):
    stateDct=dict()
    for nm in resultCoef.names:
        if (nm.find('isState') != -1):
            stateName=nm.split('isState_')[1].strip()
            stateDct[stateName.strip()]=resultCoef[resultCoef.names.index(nm)]
    return stateDct

stateFixedParams=getStateFixedParams(result.rx('coefficients')[0])
#print(stateFixedParams)

stateFixedParamsHumidDeviation=getStateFixedParams(resultHumidDeviation.rx('coefficients')[0])
#print(stateFixedParams)
#print('\n\n')
#print(stateFixedParamsHumidDeviation)
medianHumidity=dict(zip(panelDF['State'].values,panelDF['MedianRelativeHumidity'].values))

fixedParamChangeList=[]
medianHumidityList=[]
states=[]
for state in stateFixedParams:
    states.append(state)
    fixedParamChangeList.append(stateFixedParamsHumidDeviation[state]- stateFixedParams[state])
    medianHumidityList.append(medianHumidity[state])
    
import numpy
mean=numpy.mean(medianHumidityList)
#print(numpy.corrcoef(fixedParamChangeList,medianHumidityList))
fixedParamChangePerRH=[]
for i in range(len(fixedParamChangeList)):
    if (numpy.abs(medianHumidityList[i]-mean) < 2):
        print('*** %s within 2 percent of median humidity, fixed param change less accurate'%(states[i]))
    else:
        fixedParamChangePerRH.append(fixedParamChangeList[i]/(medianHumidityList[i]-mean))
    print(states[i],"%3.3f"%fixedParamChangeList[i],"%3.3f"%medianHumidityList[i],
          "%3.3f"%(fixedParamChangeList[i]/(medianHumidityList[i]-mean)))
    
print('mean change per state median RH %3.3f, min %3.3f max %3.3f'%(numpy.mean(fixedParamChangePerRH),
     numpy.min(fixedParamChangePerRH),numpy.max(fixedParamChangePerRH)))
#print(zip(fixedParamChangeList,medianHumidityList))
# Out:
# Alabama -0.153 74.400 -0.024
# Alaska -0.321 82.700 -0.022
# Arizona 0.816 26.600 -0.020
# Arkansas -0.195 76.450 -0.023
# California 0.422 46.050 -0.019
# Colorado 0.496 42.400 -0.019
# Connecticut -0.101 71.850 -0.027
# Delaware -0.118 72.650 -0.026
# *** District_of_Columbia within 2 percent of median humidity, fixed param change less accurate
# District_of_Columbia -0.017 67.700 0.042
# *** Florida within 2 percent of median humidity, fixed param change less accurate
# Florida -0.039 68.750 -0.060
# *** Georgia within 2 percent of median humidity, fixed param change less accurate
# Georgia -0.028 68.250 -0.200
# Hawaii -0.126 73.050 -0.025
# Idaho 0.196 57.200 -0.018
# Illinois -0.088 71.200 -0.029
# Indiana -0.197 76.550 -0.023
# Iowa -0.150 74.250 -0.024
# Kentucky -0.211 77.250 -0.023
# Louisiana -0.221 77.750 -0.023
# Maine -0.177 75.600 -0.024
# Maryland -0.082 70.900 -0.029
# Massachusetts -0.129 73.200 -0.025
# Michigan -0.163 74.900 -0.024
# Minnesota -0.133 73.400 -0.025
# Mississippi -0.248 79.100 -0.023
# Missouri -0.125 73.000 -0.025
# Montana 0.036 65.050 -0.012
# *** Nebraska within 2 percent of median humidity, fixed param change less accurate
# Nebraska -0.007 67.200 0.008
# Nevada 0.810 26.900 -0.020
# New_Hampshire -0.169 75.200 -0.024
# *** New_Jersey within 2 percent of median humidity, fixed param change less accurate
# New_Jersey -0.002 66.950 0.002
# New_Mexico 0.612 36.650 -0.019
# New_York -0.074 70.500 -0.031
# North_Carolina -0.132 73.350 -0.025
# North_Dakota 0.059 63.950 -0.014
# Ohio -0.207 77.050 -0.023
# *** Oklahoma within 2 percent of median humidity, fixed param change less accurate
# Oklahoma -0.002 66.950 0.002
# Oregon -0.157 74.600 -0.024
# Pennsylvania -0.149 74.200 -0.024
# Rhode_Island -0.143 73.900 -0.025
# South_Carolina -0.114 72.450 -0.026
# South_Dakota 0.022 65.750 -0.009
# Tennessee -0.178 75.650 -0.024
# Texas 0.051 64.350 -0.013
# Utah 0.356 49.300 -0.019
# Vermont -0.276 80.450 -0.022
# Virginia -0.116 72.550 -0.026
# Washington -0.195 76.450 -0.023
# West_Virginia -0.231 78.250 -0.023
# Wisconsin -0.231 78.250 -0.023
# Wyoming 0.253 54.350 -0.018
# mean change per state median RH -0.023, min -0.031 max -0.009
